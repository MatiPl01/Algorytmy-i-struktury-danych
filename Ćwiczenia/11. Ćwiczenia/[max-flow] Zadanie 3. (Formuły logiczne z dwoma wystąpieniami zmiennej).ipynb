# %% [markdown]
# ### Treść zadania

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Omówienie algorytmu

# %% [markdown]
# Jest to algorytm bardziej do omówienia niż do implementacji, więc go nie implementuję.
