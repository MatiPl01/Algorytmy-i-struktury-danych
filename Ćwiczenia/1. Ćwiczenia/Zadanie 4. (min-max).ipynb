# %% [markdown]
# > Proszę zaimplementować funkcję, która mając na wejściu tablicę n elementów oblicza jednocześnie jej największy i najmniejszy element wykonując $ \frac{3}{2}n $ porównań.

# %% [markdown]
# ##### Funkcja sprawdzająca poprawność algorytmu (nie jest częścią zadania)

# %%
import random

def test_minmax(fn, *, reps=20):
    passed = 0
    for i in range(reps):
        values = [random.randint(-1000, 1000) for _ in range(random.randint(1, 20))]
        res_min, res_max = fn(values)
        expected_min, expected_max = min(values), max(values)
        is_correct = res_min == expected_min and res_max == expected_max
        passed += is_correct
        print(f'#{i+1} test (currently passed: {passed}/{reps})')
        print('Test values:', values)
        print('Expected min:', expected_min, '\tResult min:', res_min)
        print('Expected max:', expected_max, '\tResult max:', res_max)
        print(f'Test {"passed" if is_correct else "failed"}')
        print()
    print(f'Total tests passed: {passed}/{reps}')
    print(f'This algorithm is {"correct" if passed == reps else "wrong"}')

# %% [markdown]
# ### Implementacja algorytmu

# %% [markdown]
# Najbardziej trywialnym rozwiązaniem jest przejście po całej sekwencji i kolejno sprawdzenie, czy bieżąca wartość jest największa oraz, czy jest ona najmniejsza. Nie jest to jednak optymalne rozwiązanie, ponieważ wiele wartości nie będzie ani największymi ani najmniejszymi, więc niepotrzebnie wykonujemy $ 2 $ sprawdzenia na jedną wartość (łacznie $ 2n $ porównań).

# %% [markdown]
# W obu poniższych implementacjach zaczynamy od tego, że zmiennym $ global\_max $ i $ global\_min $ przypisujemy ostatni element z sekwencji. Robimy tak, bo w pętli $ for $ będziemy przechodzić przez parzystą liczbę elementów, więc jeżeli sekwencja $ arr $ ma np. $ 9 $ elementów, zakończymy sprawdzanie na ósmym w kolejności elemencie (tym o indeksie $ 7 $). Pozwala nam to jednocześnie obsłużyć oba możliwe scenariusze - gdy sekwencja jest parzystej lub nieparzystej długości. Dzięki temu nie jest konieczne porównywanie osobno ostatniej wartości w nieparzystej sekwencji z $ global\_max $ oraz $ global\_min $ po zakończeniu pętli. W samej pętli for w kolejnych iteracjach przypisujemy zmiennej $ i $ co drugi indeks, począwszy od $ 0 $ (kolejno $ 0, 2, 4, ... $), a następnie porównujemy dwie sąsiednie wartości, decydując, która z nich jest większa. Po wyznaczeniu większej oraz mniejszej wartości z pary, porównujemy tylko tę większą z $ global\_max $ oraz tylko tę mniejszą z $ global\_min $. Łatwo można zauważyć, że na każdą parę ($ 2 $ sąsiednie wartości) mamy $ 3 $ porównania (1. porównanie tej pary, 2. porównanie większej wartości z $ global\_max $, 3. porównanie mniejszej wartości z $ global\_min $). Ponieważ pętla for ma łącznie $ \lfloor\frac{n}{2}\rfloor $ przebiegów (podłoga z $ \frac{n}{2} $, bo dla nieparzystych $ n $ omijamy ostatni element - wyjaśnienie wyżej), gdzie $ n = len(arr) $, co oznacza, że mamy $ \lfloor\frac{n}{2}\rfloor $ par do porównania, a na każdą parę są potrzebne $ 3 $ porównania, łącznie konieczne jest $ 3 \cdot \lfloor\frac{n}{2}\rfloor \approx \frac{3}{2}n $ porównań.

# %% [markdown]
# #### I wersja (z użyciem funkcji min oraz max)

# %% [markdown]
# Nieco wolniejsza niż II wersja, bo poza sprawdzeniem, która wartość jest większa/mniejsza, przy pomocy funkcji min/max, ZAWSZE odpowiednio mniejsza/większa wartość musi zostać przypisana właściwej zmiennej (global_min/global_max), nawet gdy global_min jest mniejsze a global_max większe od wartości, z którą jest porównywane.

# %%
def minmax(arr):
    global_min = global_max = arr[-1]
    
    for i in range(0, len(arr)-1, 2):
        if arr[i] > arr[i+1]:
            global_max = max(global_max, arr[i])
            global_min = min(global_min, arr[i+1])
        else:
            global_max = max(global_max, arr[i+1])
            global_min = min(global_min, arr[i])
            
    return global_min, global_max

# %% [markdown]
# ###### Przykładowy test

# %%
test_minmax(minmax, reps=100)
# Out:
# #1 test (currently passed: 1/100)
# Test values: [309, 398, 847, -113, 975, 660, 970, 225, 295, -31, -301, 535, -577, -38, -315, -157]
# Expected min: -577 	Result min: -577
# Expected max: 975 	Result max: 975
# Test passed
#
# #2 test (currently passed: 2/100)
# Test values: [4, 736, -229, -230, -769, -788, 444, -18, -819, 67, -976, -423, -161, 884, -360, -354, 401, -528, -512, -838]
# Expected min: -976 	Result min: -976
# Expected max: 884 	Result max: 884
# Test passed
#
# #3 test (currently passed: 3/100)
# Test values: [131, -206, -715, -545, 769, -336, 706]
# Expected min: -715 	Result min: -715
# Expected max: 769 	Result max: 769
# Test passed
#
# #4 test (currently passed: 4/100)
# Test values: [523, -790, 699, -911, -668, 978]
# Expected min: -911 	Result min: -911
# Expected max: 978 	Result max: 978
# Test passed
#
# #5 test (currently passed: 5/100)
# Test values: [660, -830, 688]
# Expected min: -830 	Result min: -830
# Expected max: 688 	Result max: 688
# Test passed
#
# #6 test (currently passed: 6/100)
# Test values: [50, 661, -621, -374, 194, -117, 162, -779, 120, -902, 224, 194]
# Expected min: -902 	Result min: -902
# Expected max: 661 	Result max: 661
# Test passed
#
# #7 test (currently passed: 7/100)
# Test values: [-212, -485, 499, -758, -69, -46]
# Expected min: -758 	Result min: -758
# Expected max: 499 	Result max: 499
# Test passed
#
# #8 test (currently passed: 8/100)
# Test values: [336]
# Expected min: 336 	Result min: 336
# Expected max: 336 	Result max: 336
# Test passed
#
# #9 test (currently passed: 9/100)
# Test values: [816, 578, 988, 131, 281, 397, 558, 187, 172, -494, -622, -329, 125, 158, 75, -16, -69, -911]
# Expected min: -911 	Result min: -911
# Expected max: 988 	Result max: 988
# Test passed
#
# #10 test (currently passed: 10/100)
# Test values: [885]
# Expected min: 885 	Result min: 885
# Expected max: 885 	Result max: 885
# Test passed
#
# #11 test (currently passed: 11/100)
# Test values: [81, -477, 769, -789, 263]
# Expected min: -789 	Result min: -789
# Expected max: 769 	Result max: 769
# Test passed
#
# #12 test (currently passed: 12/100)
# Test values: [-520, 641, -720, 804, 26, 244, 341, -893, -501, 8, -283, 83, 945, -498]
# Expected min: -893 	Result min: -893
# Expected max: 945 	Result max: 945
# Test passed
#
# #13 test (currently passed: 13/100)
# Test values: [-792, 982, 626, -617, 558, -853, 442, 275, -958, 843, -105, 406, -602, 943, -982, 584, 934]
# Expected min: -982 	Result min: -982
# Expected max: 982 	Result max: 982
# Test passed
#
# #14 test (currently passed: 14/100)
# Test values: [-602, 978, -236, -732, 684, -923, 469, 632, 388, 526, 445, -85]
# Expected min: -923 	Result min: -923
# Expected max: 978 	Result max: 978
# Test passed
#
# #15 test (currently passed: 15/100)
# Test values: [409, -684, 771, -792, -937, -606, -624, -640, -313, -487, 73, 971, -271, -305, 734, 233, -464, 123, 93]
# Expected min: -937 	Result min: -937
# Expected max: 971 	Result max: 971
# Test passed
#
# #16 test (currently passed: 16/100)
# Test values: [-250, -99, -786, -426, -556, 88, 46, -472, 312, -645, 929, -445, -395, 938, 796, -658]
# Expected min: -786 	Result min: -786
# Expected max: 938 	Result max: 938
# Test passed
#
# #17 test (currently passed: 17/100)
# Test values: [-637, 673, 674, -246, -972, -389, 468, 168, 600, -849, 497]
# Expected min: -972 	Result min: -972
# Expected max: 674 	Result max: 674
# Test passed
#
# #18 test (currently passed: 18/100)
# Test values: [-673, 53, 312, -328, -540, 228, 617, 343, -422, 940, 16, 645, -529, 87, 205, -976]
# Expected min: -976 	Result min: -976
# Expected max: 940 	Result max: 940
# Test passed
#
# #19 test (currently passed: 19/100)
# Test values: [981, -654, -714, -481, -952, -785, 39, 231, -913, 560]
# Expected min: -952 	Result min: -952
# Expected max: 981 	Result max: 981
# Test passed
#
# #20 test (currently passed: 20/100)
# Test values: [964, 347, 950, -781, 650, 470]
# Expected min: -781 	Result min: -781
# Expected max: 964 	Result max: 964
# Test passed
#
# #21 test (currently passed: 21/100)
# Test values: [339, 652, -244]
# Expected min: -244 	Result min: -244
# Expected max: 652 	Result max: 652
# Test passed
#
# #22 test (currently passed: 22/100)
# Test values: [966, -586, 860, -311, 382, 572, 465, 110, 820]
# Expected min: -586 	Result min: -586
# Expected max: 966 	Result max: 966
# Test passed
#
# #23 test (currently passed: 23/100)
# Test values: [461, -513, -918, 915, 47, 821, 739, -452, -1, -574, 434, -705]
# Expected min: -918 	Result min: -918
# Expected max: 915 	Result max: 915
# Test passed
#
# #24 test (currently passed: 24/100)
# Test values: [-954, -394, -191, -544, 69, 994, 302, 404, -458, 780, -767, -720, -274, -219, 117, 11]
# Expected min: -954 	Result min: -954
# Expected max: 994 	Result max: 994
# Test passed
#
# #25 test (currently passed: 25/100)
# Test values: [-266, 164]
# Expected min: -266 	Result min: -266
# Expected max: 164 	Result max: 164
# Test passed
#
# #26 test (currently passed: 26/100)
# Test values: [795, -466, 578, -442, 978, -567, -487, 353, 710, -961, -269, 955, 548, 764, -698]
# Expected min: -961 	Result min: -961
# Expected max: 978 	Result max: 978
# Test passed
#
# #27 test (currently passed: 27/100)
# Test values: [21, 137, -98]
# Expected min: -98 	Result min: -98
# Expected max: 137 	Result max: 137
# Test passed
#
# #28 test (currently passed: 28/100)
# Test values: [847, 493, 828, -441, -23, -416, 114, 601, -453, -323, 845, -978, -757]
# Expected min: -978 	Result min: -978
# Expected max: 847 	Result max: 847
# Test passed
#
# #29 test (currently passed: 29/100)
# Test values: [946, 940, -318, -697, -416, -342, -290, 249, 478, 873, 802, -94, 237, 186, -79]
# Expected min: -697 	Result min: -697
# Expected max: 946 	Result max: 946
# Test passed
#
# #30 test (currently passed: 30/100)
# Test values: [-750, 72, 78]
# Expected min: -750 	Result min: -750
# Expected max: 78 	Result max: 78
# Test passed
#
# #31 test (currently passed: 31/100)
# Test values: [888, 856, 837, 915, 422, -828, 306, -64, 84, -758]
# Expected min: -828 	Result min: -828
# Expected max: 915 	Result max: 915
# Test passed
#
# #32 test (currently passed: 32/100)
# Test values: [201, -314, -385, 94, -263, 864, 867, 30, -855, 282, -873, 887, 90, 350, -1, 327, -72, 669, 783, 563]
# Expected min: -873 	Result min: -873
# Expected max: 887 	Result max: 887
# Test passed
#
# #33 test (currently passed: 33/100)
# Test values: [-759, -764, 214, 703, -723, -898, -85]
# Expected min: -898 	Result min: -898
# Expected max: 703 	Result max: 703
# Test passed
#
# #34 test (currently passed: 34/100)
# Test values: [997, 463, -782, 581, -742, -527, -273, 12, -947]
# Expected min: -947 	Result min: -947
# Expected max: 997 	Result max: 997
# Test passed
#
# #35 test (currently passed: 35/100)
# Test values: [847, -388, 311, 288, 913, 960, 467, -573]
# Expected min: -573 	Result min: -573
# Expected max: 960 	Result max: 960
# Test passed
#
# #36 test (currently passed: 36/100)
# Test values: [-170, 457, 200]
# Expected min: -170 	Result min: -170
# Expected max: 457 	Result max: 457
# Test passed
#
# #37 test (currently passed: 37/100)
# Test values: [-933, 934, 894, -824, 272, 285]
# Expected min: -933 	Result min: -933
# Expected max: 934 	Result max: 934
# Test passed
#
# #38 test (currently passed: 38/100)
# Test values: [-651, 655, 704, -86, 588, -393, -341, 428, -600, 863, 502, -68]
# Expected min: -651 	Result min: -651
# Expected max: 863 	Result max: 863
# Test passed
#
# #39 test (currently passed: 39/100)
# Test values: [-315, -469, 765, -417, -529, 164, -261, 26, 59, 345, -200, -197, 56, 895, -404, -163, 158]
# Expected min: -529 	Result min: -529
# Expected max: 895 	Result max: 895
# Test passed
#
# #40 test (currently passed: 40/100)
# Test values: [921, -801, -712, 86, -570, 645, -355, -608, 38, 959, -128, -469, -815, 217]
# Expected min: -815 	Result min: -815
# Expected max: 959 	Result max: 959
# Test passed
#
# #41 test (currently passed: 41/100)
# Test values: [221, -14, 138, -595, -929, 147, -722, -214]
# Expected min: -929 	Result min: -929
# Expected max: 221 	Result max: 221
# Test passed
#
# #42 test (currently passed: 42/100)
# Test values: [786, 981, -968, 203, -289, -218, 977, 929, 168, -848, 259, -138]
# Expected min: -968 	Result min: -968
# Expected max: 981 	Result max: 981
# Test passed
#
# #43 test (currently passed: 43/100)
# Test values: [346, -194, -11, -24, 424, 872, 671, 294, 708, 856, -497, 898, -824, -486, 437, -259]
# Expected min: -824 	Result min: -824
# Expected max: 898 	Result max: 898
# Test passed
#
# #44 test (currently passed: 44/100)
# Test values: [-534, -675, 816, 551, 509, -907, -741, -196, -775, 745, -358, 425, -81, 252, 127, -922, -296, 829, -540]
# Expected min: -922 	Result min: -922
# Expected max: 829 	Result max: 829
# Test passed
#
# #45 test (currently passed: 45/100)
# Test values: [550, 774, 462, -62, -753, -682, -791, 478, -856, -443, 24, -595, 178]
# Expected min: -856 	Result min: -856
# Expected max: 774 	Result max: 774
# Test passed
#
# #46 test (currently passed: 46/100)
# Test values: [-2]
# Expected min: -2 	Result min: -2
# Expected max: -2 	Result max: -2
# Test passed
#
# #47 test (currently passed: 47/100)
# Test values: [495, -153, 694, -275, 623, -741, 167, -339, 545, -443]
# Expected min: -741 	Result min: -741
# Expected max: 694 	Result max: 694
# Test passed
#
# #48 test (currently passed: 48/100)
# Test values: [311, -316, -558, 819, -161, 50, -935, -851, -874, -915, 682]
# Expected min: -935 	Result min: -935
# Expected max: 819 	Result max: 819
# Test passed
#
# #49 test (currently passed: 49/100)
# Test values: [-146, 202, 703, -575]
# Expected min: -575 	Result min: -575
# Expected max: 703 	Result max: 703
# Test passed
#
# #50 test (currently passed: 50/100)
# Test values: [-16, -524, 961, 566, 472, -331, 695, -329, -745, -741, -284, 534, 177, -883, -70, 801]
# Expected min: -883 	Result min: -883
# Expected max: 961 	Result max: 961
# Test passed
#
# #51 test (currently passed: 51/100)
# Test values: [-824, 325, -862, -595, -641, -780, -241, 453, 712, -162, -90, -470, -128, 124]
# Expected min: -862 	Result min: -862
# Expected max: 712 	Result max: 712
# Test passed
#
# #52 test (currently passed: 52/100)
# Test values: [-66, -185, -170, 15, -187, 926, 713, 4, 331, 75, 432, 865, -227, -234, 990, -992, -218]
# Expected min: -992 	Result min: -992
# Expected max: 990 	Result max: 990
# Test passed
#
# #53 test (currently passed: 53/100)
# Test values: [224, -442, 481, 240, 812, 196, 335, 52, 865, 371]
# Expected min: -442 	Result min: -442
# Expected max: 865 	Result max: 865
# Test passed
#
# #54 test (currently passed: 54/100)
# Test values: [991, -676, -392, 403]
# Expected min: -676 	Result min: -676
# Expected max: 991 	Result max: 991
# Test passed
#
# #55 test (currently passed: 55/100)
# Test values: [-901, 939, 832, -579, -290, 955, 419, 236, 169, 961, 690, -616, -544, -301, -360, 345, -688, 410, 546, -280]
# Expected min: -901 	Result min: -901
# Expected max: 961 	Result max: 961
# Test passed
#
# #56 test (currently passed: 56/100)
# Test values: [113, 637, -339, -871, 148, 174, 255, 114, 929, -626, -67, -484, -247, 715, -58, 936]
# Expected min: -871 	Result min: -871
# Expected max: 936 	Result max: 936
# Test passed
#
# #57 test (currently passed: 57/100)
# Test values: [178, -57, -559, 377, -186, -963, -822, -715, -682]
# Expected min: -963 	Result min: -963
# Expected max: 377 	Result max: 377
# Test passed
#
# #58 test (currently passed: 58/100)
# Test values: [-86, -641, -247, 173]
# Expected min: -641 	Result min: -641
# Expected max: 173 	Result max: 173
# Test passed
#
# #59 test (currently passed: 59/100)
# Test values: [-4, 546, -879, -46, 242, 377, -135, 667, 117, 523, 246, -297]
# Expected min: -879 	Result min: -879
# Expected max: 667 	Result max: 667
# Test passed
#
# #60 test (currently passed: 60/100)
# Test values: [-959, 474, 966, -143, -44, 328, 325, -299, 585, 10, 295, 159, -487, -838]
# Expected min: -959 	Result min: -959
# Expected max: 966 	Result max: 966
# Test passed
#
# #61 test (currently passed: 61/100)
# Test values: [668, 14, 741, 899, -466, 193, 123, -366, -234, -782, -829, 327, -97, 145, 180, 840, -996, -750]
# Expected min: -996 	Result min: -996
# Expected max: 899 	Result max: 899
# Test passed
#
# #62 test (currently passed: 62/100)
# Test values: [266, 948, 266, 393, -702, -841, -686, -926, -135, -610, -775]
# Expected min: -926 	Result min: -926
# Expected max: 948 	Result max: 948
# Test passed
#
# #63 test (currently passed: 63/100)
# Test values: [-113, -855, 125, -448, -932, -760, 342]
# Expected min: -932 	Result min: -932
# Expected max: 342 	Result max: 342
# Test passed
#
# #64 test (currently passed: 64/100)
# Test values: [-376, -828, 431, 445, 833, 272, -415, -478, 973, 266, -428, -644, 975, 23, -26, -375, 159]
# Expected min: -828 	Result min: -828
# Expected max: 975 	Result max: 975
# Test passed
#
# #65 test (currently passed: 65/100)
# Test values: [-676, 378, 952, 127, 316, -889, -232, 839, 35, -80, 847, 764, -429, 574]
# Expected min: -889 	Result min: -889
# Expected max: 952 	Result max: 952
# Test passed
#
# #66 test (currently passed: 66/100)
# Test values: [-573, -787, 547, 342, 880, 685, -63, -612, 509, 189, -617, 292, 139]
# Expected min: -787 	Result min: -787
# Expected max: 880 	Result max: 880
# Test passed
#
# #67 test (currently passed: 67/100)
# Test values: [894, -704, -978, 8, -974, -421, 153, 184, -490, -599, 659]
# Expected min: -978 	Result min: -978
# Expected max: 894 	Result max: 894
# Test passed
#
# #68 test (currently passed: 68/100)
# Test values: [54, 828, -72, -490]
# Expected min: -490 	Result min: -490
# Expected max: 828 	Result max: 828
# Test passed
#
# #69 test (currently passed: 69/100)
# Test values: [663, 463, -260, -146, -175, 119]
# Expected min: -260 	Result min: -260
# Expected max: 663 	Result max: 663
# Test passed
#
# #70 test (currently passed: 70/100)
# Test values: [24, -340, 470, -773, 591, 780, -475]
# Expected min: -773 	Result min: -773
# Expected max: 780 	Result max: 780
# Test passed
#
# #71 test (currently passed: 71/100)
# Test values: [-653, 931, -656, -606, 276, 887, 761, -532, -500, 538, -765, -879, -251, -431, 830, 545, -246]
# Expected min: -879 	Result min: -879
# Expected max: 931 	Result max: 931
# Test passed
#
# #72 test (currently passed: 72/100)
# Test values: [-856, -465, 793]
# Expected min: -856 	Result min: -856
# Expected max: 793 	Result max: 793
# Test passed
#
# #73 test (currently passed: 73/100)
# Test values: [594, 978, -11, -149, 706, 363, -815, -367, -318, -29, -399, 709, -918, 897, 98, -918, 807, 879, 472, 797]
# Expected min: -918 	Result min: -918
# Expected max: 978 	Result max: 978
# Test passed
#
# #74 test (currently passed: 74/100)
# Test values: [329, -248, 249, 311]
# Expected min: -248 	Result min: -248
# Expected max: 329 	Result max: 329
# Test passed
#
# #75 test (currently passed: 75/100)
# Test values: [-352, -971, 162, -174, -280, -746, 775, -109, 930, -53, -479, -116, -987]
# Expected min: -987 	Result min: -987
# Expected max: 930 	Result max: 930
# Test passed
#
# #76 test (currently passed: 76/100)
# Test values: [-831, -555, -474, -978, 784]
# Expected min: -978 	Result min: -978
# Expected max: 784 	Result max: 784
# Test passed
#
# #77 test (currently passed: 77/100)
# Test values: [-311, 762, 113, -546]
# Expected min: -546 	Result min: -546
# Expected max: 762 	Result max: 762
# Test passed
#
# #78 test (currently passed: 78/100)
# Test values: [784, -712, 221, 119, -224, 185, 992, 231, -484, 749, 283, -445, 332, 543, 327, 468, -216, 143, 752, -850]
# Expected min: -850 	Result min: -850
# Expected max: 992 	Result max: 992
# Test passed
#
# #79 test (currently passed: 79/100)
# Test values: [-724, -385, 517, 85, -403, -277, 86, 396, -120, -856, 729]
# Expected min: -856 	Result min: -856
# Expected max: 729 	Result max: 729
# Test passed
#
# #80 test (currently passed: 80/100)
# Test values: [217, 296, -581, 955, -948, 717, -995, 49, -183, 395, -763, 865, -353, -639, 263, 540, -502, -778, -283]
# Expected min: -995 	Result min: -995
# Expected max: 955 	Result max: 955
# Test passed
#
# #81 test (currently passed: 81/100)
# Test values: [-462, -975, -108, 912, 800, 170, -983, -66, 673, -758, 690, -280, -199, 146, -985, -20, -71, -564]
# Expected min: -985 	Result min: -985
# Expected max: 912 	Result max: 912
# Test passed
#
# #82 test (currently passed: 82/100)
# Test values: [-47, -500, -46, 152, 685, 959, 484, 416, -719, -476, 56, 743, 116, -408, 685, 305, 770, 302]
# Expected min: -719 	Result min: -719
# Expected max: 959 	Result max: 959
# Test passed
#
# #83 test (currently passed: 83/100)
# Test values: [639, 605, -126, 11, 755, -772, 507]
# Expected min: -772 	Result min: -772
# Expected max: 755 	Result max: 755
# Test passed
#
# #84 test (currently passed: 84/100)
# Test values: [-721, -710, 428, 723]
# Expected min: -721 	Result min: -721
# Expected max: 723 	Result max: 723
# Test passed
#
# #85 test (currently passed: 85/100)
# Test values: [-478, -760]
# Expected min: -760 	Result min: -760
# Expected max: -478 	Result max: -478
# Test passed
#
# #86 test (currently passed: 86/100)
# Test values: [-545, 626, 669, 346, 268, 212, -542, 775, 577]
# Expected min: -545 	Result min: -545
# Expected max: 775 	Result max: 775
# Test passed
#
# #87 test (currently passed: 87/100)
# Test values: [399, -84, 865, 936, -79, -833, 254, -872, -785, -169, 969, 5, 256, 149, 93, 10, 583, 347]
# Expected min: -872 	Result min: -872
# Expected max: 969 	Result max: 969
# Test passed
#
# #88 test (currently passed: 88/100)
# Test values: [137, 836, -273, 67, -142, 295, 525, 73, -329, -570, 41, -597, -317, -566, 655, 16]
# Expected min: -597 	Result min: -597
# Expected max: 836 	Result max: 836
# Test passed
#
# #89 test (currently passed: 89/100)
# Test values: [163, 563, 862, -460, 913, 408, 237, -466, 481, -364]
# Expected min: -466 	Result min: -466
# Expected max: 913 	Result max: 913
# Test passed
#
# #90 test (currently passed: 90/100)
# Test values: [-171, 231, 528, 140, -864, -237]
# Expected min: -864 	Result min: -864
# Expected max: 528 	Result max: 528
# Test passed
#
# #91 test (currently passed: 91/100)
# Test values: [-163, -396, 345, -711, -556, 985, -139, 178, 109, -749, 739, 576, -34, 400, -631, 93, -543, 163, -54]
# Expected min: -749 	Result min: -749
# Expected max: 985 	Result max: 985
# Test passed
#
# #92 test (currently passed: 92/100)
# Test values: [-303, 317, -405, -332, -88, 903, -497, 845, -190, 341, -773, 318, 1]
# Expected min: -773 	Result min: -773
# Expected max: 903 	Result max: 903
# Test passed
#
# #93 test (currently passed: 93/100)
# Test values: [974, -898, -589, 213, 714, -506]
# Expected min: -898 	Result min: -898
# Expected max: 974 	Result max: 974
# Test passed
#
# #94 test (currently passed: 94/100)
# Test values: [-503, 761, 103, 956, -501, 209, -384, -460, 343, -85, 214, 203, -391, -46, 513, 373, -717, -544, -60]
# Expected min: -717 	Result min: -717
# Expected max: 956 	Result max: 956
# Test passed
#
# #95 test (currently passed: 95/100)
# Test values: [382, -960, 978, -759, 53]
# Expected min: -960 	Result min: -960
# Expected max: 978 	Result max: 978
# Test passed
#
# #96 test (currently passed: 96/100)
# Test values: [466, 534, -237, -442, -284, -155, -573, 733, 904, -89, -889, 727, -633, 317, -65, -147]
# Expected min: -889 	Result min: -889
# Expected max: 904 	Result max: 904
# Test passed
#
# #97 test (currently passed: 97/100)
# Test values: [864, 919, 631, 720, -233, 826, -706, -394, -333]
# Expected min: -706 	Result min: -706
# Expected max: 919 	Result max: 919
# Test passed
#
# #98 test (currently passed: 98/100)
# Test values: [-544, -857, 88, 13, -848, 487, 408, -584, 791, 62, 717]
# Expected min: -857 	Result min: -857
# Expected max: 791 	Result max: 791
# Test passed
#
# #99 test (currently passed: 99/100)
# Test values: [921, -435, -160, -159, -38, 596, 19, -54, -649, -778, 665, -828]
# Expected min: -828 	Result min: -828
# Expected max: 921 	Result max: 921
# Test passed
#
# #100 test (currently passed: 100/100)
# Test values: [-739, 663, -53, -389, 990, -385, -668, 105, -129, 28, 418, -618, 435, 399, -965, 817, -486]
# Expected min: -965 	Result min: -965
# Expected max: 990 	Result max: 990
# Test passed
#
# Total tests passed: 100/100
# This algorithm is correct

# %% [markdown]
# #### II wersja (bez użycia funkcji $ min $ oraz $ max $)

# %%
def minmax(arr):
    global_min = global_max = arr[-1]
    
    for i in range(0, len(arr)-1, 2):
        if arr[i] > arr[i+1]:
            if arr[i] > global_max:   global_max = arr[i]
            if arr[i+1] < global_min: global_min = arr[i+1]
        else:
            if arr[i+1] > global_max: global_max = arr[i+1]
            if arr[i] < global_min:   global_min = arr[i]
    return global_min, global_max

# %% [markdown]
# ###### Przykładowy test

# %%
test_minmax(minmax, reps=100)
# Out:
# #1 test (currently passed: 1/100)
# Test values: [885, -999, 201, -140, 864, 254, -128, -696, 413, -716, -512]
# Expected min: -999 	Result min: -999
# Expected max: 885 	Result max: 885
# Test passed
#
# #2 test (currently passed: 2/100)
# Test values: [-670, 163, 473, 637, 382]
# Expected min: -670 	Result min: -670
# Expected max: 637 	Result max: 637
# Test passed
#
# #3 test (currently passed: 3/100)
# Test values: [775, 93, 937, -211, 219, 103, -436, -64, 333, 713, 819, 453, 776, -672, 227, 246, 296, -213]
# Expected min: -672 	Result min: -672
# Expected max: 937 	Result max: 937
# Test passed
#
# #4 test (currently passed: 4/100)
# Test values: [-564, 523, 813, -871, -616, -212, 142, -142, -490, 988, -282]
# Expected min: -871 	Result min: -871
# Expected max: 988 	Result max: 988
# Test passed
#
# #5 test (currently passed: 5/100)
# Test values: [-190, 800, -804, 41, 16, 527, 278, -451, -712]
# Expected min: -804 	Result min: -804
# Expected max: 800 	Result max: 800
# Test passed
#
# #6 test (currently passed: 6/100)
# Test values: [284, 178, 680, -74, -879, 954, 132, -832, -593]
# Expected min: -879 	Result min: -879
# Expected max: 954 	Result max: 954
# Test passed
#
# #7 test (currently passed: 7/100)
# Test values: [380, -320, -202, 486, -967, 689, -336, 404, -18, 836]
# Expected min: -967 	Result min: -967
# Expected max: 836 	Result max: 836
# Test passed
#
# #8 test (currently passed: 8/100)
# Test values: [-158, -826, -343, -548]
# Expected min: -826 	Result min: -826
# Expected max: -158 	Result max: -158
# Test passed
#
# #9 test (currently passed: 9/100)
# Test values: [20, 437, 633, -991, -989, -552, -554, -487, -690, -894, 538, 234, 543, -231, 713, 952, 55, 710]
# Expected min: -991 	Result min: -991
# Expected max: 952 	Result max: 952
# Test passed
#
# #10 test (currently passed: 10/100)
# Test values: [-556, 123, -358, 848, -452, -625, 146, 321, 866, -990, -249, -140, 1000, 91]
# Expected min: -990 	Result min: -990
# Expected max: 1000 	Result max: 1000
# Test passed
#
# #11 test (currently passed: 11/100)
# Test values: [502, 93, -997, -62, -828, 772, 993, 387, 19, -370, -939, -981, -26]
# Expected min: -997 	Result min: -997
# Expected max: 993 	Result max: 993
# Test passed
#
# #12 test (currently passed: 12/100)
# Test values: [364, 636, -667, -497, -529, 694, 162, -670, -976]
# Expected min: -976 	Result min: -976
# Expected max: 694 	Result max: 694
# Test passed
#
# #13 test (currently passed: 13/100)
# Test values: [865, 248, 898, 791, 664, 65, 950, 613, -275, 116, -825, 417, 14, -225, 102, 762, -970, -141, 178, 343]
# Expected min: -970 	Result min: -970
# Expected max: 950 	Result max: 950
# Test passed
#
# #14 test (currently passed: 14/100)
# Test values: [-76, 805, -757, -861, 796, 671, -434, -229, -896, 261, -148, 941]
# Expected min: -896 	Result min: -896
# Expected max: 941 	Result max: 941
# Test passed
#
# #15 test (currently passed: 15/100)
# Test values: [246, 216, 306, -4, -337, 570, 849, 104, 826]
# Expected min: -337 	Result min: -337
# Expected max: 849 	Result max: 849
# Test passed
#
# #16 test (currently passed: 16/100)
# Test values: [981, 961, 476, -157, -715, 979]
# Expected min: -715 	Result min: -715
# Expected max: 981 	Result max: 981
# Test passed
#
# #17 test (currently passed: 17/100)
# Test values: [448, -232, -78, 255, 540, 331, -39, -95, -75, -376, -237, -628, 776, 698, -26, 615, -763, -323, -452]
# Expected min: -763 	Result min: -763
# Expected max: 776 	Result max: 776
# Test passed
#
# #18 test (currently passed: 18/100)
# Test values: [-642, 476, -520, 329, -853, 113, -190, -561, 967]
# Expected min: -853 	Result min: -853
# Expected max: 967 	Result max: 967
# Test passed
#
# #19 test (currently passed: 19/100)
# Test values: [-462, 603, 419, 514, 547, 349, 30, 874, -463, -995, -754, -860, 377, 239, 911, -672, -658]
# Expected min: -995 	Result min: -995
# Expected max: 911 	Result max: 911
# Test passed
#
# #20 test (currently passed: 20/100)
# Test values: [823, 808, -513, -146, -740, -482, 754, 255, -290, 393, -635, -982, -995, -393, 803, 533, -602, 492, -564]
# Expected min: -995 	Result min: -995
# Expected max: 823 	Result max: 823
# Test passed
#
# #21 test (currently passed: 21/100)
# Test values: [-818, 473, 460, -259, -663, -343, 831]
# Expected min: -818 	Result min: -818
# Expected max: 831 	Result max: 831
# Test passed
#
# #22 test (currently passed: 22/100)
# Test values: [11, -164, 920, 229, -38, -748, -33, 261, 468, -747, 650, -723, -789, 850, 956]
# Expected min: -789 	Result min: -789
# Expected max: 956 	Result max: 956
# Test passed
#
# #23 test (currently passed: 23/100)
# Test values: [-337, -359, 755, -278, -65, -814, 404, 383, -903, -995, 565, 544, -72, 295, -539, -773, -720]
# Expected min: -995 	Result min: -995
# Expected max: 755 	Result max: 755
# Test passed
#
# #24 test (currently passed: 24/100)
# Test values: [-444, 526, -297, -698, 98]
# Expected min: -698 	Result min: -698
# Expected max: 526 	Result max: 526
# Test passed
#
# #25 test (currently passed: 25/100)
# Test values: [-681, 405, -626, -96, -722, -949, -98]
# Expected min: -949 	Result min: -949
# Expected max: 405 	Result max: 405
# Test passed
#
# #26 test (currently passed: 26/100)
# Test values: [74, -716, 933, -445, -824, 66, -653, -802, 282, -7, 830, 194, 38, -4, -476, -497, 862, 488, -4]
# Expected min: -824 	Result min: -824
# Expected max: 933 	Result max: 933
# Test passed
#
# #27 test (currently passed: 27/100)
# Test values: [409, -252, 224]
# Expected min: -252 	Result min: -252
# Expected max: 409 	Result max: 409
# Test passed
#
# #28 test (currently passed: 28/100)
# Test values: [744, -721, 719, 98, -430, -652, 879, 111, 33, -626, -797, -159, -415, 318, 591, -781, 435, -233, -297]
# Expected min: -797 	Result min: -797
# Expected max: 879 	Result max: 879
# Test passed
#
# #29 test (currently passed: 29/100)
# Test values: [-413, 27, -594, 510, -172, 161, -338, 452, 621]
# Expected min: -594 	Result min: -594
# Expected max: 621 	Result max: 621
# Test passed
#
# #30 test (currently passed: 30/100)
# Test values: [-148, 337, 919, 432, -277, -797, 186, 107, -833, 758, -483, -691, -25, 463, -914]
# Expected min: -914 	Result min: -914
# Expected max: 919 	Result max: 919
# Test passed
#
# #31 test (currently passed: 31/100)
# Test values: [209, 995, 898, -705, 68, -576, -21]
# Expected min: -705 	Result min: -705
# Expected max: 995 	Result max: 995
# Test passed
#
# #32 test (currently passed: 32/100)
# Test values: [-689, -928, 264]
# Expected min: -928 	Result min: -928
# Expected max: 264 	Result max: 264
# Test passed
#
# #33 test (currently passed: 33/100)
# Test values: [580, 860, 319, -831, -627, -835, -207, 802, 779]
# Expected min: -835 	Result min: -835
# Expected max: 860 	Result max: 860
# Test passed
#
# #34 test (currently passed: 34/100)
# Test values: [-719, -459, -37, -372, 220, 188, -82, 5, 494, -808, 11, 258, -415, 690]
# Expected min: -808 	Result min: -808
# Expected max: 690 	Result max: 690
# Test passed
#
# #35 test (currently passed: 35/100)
# Test values: [-655, -556, 134]
# Expected min: -655 	Result min: -655
# Expected max: 134 	Result max: 134
# Test passed
#
# #36 test (currently passed: 36/100)
# Test values: [514, -284, 155, 509]
# Expected min: -284 	Result min: -284
# Expected max: 514 	Result max: 514
# Test passed
#
# #37 test (currently passed: 37/100)
# Test values: [-383, 852, -402, -925, -800, -722, 311, 681, 409, 4, -39, -831, -409]
# Expected min: -925 	Result min: -925
# Expected max: 852 	Result max: 852
# Test passed
#
# #38 test (currently passed: 38/100)
# Test values: [-436, 57, 482, 564, 57, 30, -933, 384, 559, 348, 683]
# Expected min: -933 	Result min: -933
# Expected max: 683 	Result max: 683
# Test passed
#
# #39 test (currently passed: 39/100)
# Test values: [105, 91, -160, 613, 407, 631, -1000, -423]
# Expected min: -1000 	Result min: -1000
# Expected max: 631 	Result max: 631
# Test passed
#
# #40 test (currently passed: 40/100)
# Test values: [-617, -978, -516, 678, -680, 68, 800, 783, 219, -64, -201, 236, 752, -258, -272, 757, 184, -564]
# Expected min: -978 	Result min: -978
# Expected max: 800 	Result max: 800
# Test passed
#
# #41 test (currently passed: 41/100)
# Test values: [376, -864, -979, -860, -549, 168, -711, -607, 686, 720, -29, 502, 843, 52, -923, 263]
# Expected min: -979 	Result min: -979
# Expected max: 843 	Result max: 843
# Test passed
#
# #42 test (currently passed: 42/100)
# Test values: [455, 509, -846, -362, -632, -212, -242, 51, 259, -626, -144, -228, 67, 751, 251, -945, 741, -421, 334]
# Expected min: -945 	Result min: -945
# Expected max: 751 	Result max: 751
# Test passed
#
# #43 test (currently passed: 43/100)
# Test values: [-506, -71, 307, -349, -499, -567, -578, 629, -894, 906, -900, -404, 692, -489, -76, 272, 72]
# Expected min: -900 	Result min: -900
# Expected max: 906 	Result max: 906
# Test passed
#
# #44 test (currently passed: 44/100)
# Test values: [687, 152, 139, -208, -109, -383, -277, 273, 347, 317, -542]
# Expected min: -542 	Result min: -542
# Expected max: 687 	Result max: 687
# Test passed
#
# #45 test (currently passed: 45/100)
# Test values: [857, -113, 381]
# Expected min: -113 	Result min: -113
# Expected max: 857 	Result max: 857
# Test passed
#
# #46 test (currently passed: 46/100)
# Test values: [518, 526, -227, -609, 595, 498]
# Expected min: -609 	Result min: -609
# Expected max: 595 	Result max: 595
# Test passed
#
# #47 test (currently passed: 47/100)
# Test values: [648, -921, 154, 661, -771, -575, 708, -271, -972, -501, 822, -986, 975, 341, 11, -355]
# Expected min: -986 	Result min: -986
# Expected max: 975 	Result max: 975
# Test passed
#
# #48 test (currently passed: 48/100)
# Test values: [-847, 161, 640, 445]
# Expected min: -847 	Result min: -847
# Expected max: 640 	Result max: 640
# Test passed
#
# #49 test (currently passed: 49/100)
# Test values: [749, 758, 308, 315, 121, -15, 567, 117, -302, -408, -909, -157, -595, 472, -883, -715]
# Expected min: -909 	Result min: -909
# Expected max: 758 	Result max: 758
# Test passed
#
# #50 test (currently passed: 50/100)
# Test values: [-736, -436]
# Expected min: -736 	Result min: -736
# Expected max: -436 	Result max: -436
# Test passed
#
# #51 test (currently passed: 51/100)
# Test values: [839, 671, -528, 22]
# Expected min: -528 	Result min: -528
# Expected max: 839 	Result max: 839
# Test passed
#
# #52 test (currently passed: 52/100)
# Test values: [-89, -798, 293, 444, -953, 511, -166, -313, -403, 462, -391, 484, -59, 891, -414, 458, -595, -756]
# Expected min: -953 	Result min: -953
# Expected max: 891 	Result max: 891
# Test passed
#
# #53 test (currently passed: 53/100)
# Test values: [183, -224, 77, 806, 409, 253, 917, -895, 811, -149]
# Expected min: -895 	Result min: -895
# Expected max: 917 	Result max: 917
# Test passed
#
# #54 test (currently passed: 54/100)
# Test values: [-90, 425, -825, 425, -755, -35]
# Expected min: -825 	Result min: -825
# Expected max: 425 	Result max: 425
# Test passed
#
# #55 test (currently passed: 55/100)
# Test values: [-697, 502, -380, 546, -461, 763, -912]
# Expected min: -912 	Result min: -912
# Expected max: 763 	Result max: 763
# Test passed
#
# #56 test (currently passed: 56/100)
# Test values: [67, 324, -270, -159, -142, -72, -754, -826, -973, 968, 984, -772, -304, -838, -566]
# Expected min: -973 	Result min: -973
# Expected max: 984 	Result max: 984
# Test passed
#
# #57 test (currently passed: 57/100)
# Test values: [792, -685, -824, -309, 406, -770, -786, -996, -940, 70, -897, -63, -487, 664, 921, -702]
# Expected min: -996 	Result min: -996
# Expected max: 921 	Result max: 921
# Test passed
#
# #58 test (currently passed: 58/100)
# Test values: [-532, -678, -799, 199, 444, -403, 122, -62, -848, 517, -920]
# Expected min: -920 	Result min: -920
# Expected max: 517 	Result max: 517
# Test passed
#
# #59 test (currently passed: 59/100)
# Test values: [-202, 777, -473, -734, -227]
# Expected min: -734 	Result min: -734
# Expected max: 777 	Result max: 777
# Test passed
#
# #60 test (currently passed: 60/100)
# Test values: [57, 286, -713, 58, 3]
# Expected min: -713 	Result min: -713
# Expected max: 286 	Result max: 286
# Test passed
#
# #61 test (currently passed: 61/100)
# Test values: [-361, 482, -48, -896, -51]
# Expected min: -896 	Result min: -896
# Expected max: 482 	Result max: 482
# Test passed
#
# #62 test (currently passed: 62/100)
# Test values: [-733, 313, 86, 456, -795, -434]
# Expected min: -795 	Result min: -795
# Expected max: 456 	Result max: 456
# Test passed
#
# #63 test (currently passed: 63/100)
# Test values: [-384, 601, 546, -398, 518, 402, -252, 903, 977, -713, -594, 865, -467, 511, -993, -958, 740]
# Expected min: -993 	Result min: -993
# Expected max: 977 	Result max: 977
# Test passed
#
# #64 test (currently passed: 64/100)
# Test values: [39, -48, -606, -543, 655, -566, -615, -938, 354, -958, 606, 115, -901, -580, 88, -536, -386, -567, -309, 690]
# Expected min: -958 	Result min: -958
# Expected max: 690 	Result max: 690
# Test passed
#
# #65 test (currently passed: 65/100)
# Test values: [-634, -982]
# Expected min: -982 	Result min: -982
# Expected max: -634 	Result max: -634
# Test passed
#
# #66 test (currently passed: 66/100)
# Test values: [-407, -791, -370]
# Expected min: -791 	Result min: -791
# Expected max: -370 	Result max: -370
# Test passed
#
# #67 test (currently passed: 67/100)
# Test values: [-486, 361, 782, -511]
# Expected min: -511 	Result min: -511
# Expected max: 782 	Result max: 782
# Test passed
#
# #68 test (currently passed: 68/100)
# Test values: [-984, 510, 395, -156, -295, -211]
# Expected min: -984 	Result min: -984
# Expected max: 510 	Result max: 510
# Test passed
#
# #69 test (currently passed: 69/100)
# Test values: [123, -11, 10, -475, -677, -483, 116, -236, 929, 492, -273, -803, -521, 720, -40, -143, 980, -449, 435]
# Expected min: -803 	Result min: -803
# Expected max: 980 	Result max: 980
# Test passed
#
# #70 test (currently passed: 70/100)
# Test values: [-775, -763, 210, -992, 162, -68, 528, 110, 71, -906, -751, -695, 872, -741, 748, 102, -875, 550, -346, -957]
# Expected min: -992 	Result min: -992
# Expected max: 872 	Result max: 872
# Test passed
#
# #71 test (currently passed: 71/100)
# Test values: [103, -776, 990, -901, 24, 809]
# Expected min: -901 	Result min: -901
# Expected max: 990 	Result max: 990
# Test passed
#
# #72 test (currently passed: 72/100)
# Test values: [-943, -566, 48, -695, -217, -791, -297, -898, 863]
# Expected min: -943 	Result min: -943
# Expected max: 863 	Result max: 863
# Test passed
#
# #73 test (currently passed: 73/100)
# Test values: [393, 894]
# Expected min: 393 	Result min: 393
# Expected max: 894 	Result max: 894
# Test passed
#
# #74 test (currently passed: 74/100)
# Test values: [-407, -259, 304, -806, -214, 253, -770, -772, -41]
# Expected min: -806 	Result min: -806
# Expected max: 304 	Result max: 304
# Test passed
#
# #75 test (currently passed: 75/100)
# Test values: [199, 991, -38, 222, -397, -172, 336, 859, -595, 456, -992, -716, 749, -201, 462, -756, -187, -69, 254, -911]
# Expected min: -992 	Result min: -992
# Expected max: 991 	Result max: 991
# Test passed
#
# #76 test (currently passed: 76/100)
# Test values: [-652, 507, -241, -798, 555, 458, -75, 242, -219, 666, 864, 413, 79, 660, 670, -908]
# Expected min: -908 	Result min: -908
# Expected max: 864 	Result max: 864
# Test passed
#
# #77 test (currently passed: 77/100)
# Test values: [851, -366, -825, 262, 321, -748, 716, -673, 639, 700, -221, -267]
# Expected min: -825 	Result min: -825
# Expected max: 851 	Result max: 851
# Test passed
#
# #78 test (currently passed: 78/100)
# Test values: [749, 859, 660, -888, 908, -921, 617, 151, 432, 788, -323, -705, -540, -433, 890, -673]
# Expected min: -921 	Result min: -921
# Expected max: 908 	Result max: 908
# Test passed
#
# #79 test (currently passed: 79/100)
# Test values: [651, -193, -228, -686, -495, -220, -55, -986]
# Expected min: -986 	Result min: -986
# Expected max: 651 	Result max: 651
# Test passed
#
# #80 test (currently passed: 80/100)
# Test values: [-40, 895, -483, 168, 682, 492, 631, -32, -305, 976, -479, -672]
# Expected min: -672 	Result min: -672
# Expected max: 976 	Result max: 976
# Test passed
#
# #81 test (currently passed: 81/100)
# Test values: [911, -501, -428, -314, 204]
# Expected min: -501 	Result min: -501
# Expected max: 911 	Result max: 911
# Test passed
#
# #82 test (currently passed: 82/100)
# Test values: [-161, -934, 866, 479, 685, 844, -330, 787, -131, 937, -58, -75, 680, -832]
# Expected min: -934 	Result min: -934
# Expected max: 937 	Result max: 937
# Test passed
#
# #83 test (currently passed: 83/100)
# Test values: [-68, 822, 508]
# Expected min: -68 	Result min: -68
# Expected max: 822 	Result max: 822
# Test passed
#
# #84 test (currently passed: 84/100)
# Test values: [-541, 962, -118, -574]
# Expected min: -574 	Result min: -574
# Expected max: 962 	Result max: 962
# Test passed
#
# #85 test (currently passed: 85/100)
# Test values: [905, 789, 266, -648, 464, 441, 473, 175, -493, 837, -134, 882, -320, -74, 740]
# Expected min: -648 	Result min: -648
# Expected max: 905 	Result max: 905
# Test passed
#
# #86 test (currently passed: 86/100)
# Test values: [534, 938, -489]
# Expected min: -489 	Result min: -489
# Expected max: 938 	Result max: 938
# Test passed
#
# #87 test (currently passed: 87/100)
# Test values: [413, -222, -843, 844]
# Expected min: -843 	Result min: -843
# Expected max: 844 	Result max: 844
# Test passed
#
# #88 test (currently passed: 88/100)
# Test values: [568, 275, 829, 678, 737, 902, -378, 293, 318]
# Expected min: -378 	Result min: -378
# Expected max: 902 	Result max: 902
# Test passed
#
# #89 test (currently passed: 89/100)
# Test values: [-33, -111, -236, 164, -983, 156, 381, -221, -232, 530]
# Expected min: -983 	Result min: -983
# Expected max: 530 	Result max: 530
# Test passed
#
# #90 test (currently passed: 90/100)
# Test values: [675, 213, -167, -568, -907, 399, -208, 431, -433, 913, -605, 852, 156, 98, -112]
# Expected min: -907 	Result min: -907
# Expected max: 913 	Result max: 913
# Test passed
#
# #91 test (currently passed: 91/100)
# Test values: [-744, 130, -178, -315, 240, -770, 27, 571, -523]
# Expected min: -770 	Result min: -770
# Expected max: 571 	Result max: 571
# Test passed
#
# #92 test (currently passed: 92/100)
# Test values: [-126, 323, 596, 272, 851, -406, -377, 341, 909, -662, 951, -732, -540, 182]
# Expected min: -732 	Result min: -732
# Expected max: 951 	Result max: 951
# Test passed
#
# #93 test (currently passed: 93/100)
# Test values: [-112, 421, -424, 943, 140, 337, -163, -888, 703, -928, -96, 507, 540, -923, 755, 851, 110, 654, 871, 967]
# Expected min: -928 	Result min: -928
# Expected max: 967 	Result max: 967
# Test passed
#
# #94 test (currently passed: 94/100)
# Test values: [562, 877, -488, 255, 186, -548, 296, -229, -965, -327, -264, 872, -828, 511, 143, -857, -451]
# Expected min: -965 	Result min: -965
# Expected max: 877 	Result max: 877
# Test passed
#
# #95 test (currently passed: 95/100)
# Test values: [-697, 891, -909, -588, -700, 725, -847, -681, 490]
# Expected min: -909 	Result min: -909
# Expected max: 891 	Result max: 891
# Test passed
#
# #96 test (currently passed: 96/100)
# Test values: [-180, -657, 118, 960, -681, 427, 362, 816]
# Expected min: -681 	Result min: -681
# Expected max: 960 	Result max: 960
# Test passed
#
# #97 test (currently passed: 97/100)
# Test values: [-479, 280, -328, -653, 771, -96, -740, 658, 52, 363, 303, -79, 621, -769, -782, 329, -873, 256]
# Expected min: -873 	Result min: -873
# Expected max: 771 	Result max: 771
# Test passed
#
# #98 test (currently passed: 98/100)
# Test values: [-592]
# Expected min: -592 	Result min: -592
# Expected max: -592 	Result max: -592
# Test passed
#
# #99 test (currently passed: 99/100)
# Test values: [-4, -587, -723]
# Expected min: -723 	Result min: -723
# Expected max: -4 	Result max: -4
# Test passed
#
# #100 test (currently passed: 100/100)
# Test values: [-615, -870, 221, -157, 170, 316, -714, 278, 252, 406, -777, -380, 522, -32, -175, -963, -186, -351, -372]
# Expected min: -963 	Result min: -963
# Expected max: 522 	Result max: 522
# Test passed
#
# Total tests passed: 100/100
# This algorithm is correct

# %% [markdown]
# ### Tutaj rozwiązanie, które nie spełnia warunku na $ \frac{3}{2}n $ porównań ($ 2n $ porównań)

# %% [markdown]
# #### I wersja (z użyciem funkcji $ min $ oraz $ max $)

# %% [markdown]
# Nieco wolniejsze od II wersji, bo jest ten sam problem, co w przypadku wcześniejszego algorytmu. Tu dochodzi jeszcze kwestia taka, że jeżeli dana wartość będzie mniejsza niż $ global\_min $ i tak jest jeszcze raz sprawdzana przez funkcję $ max $ i porównywana z $ global\_max $, mimo że wartość największa nie może być mniejsza od wartości najmniejszej. W tej sytuacji tym bardziej warto zastosować II wersję algorytmu.

# %%
def minmax(arr):
    global_min = global_max = arr[0]
    for i in range(1, len(arr)):
        global_min = min(global_min, arr[i])
        global_max = max(global_max, arr[i])
    return global_min, global_max

# %% [markdown]
# ###### Przykładowy test

# %%
test_minmax(minmax, reps=100)
# Out:
# #1 test (currently passed: 1/100)
# Test values: [-390, 60, 85, 508, -722, -872, -55, -892, -122, 352, 910, 660, -755, -527]
# Expected min: -892 	Result min: -892
# Expected max: 910 	Result max: 910
# Test passed
#
# #2 test (currently passed: 2/100)
# Test values: [969, -94, 178, 401, 161, -526]
# Expected min: -526 	Result min: -526
# Expected max: 969 	Result max: 969
# Test passed
#
# #3 test (currently passed: 3/100)
# Test values: [756]
# Expected min: 756 	Result min: 756
# Expected max: 756 	Result max: 756
# Test passed
#
# #4 test (currently passed: 4/100)
# Test values: [-167, -351, 499, 680, -474, -345, -785, 705, -674, -870, -843, 545, -205, 160, 476, -992, -574, 588, 352, 861]
# Expected min: -992 	Result min: -992
# Expected max: 861 	Result max: 861
# Test passed
#
# #5 test (currently passed: 5/100)
# Test values: [463, -411, -323, -662, -135, -467]
# Expected min: -662 	Result min: -662
# Expected max: 463 	Result max: 463
# Test passed
#
# #6 test (currently passed: 6/100)
# Test values: [207, 7, 105, -757, -670, -339, -401, 623, 92, -745, -327, -400, -908]
# Expected min: -908 	Result min: -908
# Expected max: 623 	Result max: 623
# Test passed
#
# #7 test (currently passed: 7/100)
# Test values: [344, 455, 506, -632, 31, 690, -986, 706, 224, -160, 485, 49, 516, 101, 235, 150]
# Expected min: -986 	Result min: -986
# Expected max: 706 	Result max: 706
# Test passed
#
# #8 test (currently passed: 8/100)
# Test values: [-178, -534, -773, 760, -123, 631, 271, -860, -767, -76, -526, 977, 557, 5, -478, 95, 941, -651]
# Expected min: -860 	Result min: -860
# Expected max: 977 	Result max: 977
# Test passed
#
# #9 test (currently passed: 9/100)
# Test values: [635, 237, 127, 47, -266, -529, 277, 624]
# Expected min: -529 	Result min: -529
# Expected max: 635 	Result max: 635
# Test passed
#
# #10 test (currently passed: 10/100)
# Test values: [-484, 580, -155, 1, -531, 679, -900, 593, -203, -265, 187, 484, -27, -902, -840, 909, -159, -73, 902]
# Expected min: -902 	Result min: -902
# Expected max: 909 	Result max: 909
# Test passed
#
# #11 test (currently passed: 11/100)
# Test values: [-497, -823, -567, 140, -541, 841, -147, -996]
# Expected min: -996 	Result min: -996
# Expected max: 841 	Result max: 841
# Test passed
#
# #12 test (currently passed: 12/100)
# Test values: [-82, -900, -996, 40, -889, -179, 278, 812, -4, -917]
# Expected min: -996 	Result min: -996
# Expected max: 812 	Result max: 812
# Test passed
#
# #13 test (currently passed: 13/100)
# Test values: [-792, -301, -197, -489, -670, -14, 217, 272, -959]
# Expected min: -959 	Result min: -959
# Expected max: 272 	Result max: 272
# Test passed
#
# #14 test (currently passed: 14/100)
# Test values: [314, -494, 931, 724, 578, 888, 774, 447, -868, -483, -402, 748, -949]
# Expected min: -949 	Result min: -949
# Expected max: 931 	Result max: 931
# Test passed
#
# #15 test (currently passed: 15/100)
# Test values: [-589, -441, 84, 803, 513, -152, -857, 100, -929, -813, 930, -372, 167, -935]
# Expected min: -935 	Result min: -935
# Expected max: 930 	Result max: 930
# Test passed
#
# #16 test (currently passed: 16/100)
# Test values: [-433, -996, -916, -18, -40, -58]
# Expected min: -996 	Result min: -996
# Expected max: -18 	Result max: -18
# Test passed
#
# #17 test (currently passed: 17/100)
# Test values: [-161, -201, -179, 689, -340, 969, 566, -614, -212, -276, -131]
# Expected min: -614 	Result min: -614
# Expected max: 969 	Result max: 969
# Test passed
#
# #18 test (currently passed: 18/100)
# Test values: [655, -239, 401, -825, 455, -719, 877, 165, 987, -491, -721, -898, 965, -724, -872, 122]
# Expected min: -898 	Result min: -898
# Expected max: 987 	Result max: 987
# Test passed
#
# #19 test (currently passed: 19/100)
# Test values: [831, -102, 357, -644, -583, 766, -219, 476, -419, -430, 921, 352, 577, 454, -187, -779, -131, -704]
# Expected min: -779 	Result min: -779
# Expected max: 921 	Result max: 921
# Test passed
#
# #20 test (currently passed: 20/100)
# Test values: [-694, 238, -358, 145, -920, 924, -331, 728, 297, 553, 574, -142, 821, -211, -598, -413, -23, -728, -673]
# Expected min: -920 	Result min: -920
# Expected max: 924 	Result max: 924
# Test passed
#
# #21 test (currently passed: 21/100)
# Test values: [747, 632, -339, 85, 851, -440, -861, 105, -665, -773, -507, -655]
# Expected min: -861 	Result min: -861
# Expected max: 851 	Result max: 851
# Test passed
#
# #22 test (currently passed: 22/100)
# Test values: [661, 431, -554, -898, -33, 208, -736, -830, -243, -89, 706, -655, -835, 745, 1, -450, 278]
# Expected min: -898 	Result min: -898
# Expected max: 745 	Result max: 745
# Test passed
#
# #23 test (currently passed: 23/100)
# Test values: [-585, 758, 450, -764, 877, -953, -137, 805, -171, 570, 932, 318, 865, -857, 608, -844, 236, -827, -777, 382]
# Expected min: -953 	Result min: -953
# Expected max: 932 	Result max: 932
# Test passed
#
# #24 test (currently passed: 24/100)
# Test values: [62, 821, 739, 318, 662, -750]
# Expected min: -750 	Result min: -750
# Expected max: 821 	Result max: 821
# Test passed
#
# #25 test (currently passed: 25/100)
# Test values: [-215, -972, 706, -460, 226, -654, 19, -483, -811, -427, -514, 986, 218, 617, -968, -670, 222]
# Expected min: -972 	Result min: -972
# Expected max: 986 	Result max: 986
# Test passed
#
# #26 test (currently passed: 26/100)
# Test values: [-223, 321, -148]
# Expected min: -223 	Result min: -223
# Expected max: 321 	Result max: 321
# Test passed
#
# #27 test (currently passed: 27/100)
# Test values: [-987, -790, -54, -717, -159, 532, -372, -923, 837, 937, -323, 657, -539, -511, 956]
# Expected min: -987 	Result min: -987
# Expected max: 956 	Result max: 956
# Test passed
#
# #28 test (currently passed: 28/100)
# Test values: [70, -18, 929, -841, -670, -874, 34, 378, -17, -886]
# Expected min: -886 	Result min: -886
# Expected max: 929 	Result max: 929
# Test passed
#
# #29 test (currently passed: 29/100)
# Test values: [151, 481, -663, -605, -505, -220, -873, 50, -411, -178, 997, -659, 587, 681, 324, -557, 723]
# Expected min: -873 	Result min: -873
# Expected max: 997 	Result max: 997
# Test passed
#
# #30 test (currently passed: 30/100)
# Test values: [749, 964, 619, -86, 635, 53, 446]
# Expected min: -86 	Result min: -86
# Expected max: 964 	Result max: 964
# Test passed
#
# #31 test (currently passed: 31/100)
# Test values: [-646, 572, 836, 866, 277, 2]
# Expected min: -646 	Result min: -646
# Expected max: 866 	Result max: 866
# Test passed
#
# #32 test (currently passed: 32/100)
# Test values: [305, 161]
# Expected min: 161 	Result min: 161
# Expected max: 305 	Result max: 305
# Test passed
#
# #33 test (currently passed: 33/100)
# Test values: [701, -176, 568, -839, -206, 490, -722, 163, -765, -957, 909]
# Expected min: -957 	Result min: -957
# Expected max: 909 	Result max: 909
# Test passed
#
# #34 test (currently passed: 34/100)
# Test values: [-56, -985, -787, 901, -427, -952, 724, -643, -946, -175]
# Expected min: -985 	Result min: -985
# Expected max: 901 	Result max: 901
# Test passed
#
# #35 test (currently passed: 35/100)
# Test values: [172, -955, 340, -263, 695, 785, 787, 8, -620, -653, -112, 3, 295]
# Expected min: -955 	Result min: -955
# Expected max: 787 	Result max: 787
# Test passed
#
# #36 test (currently passed: 36/100)
# Test values: [390, -270, 347, -265, -490, -420, 206, 464, -692, 653, 412]
# Expected min: -692 	Result min: -692
# Expected max: 653 	Result max: 653
# Test passed
#
# #37 test (currently passed: 37/100)
# Test values: [699, 857, -182, 461, 446, 756, -291, -916, 557, 133, -166, 892, -912]
# Expected min: -916 	Result min: -916
# Expected max: 892 	Result max: 892
# Test passed
#
# #38 test (currently passed: 38/100)
# Test values: [-287, 325, -418, -98, -888, 150, 81, -715, -523, -155, -122, 432, -623, 385, 664, -927]
# Expected min: -927 	Result min: -927
# Expected max: 664 	Result max: 664
# Test passed
#
# #39 test (currently passed: 39/100)
# Test values: [768, 796, 523, 349, -829, 532, 662, -795, -825, 57, 80, 304, -546, 372, 194, 335]
# Expected min: -829 	Result min: -829
# Expected max: 796 	Result max: 796
# Test passed
#
# #40 test (currently passed: 40/100)
# Test values: [265, -327, -235, -202, -748, -738, 73, 488, 354, 371]
# Expected min: -748 	Result min: -748
# Expected max: 488 	Result max: 488
# Test passed
#
# #41 test (currently passed: 41/100)
# Test values: [-260, 266, -233, 385, -821, 830, -393, -13, -803, -3, 730, 968, -88]
# Expected min: -821 	Result min: -821
# Expected max: 968 	Result max: 968
# Test passed
#
# #42 test (currently passed: 42/100)
# Test values: [672, -317, -412, -775, 210, -233, 626, 680, 65, 445, 706, 139, 822, -271, -100]
# Expected min: -775 	Result min: -775
# Expected max: 822 	Result max: 822
# Test passed
#
# #43 test (currently passed: 43/100)
# Test values: [-978, 173, 909, -263, 427, -250, 421, -140, -152, 402, -480, 36]
# Expected min: -978 	Result min: -978
# Expected max: 909 	Result max: 909
# Test passed
#
# #44 test (currently passed: 44/100)
# Test values: [-939, -6, -699, -827, 143, -309, 544, -403, 946, -50, 41]
# Expected min: -939 	Result min: -939
# Expected max: 946 	Result max: 946
# Test passed
#
# #45 test (currently passed: 45/100)
# Test values: [596, 159, -965, -68, 190, -934, -697, 733, -544, 694, -166, -616, 895, -366, -852, -648, -222]
# Expected min: -965 	Result min: -965
# Expected max: 895 	Result max: 895
# Test passed
#
# #46 test (currently passed: 46/100)
# Test values: [-976, 237, -137]
# Expected min: -976 	Result min: -976
# Expected max: 237 	Result max: 237
# Test passed
#
# #47 test (currently passed: 47/100)
# Test values: [-167, 789, 598, 866, -651, -619, -183, 789, -969, -395, 722, 627, -603, -789, -39, 39, -503]
# Expected min: -969 	Result min: -969
# Expected max: 866 	Result max: 866
# Test passed
#
# #48 test (currently passed: 48/100)
# Test values: [585, 282, -555, -643, 347, 178, -709, 616, 986, -567]
# Expected min: -709 	Result min: -709
# Expected max: 986 	Result max: 986
# Test passed
#
# #49 test (currently passed: 49/100)
# Test values: [-397, 87, 979, -157, -527, -407, 385, -978, 521, -205]
# Expected min: -978 	Result min: -978
# Expected max: 979 	Result max: 979
# Test passed
#
# #50 test (currently passed: 50/100)
# Test values: [289]
# Expected min: 289 	Result min: 289
# Expected max: 289 	Result max: 289
# Test passed
#
# #51 test (currently passed: 51/100)
# Test values: [-732, -986, -895, 681, 126, -676, -467, -471]
# Expected min: -986 	Result min: -986
# Expected max: 681 	Result max: 681
# Test passed
#
# #52 test (currently passed: 52/100)
# Test values: [-843, -972, 146, 390, -880, -955, 564, -1, -846, 985]
# Expected min: -972 	Result min: -972
# Expected max: 985 	Result max: 985
# Test passed
#
# #53 test (currently passed: 53/100)
# Test values: [-784, 92, 7, 282, 401, 171, 343]
# Expected min: -784 	Result min: -784
# Expected max: 401 	Result max: 401
# Test passed
#
# #54 test (currently passed: 54/100)
# Test values: [792, -943, -50, -640, 972, 530, -622, -110, -737, 928, -543, -144, 968, 653, 243, 72, 340, 985, 628]
# Expected min: -943 	Result min: -943
# Expected max: 985 	Result max: 985
# Test passed
#
# #55 test (currently passed: 55/100)
# Test values: [791, 256, 258, -408, -765, -863, 984, 665, 122, 567, -886, 136, -236, 367, 589]
# Expected min: -886 	Result min: -886
# Expected max: 984 	Result max: 984
# Test passed
#
# #56 test (currently passed: 56/100)
# Test values: [731, 152, 866, 95, 147, 820, 359, 208, 297, 827, -151, 377, -433, -487, 683]
# Expected min: -487 	Result min: -487
# Expected max: 866 	Result max: 866
# Test passed
#
# #57 test (currently passed: 57/100)
# Test values: [806, 450, 430, 999, 564]
# Expected min: 430 	Result min: 430
# Expected max: 999 	Result max: 999
# Test passed
#
# #58 test (currently passed: 58/100)
# Test values: [700, -68, 185, -130, 311]
# Expected min: -130 	Result min: -130
# Expected max: 700 	Result max: 700
# Test passed
#
# #59 test (currently passed: 59/100)
# Test values: [-731, 33, 543, 197]
# Expected min: -731 	Result min: -731
# Expected max: 543 	Result max: 543
# Test passed
#
# #60 test (currently passed: 60/100)
# Test values: [-445]
# Expected min: -445 	Result min: -445
# Expected max: -445 	Result max: -445
# Test passed
#
# #61 test (currently passed: 61/100)
# Test values: [-405, 156, -173, -556, -144, -459, 658]
# Expected min: -556 	Result min: -556
# Expected max: 658 	Result max: 658
# Test passed
#
# #62 test (currently passed: 62/100)
# Test values: [179, -910, 59, 3]
# Expected min: -910 	Result min: -910
# Expected max: 179 	Result max: 179
# Test passed
#
# #63 test (currently passed: 63/100)
# Test values: [773, 125, 14]
# Expected min: 14 	Result min: 14
# Expected max: 773 	Result max: 773
# Test passed
#
# #64 test (currently passed: 64/100)
# Test values: [84, 782, -273, 601, -160, 894, 308, -318, -934, -36, 269, -576, -984, -954]
# Expected min: -984 	Result min: -984
# Expected max: 894 	Result max: 894
# Test passed
#
# #65 test (currently passed: 65/100)
# Test values: [-748, 271, 395, 546, 245, -125, -769, -73, 125]
# Expected min: -769 	Result min: -769
# Expected max: 546 	Result max: 546
# Test passed
#
# #66 test (currently passed: 66/100)
# Test values: [-284, 956, -884, 860, -582, -341, -973, -489, 844, 480, 167, 775, 889, 889, 386, 688, -46]
# Expected min: -973 	Result min: -973
# Expected max: 956 	Result max: 956
# Test passed
#
# #67 test (currently passed: 67/100)
# Test values: [-369, 619, -122, 877, 673, -36, -158, -34, 688, -204, -789, 642, -910, 665]
# Expected min: -910 	Result min: -910
# Expected max: 877 	Result max: 877
# Test passed
#
# #68 test (currently passed: 68/100)
# Test values: [-153, 877, 879, 281]
# Expected min: -153 	Result min: -153
# Expected max: 879 	Result max: 879
# Test passed
#
# #69 test (currently passed: 69/100)
# Test values: [691, -726, 800, -521, 710, -963, 867, 661, -412, 185, -410, 857, 251, 630, 419, -576]
# Expected min: -963 	Result min: -963
# Expected max: 867 	Result max: 867
# Test passed
#
# #70 test (currently passed: 70/100)
# Test values: [-747, -557, 806, -611, 763, 856, -822, 229, -524, -358, -943, -543, -236, -89]
# Expected min: -943 	Result min: -943
# Expected max: 856 	Result max: 856
# Test passed
#
# #71 test (currently passed: 71/100)
# Test values: [-108, -839, 8, -790, -198, -755, -285, 218, -451, -626, -48, -453, 542, -609, -221, -589, -88, -637]
# Expected min: -839 	Result min: -839
# Expected max: 542 	Result max: 542
# Test passed
#
# #72 test (currently passed: 72/100)
# Test values: [61, -898, 742, -663]
# Expected min: -898 	Result min: -898
# Expected max: 742 	Result max: 742
# Test passed
#
# #73 test (currently passed: 73/100)
# Test values: [493, -637]
# Expected min: -637 	Result min: -637
# Expected max: 493 	Result max: 493
# Test passed
#
# #74 test (currently passed: 74/100)
# Test values: [99, 949, 807, 171, 65, 108, -823]
# Expected min: -823 	Result min: -823
# Expected max: 949 	Result max: 949
# Test passed
#
# #75 test (currently passed: 75/100)
# Test values: [362, -352, -434, 753, -580, -61, -937, -467, -41, 924, 817, 520]
# Expected min: -937 	Result min: -937
# Expected max: 924 	Result max: 924
# Test passed
#
# #76 test (currently passed: 76/100)
# Test values: [655, -333, 246, 226, 388, 193, 154, -517, -707, 435, -527, 23, 38, 527]
# Expected min: -707 	Result min: -707
# Expected max: 655 	Result max: 655
# Test passed
#
# #77 test (currently passed: 77/100)
# Test values: [681, -608, -987, -7, 46, 856, -263, 990, -945, 716]
# Expected min: -987 	Result min: -987
# Expected max: 990 	Result max: 990
# Test passed
#
# #78 test (currently passed: 78/100)
# Test values: [166, -782, 316, -60, 22, -957, 992, 331, -569, 976, -605, -261, -840, -775, -320, 156, 718, 393, -301]
# Expected min: -957 	Result min: -957
# Expected max: 992 	Result max: 992
# Test passed
#
# #79 test (currently passed: 79/100)
# Test values: [636, 344, -721, -859, 231, 450, 412, -628, 364]
# Expected min: -859 	Result min: -859
# Expected max: 636 	Result max: 636
# Test passed
#
# #80 test (currently passed: 80/100)
# Test values: [404, 209, 438, -940, -701, 368, 898, -693, -94, -757, 128, 246, 470, -836, 875]
# Expected min: -940 	Result min: -940
# Expected max: 898 	Result max: 898
# Test passed
#
# #81 test (currently passed: 81/100)
# Test values: [268, -126, -997, 33, 850, 697, -286, 799, -828, 913, -630, -267, -968]
# Expected min: -997 	Result min: -997
# Expected max: 913 	Result max: 913
# Test passed
#
# #82 test (currently passed: 82/100)
# Test values: [619, -592, -587, 336, -667, -128, -960, -117, 428, -281, 216, 175, -696, -214, -496, -308, -541]
# Expected min: -960 	Result min: -960
# Expected max: 619 	Result max: 619
# Test passed
#
# #83 test (currently passed: 83/100)
# Test values: [-62, 226, -373, 982, 167, 815, -93, 676, 860, -988]
# Expected min: -988 	Result min: -988
# Expected max: 982 	Result max: 982
# Test passed
#
# #84 test (currently passed: 84/100)
# Test values: [19, 773]
# Expected min: 19 	Result min: 19
# Expected max: 773 	Result max: 773
# Test passed
#
# #85 test (currently passed: 85/100)
# Test values: [-808, 426, 921, -972, -202, -877, 560, -347, -551, -289]
# Expected min: -972 	Result min: -972
# Expected max: 921 	Result max: 921
# Test passed
#
# #86 test (currently passed: 86/100)
# Test values: [100, -504, 297, 666, -833, -87, -713]
# Expected min: -833 	Result min: -833
# Expected max: 666 	Result max: 666
# Test passed
#
# #87 test (currently passed: 87/100)
# Test values: [750, 476, -155, -994, -299, -14, 96, 385, 951, -233, -533, -404, -897, 688, -861, 841, -165, -982, -14]
# Expected min: -994 	Result min: -994
# Expected max: 951 	Result max: 951
# Test passed
#
# #88 test (currently passed: 88/100)
# Test values: [-813, -154, 926, -406]
# Expected min: -813 	Result min: -813
# Expected max: 926 	Result max: 926
# Test passed
#
# #89 test (currently passed: 89/100)
# Test values: [94, 146, 902, 260, 193, -632]
# Expected min: -632 	Result min: -632
# Expected max: 902 	Result max: 902
# Test passed
#
# #90 test (currently passed: 90/100)
# Test values: [985, 231, 243, 706, 854, 924, 579, 607, -587, -367, -739, 680, 405, -278, -896]
# Expected min: -896 	Result min: -896
# Expected max: 985 	Result max: 985
# Test passed
#
# #91 test (currently passed: 91/100)
# Test values: [-823, -590, -902, -80, 145, 314, 949, 987, -985, 186]
# Expected min: -985 	Result min: -985
# Expected max: 987 	Result max: 987
# Test passed
#
# #92 test (currently passed: 92/100)
# Test values: [-227, -773, 406, 277, 458, 423, -308, 585]
# Expected min: -773 	Result min: -773
# Expected max: 585 	Result max: 585
# Test passed
#
# #93 test (currently passed: 93/100)
# Test values: [-868, 70, 643, -958]
# Expected min: -958 	Result min: -958
# Expected max: 643 	Result max: 643
# Test passed
#
# #94 test (currently passed: 94/100)
# Test values: [-438, -935, -211, 220, 159]
# Expected min: -935 	Result min: -935
# Expected max: 220 	Result max: 220
# Test passed
#
# #95 test (currently passed: 95/100)
# Test values: [487, 992, 600, -753, 678, 239, -420, 533, -98, -470, -523, -333, 618, -960, 4, -649, -796, -739, -233, 299]
# Expected min: -960 	Result min: -960
# Expected max: 992 	Result max: 992
# Test passed
#
# #96 test (currently passed: 96/100)
# Test values: [-664, -890, -448, -705]
# Expected min: -890 	Result min: -890
# Expected max: -448 	Result max: -448
# Test passed
#
# #97 test (currently passed: 97/100)
# Test values: [672, -100, 956, -755, 542, -974, -92, 256, 373, -773, -504, -97, 443, -447]
# Expected min: -974 	Result min: -974
# Expected max: 956 	Result max: 956
# Test passed
#
# #98 test (currently passed: 98/100)
# Test values: [814, 709, -269, 988, 109, -352, -58, -162, 441, 541, -216, 740, -501, -4, 80, 989, -84, -945, -619]
# Expected min: -945 	Result min: -945
# Expected max: 989 	Result max: 989
# Test passed
#
# #99 test (currently passed: 99/100)
# Test values: [594]
# Expected min: 594 	Result min: 594
# Expected max: 594 	Result max: 594
# Test passed
#
# #100 test (currently passed: 100/100)
# Test values: [-80, 486, 863, -686, 355, 655, 200, -473, 551, -12, 109, 511, 927, -637, 991, 777]
# Expected min: -686 	Result min: -686
# Expected max: 991 	Result max: 991
# Test passed
#
# Total tests passed: 100/100
# This algorithm is correct

# %% [markdown]
# #### II wersja (bez użycia funkcji $ min $ oraz $ max $)

# %%
def minmax(arr):
    global_min = global_max = arr[0]
    for i in range(1, len(arr)):
        if arr[i] > global_max:   global_max = arr[i]
        elif arr[i] < global_min: global_min = arr[i]
    return global_min, global_max

# %% [markdown]
# ###### Przykładowy test

# %%
test_minmax(minmax, reps=100)
# Out:
# #1 test (currently passed: 1/100)
# Test values: [27, 668, 748, -124, 990, -890, -677, 379, 551, -923, -624, -284]
# Expected min: -923 	Result min: -923
# Expected max: 990 	Result max: 990
# Test passed
#
# #2 test (currently passed: 2/100)
# Test values: [990, -220, -924, 254, -494, 200, -637, 893, 655, 306, 558, -7]
# Expected min: -924 	Result min: -924
# Expected max: 990 	Result max: 990
# Test passed
#
# #3 test (currently passed: 3/100)
# Test values: [-676, -712, -88]
# Expected min: -712 	Result min: -712
# Expected max: -88 	Result max: -88
# Test passed
#
# #4 test (currently passed: 4/100)
# Test values: [-553, 13, 8, 648, 169, -432, 669, 318, -955, 429, 273, 136, 426]
# Expected min: -955 	Result min: -955
# Expected max: 669 	Result max: 669
# Test passed
#
# #5 test (currently passed: 5/100)
# Test values: [-734, -594, -822, 378, 669, -140, 947, 697, -439, -614, -452, -899, -717, 381, -490, 911, 759, -957, 543, 28]
# Expected min: -957 	Result min: -957
# Expected max: 947 	Result max: 947
# Test passed
#
# #6 test (currently passed: 6/100)
# Test values: [-384, 558, -948, 941, 774, -710, 804, -796, 6, -989, 203, 763, 379, 206, -335]
# Expected min: -989 	Result min: -989
# Expected max: 941 	Result max: 941
# Test passed
#
# #7 test (currently passed: 7/100)
# Test values: [823, -658, -519, -239, 466, -297, -525, -358, -328, 667]
# Expected min: -658 	Result min: -658
# Expected max: 823 	Result max: 823
# Test passed
#
# #8 test (currently passed: 8/100)
# Test values: [-965, -792, -526, -76, -818, 269, 523, 297]
# Expected min: -965 	Result min: -965
# Expected max: 523 	Result max: 523
# Test passed
#
# #9 test (currently passed: 9/100)
# Test values: [-103, -94, -8, -261]
# Expected min: -261 	Result min: -261
# Expected max: -8 	Result max: -8
# Test passed
#
# #10 test (currently passed: 10/100)
# Test values: [814, -150, 90, -930, -842, 75, -718, 783, 719, -911, -698, -350, -167, 76]
# Expected min: -930 	Result min: -930
# Expected max: 814 	Result max: 814
# Test passed
#
# #11 test (currently passed: 11/100)
# Test values: [120]
# Expected min: 120 	Result min: 120
# Expected max: 120 	Result max: 120
# Test passed
#
# #12 test (currently passed: 12/100)
# Test values: [709, 66, 165, 446, 104, -613, -786, -525, -414, -711, 889, -396, -676, -489, 637, -801, 112, 672]
# Expected min: -801 	Result min: -801
# Expected max: 889 	Result max: 889
# Test passed
#
# #13 test (currently passed: 13/100)
# Test values: [586, -318, 315, -64, 759, -862, -681, -252, -551, -744, -611, -985, -720]
# Expected min: -985 	Result min: -985
# Expected max: 759 	Result max: 759
# Test passed
#
# #14 test (currently passed: 14/100)
# Test values: [-172, 967, 717, -717, -301, -447, -635, -504, 856, -826, -374, -679, 245, -312, -145]
# Expected min: -826 	Result min: -826
# Expected max: 967 	Result max: 967
# Test passed
#
# #15 test (currently passed: 15/100)
# Test values: [506, -235, -436, -474, -556, -562, -97, -957, 589, 385, 981, -927, -425, -821, 872]
# Expected min: -957 	Result min: -957
# Expected max: 981 	Result max: 981
# Test passed
#
# #16 test (currently passed: 16/100)
# Test values: [936, -58, 972, -947, -621, 669, -138, 983, 19, -912, -591, -86, -734, -245]
# Expected min: -947 	Result min: -947
# Expected max: 983 	Result max: 983
# Test passed
#
# #17 test (currently passed: 17/100)
# Test values: [-999]
# Expected min: -999 	Result min: -999
# Expected max: -999 	Result max: -999
# Test passed
#
# #18 test (currently passed: 18/100)
# Test values: [-22, -521, -324, 560, 452, -718, 258, -75, 774, -430, -380, 211, -659]
# Expected min: -718 	Result min: -718
# Expected max: 774 	Result max: 774
# Test passed
#
# #19 test (currently passed: 19/100)
# Test values: [444, -92, 667, -862]
# Expected min: -862 	Result min: -862
# Expected max: 667 	Result max: 667
# Test passed
#
# #20 test (currently passed: 20/100)
# Test values: [404, 627, 897, -852, -239, -72, -715, -164, 135, -819, -630, 121, -267, -75, -920, 437, -291, -594]
# Expected min: -920 	Result min: -920
# Expected max: 897 	Result max: 897
# Test passed
#
# #21 test (currently passed: 21/100)
# Test values: [719, -463, -940, 344, -16, -900, 487, -241, -73, -635, -557, -811, -351, -645, -103, -166, -520, 852]
# Expected min: -940 	Result min: -940
# Expected max: 852 	Result max: 852
# Test passed
#
# #22 test (currently passed: 22/100)
# Test values: [-297, 104, 666, 22, 403, -79, -354, 619]
# Expected min: -354 	Result min: -354
# Expected max: 666 	Result max: 666
# Test passed
#
# #23 test (currently passed: 23/100)
# Test values: [914, 122, -447, 463, -547, -363, -856, -111, -137]
# Expected min: -856 	Result min: -856
# Expected max: 914 	Result max: 914
# Test passed
#
# #24 test (currently passed: 24/100)
# Test values: [82, 785, 281, -465, -798, -455, 88, 972, 646, 163, 140, 990, -205, -179, 651]
# Expected min: -798 	Result min: -798
# Expected max: 990 	Result max: 990
# Test passed
#
# #25 test (currently passed: 25/100)
# Test values: [-967]
# Expected min: -967 	Result min: -967
# Expected max: -967 	Result max: -967
# Test passed
#
# #26 test (currently passed: 26/100)
# Test values: [353, 540, 148, -502, 376, 726, 986, -263, 269, -79, 674, 141, -708]
# Expected min: -708 	Result min: -708
# Expected max: 986 	Result max: 986
# Test passed
#
# #27 test (currently passed: 27/100)
# Test values: [-320, -490, 679]
# Expected min: -490 	Result min: -490
# Expected max: 679 	Result max: 679
# Test passed
#
# #28 test (currently passed: 28/100)
# Test values: [-841, -260]
# Expected min: -841 	Result min: -841
# Expected max: -260 	Result max: -260
# Test passed
#
# #29 test (currently passed: 29/100)
# Test values: [-812, -93, -351, 580, 748, -395, 803, -771, -327, -802, -294, 746, -289, -143, -897, 410, 622, 611]
# Expected min: -897 	Result min: -897
# Expected max: 803 	Result max: 803
# Test passed
#
# #30 test (currently passed: 30/100)
# Test values: [-746, 873]
# Expected min: -746 	Result min: -746
# Expected max: 873 	Result max: 873
# Test passed
#
# #31 test (currently passed: 31/100)
# Test values: [470, -255, -375, -512, -327, 482, 129, 237]
# Expected min: -512 	Result min: -512
# Expected max: 482 	Result max: 482
# Test passed
#
# #32 test (currently passed: 32/100)
# Test values: [-72, -510, 382, 223, 907, 14]
# Expected min: -510 	Result min: -510
# Expected max: 907 	Result max: 907
# Test passed
#
# #33 test (currently passed: 33/100)
# Test values: [-815, 820, 641, -271, 281, -372, -516, -630, -160]
# Expected min: -815 	Result min: -815
# Expected max: 820 	Result max: 820
# Test passed
#
# #34 test (currently passed: 34/100)
# Test values: [795, 339, 398, 147, -377, -88, 241, -909, -150, 886, -997, 312, -396, -72, 898, -884, 161, -127, -317]
# Expected min: -997 	Result min: -997
# Expected max: 898 	Result max: 898
# Test passed
#
# #35 test (currently passed: 35/100)
# Test values: [640]
# Expected min: 640 	Result min: 640
# Expected max: 640 	Result max: 640
# Test passed
#
# #36 test (currently passed: 36/100)
# Test values: [-835, 924, 466, -776]
# Expected min: -835 	Result min: -835
# Expected max: 924 	Result max: 924
# Test passed
#
# #37 test (currently passed: 37/100)
# Test values: [-814]
# Expected min: -814 	Result min: -814
# Expected max: -814 	Result max: -814
# Test passed
#
# #38 test (currently passed: 38/100)
# Test values: [850, -775, -90]
# Expected min: -775 	Result min: -775
# Expected max: 850 	Result max: 850
# Test passed
#
# #39 test (currently passed: 39/100)
# Test values: [-254, 29, 379, 413, -932, 372, 479, 191, 967, -424, 369, -396, 236, 375]
# Expected min: -932 	Result min: -932
# Expected max: 967 	Result max: 967
# Test passed
#
# #40 test (currently passed: 40/100)
# Test values: [655, 269, 207, 587, 44, -469, -29, 375, 315, 913, -410, -681, 686, 113, 120, -709, 198, -76, 112, -87]
# Expected min: -709 	Result min: -709
# Expected max: 913 	Result max: 913
# Test passed
#
# #41 test (currently passed: 41/100)
# Test values: [342, 818, 249]
# Expected min: 249 	Result min: 249
# Expected max: 818 	Result max: 818
# Test passed
#
# #42 test (currently passed: 42/100)
# Test values: [-867, 363, 398, 536, -847, 648, 288, 312, -249, -344, -752, -607, 214, -33, 861, -746, -678, -954, -853, 243]
# Expected min: -954 	Result min: -954
# Expected max: 861 	Result max: 861
# Test passed
#
# #43 test (currently passed: 43/100)
# Test values: [893, -91, -123, -80, -165, -69, 185]
# Expected min: -165 	Result min: -165
# Expected max: 893 	Result max: 893
# Test passed
#
# #44 test (currently passed: 44/100)
# Test values: [-774, -975]
# Expected min: -975 	Result min: -975
# Expected max: -774 	Result max: -774
# Test passed
#
# #45 test (currently passed: 45/100)
# Test values: [-402, -351, 905, -214, 146, -19, -364]
# Expected min: -402 	Result min: -402
# Expected max: 905 	Result max: 905
# Test passed
#
# #46 test (currently passed: 46/100)
# Test values: [809, -328, -686, -577, -849, -108, 526, -660, 617, -130, 561, -826, 776, -138, -178, -846, -512, 310, -331]
# Expected min: -849 	Result min: -849
# Expected max: 809 	Result max: 809
# Test passed
#
# #47 test (currently passed: 47/100)
# Test values: [-127, 216, -248, -916, 794, 139, -246, -557, -525, -642]
# Expected min: -916 	Result min: -916
# Expected max: 794 	Result max: 794
# Test passed
#
# #48 test (currently passed: 48/100)
# Test values: [-26, -211, -75, -369, 179, -727, -609]
# Expected min: -727 	Result min: -727
# Expected max: 179 	Result max: 179
# Test passed
#
# #49 test (currently passed: 49/100)
# Test values: [-753, 365, 149, -104, 348, 720, -97, -174, 299, 864, 33, 477, 614]
# Expected min: -753 	Result min: -753
# Expected max: 864 	Result max: 864
# Test passed
#
# #50 test (currently passed: 50/100)
# Test values: [-650, 485]
# Expected min: -650 	Result min: -650
# Expected max: 485 	Result max: 485
# Test passed
#
# #51 test (currently passed: 51/100)
# Test values: [-211, 359]
# Expected min: -211 	Result min: -211
# Expected max: 359 	Result max: 359
# Test passed
#
# #52 test (currently passed: 52/100)
# Test values: [433, -111, 199, 164, 114, 379, -941, 701]
# Expected min: -941 	Result min: -941
# Expected max: 701 	Result max: 701
# Test passed
#
# #53 test (currently passed: 53/100)
# Test values: [228, 366, -828, 54, 593, 890, -392, 462, -291, 449, 289, -938, 808, 196, -295]
# Expected min: -938 	Result min: -938
# Expected max: 890 	Result max: 890
# Test passed
#
# #54 test (currently passed: 54/100)
# Test values: [-614, 371, -125]
# Expected min: -614 	Result min: -614
# Expected max: 371 	Result max: 371
# Test passed
#
# #55 test (currently passed: 55/100)
# Test values: [-559, 644, -331, 765, 245, -150, -475, 714, 152, 956, -779, 163, -444, 885]
# Expected min: -779 	Result min: -779
# Expected max: 956 	Result max: 956
# Test passed
#
# #56 test (currently passed: 56/100)
# Test values: [-396, -18, 585, -819, 175, -227, 1000, -960, 502, 901, -580, -732, 262, 264]
# Expected min: -960 	Result min: -960
# Expected max: 1000 	Result max: 1000
# Test passed
#
# #57 test (currently passed: 57/100)
# Test values: [-552, -806]
# Expected min: -806 	Result min: -806
# Expected max: -552 	Result max: -552
# Test passed
#
# #58 test (currently passed: 58/100)
# Test values: [-102, -522, 105, -310, -790]
# Expected min: -790 	Result min: -790
# Expected max: 105 	Result max: 105
# Test passed
#
# #59 test (currently passed: 59/100)
# Test values: [-412, 875, 256, -30, -765]
# Expected min: -765 	Result min: -765
# Expected max: 875 	Result max: 875
# Test passed
#
# #60 test (currently passed: 60/100)
# Test values: [-576, 799, -92, -593, -991, 471, 18, 329, 47, -441, -510, -104, -424, 589, -667]
# Expected min: -991 	Result min: -991
# Expected max: 799 	Result max: 799
# Test passed
#
# #61 test (currently passed: 61/100)
# Test values: [-535, 629, -348, -723, 803, -116, -564, -743, -484]
# Expected min: -743 	Result min: -743
# Expected max: 803 	Result max: 803
# Test passed
#
# #62 test (currently passed: 62/100)
# Test values: [376, 504, 191, -274, 445, 101, -29, 749, -114, -930, 261, -540, -57, 178, 799, -560, 36, 717, -683]
# Expected min: -930 	Result min: -930
# Expected max: 799 	Result max: 799
# Test passed
#
# #63 test (currently passed: 63/100)
# Test values: [-888, 529, 234, 736, 59]
# Expected min: -888 	Result min: -888
# Expected max: 736 	Result max: 736
# Test passed
#
# #64 test (currently passed: 64/100)
# Test values: [-366, 78, -884, 14, -130, -554]
# Expected min: -884 	Result min: -884
# Expected max: 78 	Result max: 78
# Test passed
#
# #65 test (currently passed: 65/100)
# Test values: [953, -388, 650, -660, 168, 383, 591, 312, -744, 111]
# Expected min: -744 	Result min: -744
# Expected max: 953 	Result max: 953
# Test passed
#
# #66 test (currently passed: 66/100)
# Test values: [433, -899, 996, -665, -632, 57, -514, 205, 905, 839, 972, -53]
# Expected min: -899 	Result min: -899
# Expected max: 996 	Result max: 996
# Test passed
#
# #67 test (currently passed: 67/100)
# Test values: [-722, 442, -883, -851, 544, 106, -203, -756, -612, -802, -762, 669, -124]
# Expected min: -883 	Result min: -883
# Expected max: 669 	Result max: 669
# Test passed
#
# #68 test (currently passed: 68/100)
# Test values: [-320, -143, 839, 93]
# Expected min: -320 	Result min: -320
# Expected max: 839 	Result max: 839
# Test passed
#
# #69 test (currently passed: 69/100)
# Test values: [-107, -932, -862, -556, 957, 99, 541, -9, 580, -592, -191, 113, 372, -739]
# Expected min: -932 	Result min: -932
# Expected max: 957 	Result max: 957
# Test passed
#
# #70 test (currently passed: 70/100)
# Test values: [150, -298, 327, -28]
# Expected min: -298 	Result min: -298
# Expected max: 327 	Result max: 327
# Test passed
#
# #71 test (currently passed: 71/100)
# Test values: [862, -397, 633, -29, 962, -58, 41, -839, 957, 905, -776, 658, -735, 312]
# Expected min: -839 	Result min: -839
# Expected max: 962 	Result max: 962
# Test passed
#
# #72 test (currently passed: 72/100)
# Test values: [812, -291, -742, -643, -196, -807, 681, -262, -221, -65]
# Expected min: -807 	Result min: -807
# Expected max: 812 	Result max: 812
# Test passed
#
# #73 test (currently passed: 73/100)
# Test values: [952]
# Expected min: 952 	Result min: 952
# Expected max: 952 	Result max: 952
# Test passed
#
# #74 test (currently passed: 74/100)
# Test values: [422, 636, 825, 933, 11, -899, -652, -627, 399, 250, 444, 165, 862, 743, 649, -599, -320, -859]
# Expected min: -899 	Result min: -899
# Expected max: 933 	Result max: 933
# Test passed
#
# #75 test (currently passed: 75/100)
# Test values: [-947, 454, -535, 984, 904, -57]
# Expected min: -947 	Result min: -947
# Expected max: 984 	Result max: 984
# Test passed
#
# #76 test (currently passed: 76/100)
# Test values: [-139, -901, 469, 199, 115, 767, 855, 744, -876]
# Expected min: -901 	Result min: -901
# Expected max: 855 	Result max: 855
# Test passed
#
# #77 test (currently passed: 77/100)
# Test values: [-299, -4, 439, -344, -906, -328, 459, -631, -681, 710, 243, -465, 866, -865, -253, -810, 539, -429, 444, 250]
# Expected min: -906 	Result min: -906
# Expected max: 866 	Result max: 866
# Test passed
#
# #78 test (currently passed: 78/100)
# Test values: [-694, 752, -202, -932, 309, -87, -790, 458, -50, 425, 304, -446, -740, 386, 358, -554, -689, -833, 281, 486]
# Expected min: -932 	Result min: -932
# Expected max: 752 	Result max: 752
# Test passed
#
# #79 test (currently passed: 79/100)
# Test values: [-654, 363, -839, -376, 746, 379, -897, 784]
# Expected min: -897 	Result min: -897
# Expected max: 784 	Result max: 784
# Test passed
#
# #80 test (currently passed: 80/100)
# Test values: [358, 361, -79, -885, 597, -276, -398, 186, -621, -906, -643, 902, -965, -382]
# Expected min: -965 	Result min: -965
# Expected max: 902 	Result max: 902
# Test passed
#
# #81 test (currently passed: 81/100)
# Test values: [112, 172, -962, -40, 646, 989, -428, 482, 7, 638, -467, 922, -127, -503, -986]
# Expected min: -986 	Result min: -986
# Expected max: 989 	Result max: 989
# Test passed
#
# #82 test (currently passed: 82/100)
# Test values: [-697, -34, -561, 472, 520, 962, -853, 545, -515, -506, -854, 239]
# Expected min: -854 	Result min: -854
# Expected max: 962 	Result max: 962
# Test passed
#
# #83 test (currently passed: 83/100)
# Test values: [-307, 203, -576, -637, 418, -791, -842, -503, 70, -699, -209, 246, 681, -952, 652, 987, -670, -985, -887]
# Expected min: -985 	Result min: -985
# Expected max: 987 	Result max: 987
# Test passed
#
# #84 test (currently passed: 84/100)
# Test values: [-735, 672, 5, -478, 231, -211, -522, 215, 348, -617, 63, -872, 699]
# Expected min: -872 	Result min: -872
# Expected max: 699 	Result max: 699
# Test passed
#
# #85 test (currently passed: 85/100)
# Test values: [258, 870, -22, 84, 789, 715, -167, 310, -608, 114, -40, 378, -682, 381, -503, -145, 957, -573, 618, -527]
# Expected min: -682 	Result min: -682
# Expected max: 957 	Result max: 957
# Test passed
#
# #86 test (currently passed: 86/100)
# Test values: [-300, 927, 143, -969, 824, 7, 439]
# Expected min: -969 	Result min: -969
# Expected max: 927 	Result max: 927
# Test passed
#
# #87 test (currently passed: 87/100)
# Test values: [813, 342, -517, 482, -816, -615, -48, -276, 594]
# Expected min: -816 	Result min: -816
# Expected max: 813 	Result max: 813
# Test passed
#
# #88 test (currently passed: 88/100)
# Test values: [-889, 903, 177, -566, 484, -269, -376, 349, 778, -602, -33, 386, -205, 459, -927, -22]
# Expected min: -927 	Result min: -927
# Expected max: 903 	Result max: 903
# Test passed
#
# #89 test (currently passed: 89/100)
# Test values: [789, -171, -99, 528, -648, 826, 132, -818, -689, 694, -5, -731]
# Expected min: -818 	Result min: -818
# Expected max: 826 	Result max: 826
# Test passed
#
# #90 test (currently passed: 90/100)
# Test values: [-342, -794, -271, -4, 445, 718, -137, 641, -711, 76, 79, 818, 965, 764, 715, 532, 91]
# Expected min: -794 	Result min: -794
# Expected max: 965 	Result max: 965
# Test passed
#
# #91 test (currently passed: 91/100)
# Test values: [584, -458, 676, -295, -813, -473]
# Expected min: -813 	Result min: -813
# Expected max: 676 	Result max: 676
# Test passed
#
# #92 test (currently passed: 92/100)
# Test values: [214, 950, -784, 740, -793, 644, -786, 183, 867, -376, -95, 285]
# Expected min: -793 	Result min: -793
# Expected max: 950 	Result max: 950
# Test passed
#
# #93 test (currently passed: 93/100)
# Test values: [662, 529, -212, -94, -257, -231, -336, -385, 253]
# Expected min: -385 	Result min: -385
# Expected max: 662 	Result max: 662
# Test passed
#
# #94 test (currently passed: 94/100)
# Test values: [787, 48, 414, 818, 191, -662, -172, 849, 708, 94]
# Expected min: -662 	Result min: -662
# Expected max: 849 	Result max: 849
# Test passed
#
# #95 test (currently passed: 95/100)
# Test values: [-526, -791, -999, 491, -920, 695, -115, -732, 891, 160, 682, -305, -36, 309, 894, -985, -448]
# Expected min: -999 	Result min: -999
# Expected max: 894 	Result max: 894
# Test passed
#
# #96 test (currently passed: 96/100)
# Test values: [249, -199, -942, -706, -575, 71, -779, -459, 975, 405, -511, -469, 470, 851, 819, 821, -632, -253, 627, -42]
# Expected min: -942 	Result min: -942
# Expected max: 975 	Result max: 975
# Test passed
#
# #97 test (currently passed: 97/100)
# Test values: [-711, 247, -698, -969, 458, -937, 795, 829, -677, 87, -557, 978, -267, -409, -152, -529, -421, 541]
# Expected min: -969 	Result min: -969
# Expected max: 978 	Result max: 978
# Test passed
#
# #98 test (currently passed: 98/100)
# Test values: [-911, 111]
# Expected min: -911 	Result min: -911
# Expected max: 111 	Result max: 111
# Test passed
#
# #99 test (currently passed: 99/100)
# Test values: [-538, -623, 96, -153, -31, -644]
# Expected min: -644 	Result min: -644
# Expected max: 96 	Result max: 96
# Test passed
#
# #100 test (currently passed: 100/100)
# Test values: [413, 549, -891, 297, 849, -3, -851, 964, -402, -102, -551, 833]
# Expected min: -891 	Result min: -891
# Expected max: 964 	Result max: 964
# Test passed
#
# Total tests passed: 100/100
# This algorithm is correct
