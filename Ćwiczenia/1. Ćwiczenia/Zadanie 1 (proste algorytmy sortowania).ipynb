# %% [markdown]
# > Proszę zaimplementować jeden ze standardowych algorytmów sortowania tablicy działający w czasie $ O(n^2) $ (np. sortowanie bąbelkowe, sortowanie przez wstawianie, sortowanie przez wybieranie).

# %% [markdown]
# ##### Funkcja testująca poprawność algorytmu

# %%
import random

def test_sort(sorting_fn, *, samples=20):
    passed = 0
    for i in range(samples):
        random_lst = [random.randint(-100, 100) for _ in range(random.randint(5, 15))]
        expected = sorted(random_lst)
        print(f'#{i+1} Loop (already passed: {passed}/{samples})')
        print(f'Before sorting: {random_lst}')
        sorting_fn(random_lst)
        passed += random_lst == expected
        print(f'After sorting: {random_lst}')
        print(f'Expected result: {expected}')
        print()
    print(f'Sorting algorithm is {"correct" if passed == samples else "wrong"}')
    print(f'Passed tests in total: {passed}/{samples}')

# %% [markdown]
# ### Bubble Sort

# %%
def bubble_sort(arr):
    for i in range(len(arr)-1):
        for j in range(len(arr)-1-i):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# %% [markdown]
# ###### Kilka testów

# %%
test_sort(bubble_sort, samples=100)
# Out:
# #1 Loop (already passed: 0/100)
# Before sorting: [-97, -28, -15, 64, -14, 26, -29, -41, 70, 57, -82]
# After sorting: [-97, -82, -41, -29, -28, -15, -14, 26, 57, 64, 70]
# Expected result: [-97, -82, -41, -29, -28, -15, -14, 26, 57, 64, 70]
#
# #2 Loop (already passed: 1/100)
# Before sorting: [68, -30, 47, 27, 27, -1, -22, -39, 12, -93, -70]
# After sorting: [-93, -70, -39, -30, -22, -1, 12, 27, 27, 47, 68]
# Expected result: [-93, -70, -39, -30, -22, -1, 12, 27, 27, 47, 68]
#
# #3 Loop (already passed: 2/100)
# Before sorting: [-20, -83, -77, -50, -89, 39, -67, -93, -87, -78, -36, -85]
# After sorting: [-93, -89, -87, -85, -83, -78, -77, -67, -50, -36, -20, 39]
# Expected result: [-93, -89, -87, -85, -83, -78, -77, -67, -50, -36, -20, 39]
#
# #4 Loop (already passed: 3/100)
# Before sorting: [58, 19, 60, -84, 63, -62]
# After sorting: [-84, -62, 19, 58, 60, 63]
# Expected result: [-84, -62, 19, 58, 60, 63]
#
# #5 Loop (already passed: 4/100)
# Before sorting: [33, -37, 23, 96, 0, -97, 17, -42, 87, 35, 74, -95, -7, 88]
# After sorting: [-97, -95, -42, -37, -7, 0, 17, 23, 33, 35, 74, 87, 88, 96]
# Expected result: [-97, -95, -42, -37, -7, 0, 17, 23, 33, 35, 74, 87, 88, 96]
#
# #6 Loop (already passed: 5/100)
# Before sorting: [-48, 22, 75, 43, -50]
# After sorting: [-50, -48, 22, 43, 75]
# Expected result: [-50, -48, 22, 43, 75]
#
# #7 Loop (already passed: 6/100)
# Before sorting: [-33, -41, 66, -26, -56, -10, 65, 48, 69, 69, 6]
# After sorting: [-56, -41, -33, -26, -10, 6, 48, 65, 66, 69, 69]
# Expected result: [-56, -41, -33, -26, -10, 6, 48, 65, 66, 69, 69]
#
# #8 Loop (already passed: 7/100)
# Before sorting: [-56, 100, 43, 23, -18, -21, -23, -21, 51, -49, -41, 68]
# After sorting: [-56, -49, -41, -23, -21, -21, -18, 23, 43, 51, 68, 100]
# Expected result: [-56, -49, -41, -23, -21, -21, -18, 23, 43, 51, 68, 100]
#
# #9 Loop (already passed: 8/100)
# Before sorting: [-9, 100, 73, -25, 79, -70, 75, -55, 20, 55, -28, 79]
# After sorting: [-70, -55, -28, -25, -9, 20, 55, 73, 75, 79, 79, 100]
# Expected result: [-70, -55, -28, -25, -9, 20, 55, 73, 75, 79, 79, 100]
#
# #10 Loop (already passed: 9/100)
# Before sorting: [-7, -23, -20, -12, -21, 79, -35, 89, 49, -25, -90, 93, 57, 62]
# After sorting: [-90, -35, -25, -23, -21, -20, -12, -7, 49, 57, 62, 79, 89, 93]
# Expected result: [-90, -35, -25, -23, -21, -20, -12, -7, 49, 57, 62, 79, 89, 93]
#
# #11 Loop (already passed: 10/100)
# Before sorting: [99, 25, 69, -1, 43, -66, -43, 71, -52, 19, 100, -10, 92]
# After sorting: [-66, -52, -43, -10, -1, 19, 25, 43, 69, 71, 92, 99, 100]
# Expected result: [-66, -52, -43, -10, -1, 19, 25, 43, 69, 71, 92, 99, 100]
#
# #12 Loop (already passed: 11/100)
# Before sorting: [72, -89, -30, -88, 24, 75, -65, -23, 14, -45, 2, 18, 52, 84]
# After sorting: [-89, -88, -65, -45, -30, -23, 2, 14, 18, 24, 52, 72, 75, 84]
# Expected result: [-89, -88, -65, -45, -30, -23, 2, 14, 18, 24, 52, 72, 75, 84]
#
# #13 Loop (already passed: 12/100)
# Before sorting: [25, 2, 65, -22, -46, 81, 71, 31, 7, -100]
# After sorting: [-100, -46, -22, 2, 7, 25, 31, 65, 71, 81]
# Expected result: [-100, -46, -22, 2, 7, 25, 31, 65, 71, 81]
#
# #14 Loop (already passed: 13/100)
# Before sorting: [-33, 53, -97, -42, 83, -87, 92, 8, -61, -9, 33, -48]
# After sorting: [-97, -87, -61, -48, -42, -33, -9, 8, 33, 53, 83, 92]
# Expected result: [-97, -87, -61, -48, -42, -33, -9, 8, 33, 53, 83, 92]
#
# #15 Loop (already passed: 14/100)
# Before sorting: [-70, -72, -15, 3, 26]
# After sorting: [-72, -70, -15, 3, 26]
# Expected result: [-72, -70, -15, 3, 26]
#
# #16 Loop (already passed: 15/100)
# Before sorting: [55, 81, 1, -79, -27, 50, -62, 19, 42, -12, -1, 54, -28, -29, 46]
# After sorting: [-79, -62, -29, -28, -27, -12, -1, 1, 19, 42, 46, 50, 54, 55, 81]
# Expected result: [-79, -62, -29, -28, -27, -12, -1, 1, 19, 42, 46, 50, 54, 55, 81]
#
# #17 Loop (already passed: 16/100)
# Before sorting: [-52, 39, 68, -83, -20, 50, 20, 91, -1, 56, -18]
# After sorting: [-83, -52, -20, -18, -1, 20, 39, 50, 56, 68, 91]
# Expected result: [-83, -52, -20, -18, -1, 20, 39, 50, 56, 68, 91]
#
# #18 Loop (already passed: 17/100)
# Before sorting: [77, -23, -75, 27, -91, -56]
# After sorting: [-91, -75, -56, -23, 27, 77]
# Expected result: [-91, -75, -56, -23, 27, 77]
#
# #19 Loop (already passed: 18/100)
# Before sorting: [28, -86, 12, -77, -77, -62, -61, -5, -63, -74, 32, 36]
# After sorting: [-86, -77, -77, -74, -63, -62, -61, -5, 12, 28, 32, 36]
# Expected result: [-86, -77, -77, -74, -63, -62, -61, -5, 12, 28, 32, 36]
#
# #20 Loop (already passed: 19/100)
# Before sorting: [74, -64, -51, -31, 50, 60, 1]
# After sorting: [-64, -51, -31, 1, 50, 60, 74]
# Expected result: [-64, -51, -31, 1, 50, 60, 74]
#
# #21 Loop (already passed: 20/100)
# Before sorting: [-18, 68, 86, -99, 43, 7, -4, -34, 21, 31, 35, 95, 99, 97]
# After sorting: [-99, -34, -18, -4, 7, 21, 31, 35, 43, 68, 86, 95, 97, 99]
# Expected result: [-99, -34, -18, -4, 7, 21, 31, 35, 43, 68, 86, 95, 97, 99]
#
# #22 Loop (already passed: 21/100)
# Before sorting: [7, -10, 65, 94, 62, -100]
# After sorting: [-100, -10, 7, 62, 65, 94]
# Expected result: [-100, -10, 7, 62, 65, 94]
#
# #23 Loop (already passed: 22/100)
# Before sorting: [-19, -41, -87, -66, 22, -2, 75, -22, 71, 8, -1, -59, 84, 6, -40]
# After sorting: [-87, -66, -59, -41, -40, -22, -19, -2, -1, 6, 8, 22, 71, 75, 84]
# Expected result: [-87, -66, -59, -41, -40, -22, -19, -2, -1, 6, 8, 22, 71, 75, 84]
#
# #24 Loop (already passed: 23/100)
# Before sorting: [0, -66, 13, 13, -22, -48, 19, 82, -25, 21, 94, 31, 91]
# After sorting: [-66, -48, -25, -22, 0, 13, 13, 19, 21, 31, 82, 91, 94]
# Expected result: [-66, -48, -25, -22, 0, 13, 13, 19, 21, 31, 82, 91, 94]
#
# #25 Loop (already passed: 24/100)
# Before sorting: [4, 95, -53, 81, 41]
# After sorting: [-53, 4, 41, 81, 95]
# Expected result: [-53, 4, 41, 81, 95]
#
# #26 Loop (already passed: 25/100)
# Before sorting: [-19, -63, 84, 88, 53, 6, -85, 19, 90, 45, -67]
# After sorting: [-85, -67, -63, -19, 6, 19, 45, 53, 84, 88, 90]
# Expected result: [-85, -67, -63, -19, 6, 19, 45, 53, 84, 88, 90]
#
# #27 Loop (already passed: 26/100)
# Before sorting: [3, 17, 29, -6, 22, -5, -1, 50, -15, 75]
# After sorting: [-15, -6, -5, -1, 3, 17, 22, 29, 50, 75]
# Expected result: [-15, -6, -5, -1, 3, 17, 22, 29, 50, 75]
#
# #28 Loop (already passed: 27/100)
# Before sorting: [-39, -30, 61, 1, 81, 27, -63, -61, 3, 87, -62, -73]
# After sorting: [-73, -63, -62, -61, -39, -30, 1, 3, 27, 61, 81, 87]
# Expected result: [-73, -63, -62, -61, -39, -30, 1, 3, 27, 61, 81, 87]
#
# #29 Loop (already passed: 28/100)
# Before sorting: [68, 39, 43, -54, -30, 49, 31, -84, 43, 97, -89]
# After sorting: [-89, -84, -54, -30, 31, 39, 43, 43, 49, 68, 97]
# Expected result: [-89, -84, -54, -30, 31, 39, 43, 43, 49, 68, 97]
#
# #30 Loop (already passed: 29/100)
# Before sorting: [64, -17, 36, -79, -37, -36, -36]
# After sorting: [-79, -37, -36, -36, -17, 36, 64]
# Expected result: [-79, -37, -36, -36, -17, 36, 64]
#
# #31 Loop (already passed: 30/100)
# Before sorting: [-56, -39, 74, 82, -29, -29, 22, 56, -26, 48]
# After sorting: [-56, -39, -29, -29, -26, 22, 48, 56, 74, 82]
# Expected result: [-56, -39, -29, -29, -26, 22, 48, 56, 74, 82]
#
# #32 Loop (already passed: 31/100)
# Before sorting: [85, -98, 58, 14, -13, -21, -91, -24, 21]
# After sorting: [-98, -91, -24, -21, -13, 14, 21, 58, 85]
# Expected result: [-98, -91, -24, -21, -13, 14, 21, 58, 85]
#
# #33 Loop (already passed: 32/100)
# Before sorting: [57, 25, -77, 99, -33, -70, -23, -35, 22, -24, -61]
# After sorting: [-77, -70, -61, -35, -33, -24, -23, 22, 25, 57, 99]
# Expected result: [-77, -70, -61, -35, -33, -24, -23, 22, 25, 57, 99]
#
# #34 Loop (already passed: 33/100)
# Before sorting: [-15, 48, -91, 94, 65, -1, -97, 88, -87]
# After sorting: [-97, -91, -87, -15, -1, 48, 65, 88, 94]
# Expected result: [-97, -91, -87, -15, -1, 48, 65, 88, 94]
#
# #35 Loop (already passed: 34/100)
# Before sorting: [95, -54, -95, 81, -30, 81]
# After sorting: [-95, -54, -30, 81, 81, 95]
# Expected result: [-95, -54, -30, 81, 81, 95]
#
# #36 Loop (already passed: 35/100)
# Before sorting: [-61, 42, -10, -44, -77, -52, 21, 72, 29, 9, 30, 9, -94]
# After sorting: [-94, -77, -61, -52, -44, -10, 9, 9, 21, 29, 30, 42, 72]
# Expected result: [-94, -77, -61, -52, -44, -10, 9, 9, 21, 29, 30, 42, 72]
#
# #37 Loop (already passed: 36/100)
# Before sorting: [-13, -12, -16, -21, -98, -47, 52, -80, 28, -68, 60]
# After sorting: [-98, -80, -68, -47, -21, -16, -13, -12, 28, 52, 60]
# Expected result: [-98, -80, -68, -47, -21, -16, -13, -12, 28, 52, 60]
#
# #38 Loop (already passed: 37/100)
# Before sorting: [54, 94, 44, -16, 1, -10]
# After sorting: [-16, -10, 1, 44, 54, 94]
# Expected result: [-16, -10, 1, 44, 54, 94]
#
# #39 Loop (already passed: 38/100)
# Before sorting: [-68, 37, -73, 24, 1, 68, -12, 89]
# After sorting: [-73, -68, -12, 1, 24, 37, 68, 89]
# Expected result: [-73, -68, -12, 1, 24, 37, 68, 89]
#
# #40 Loop (already passed: 39/100)
# Before sorting: [-78, -98, -65, -97, -54, -31]
# After sorting: [-98, -97, -78, -65, -54, -31]
# Expected result: [-98, -97, -78, -65, -54, -31]
#
# #41 Loop (already passed: 40/100)
# Before sorting: [43, -82, -8, 60, 77, 64]
# After sorting: [-82, -8, 43, 60, 64, 77]
# Expected result: [-82, -8, 43, 60, 64, 77]
#
# #42 Loop (already passed: 41/100)
# Before sorting: [-96, 14, -21, -87, -43, -67, 46, 55]
# After sorting: [-96, -87, -67, -43, -21, 14, 46, 55]
# Expected result: [-96, -87, -67, -43, -21, 14, 46, 55]
#
# #43 Loop (already passed: 42/100)
# Before sorting: [16, 49, -78, -62, -27, 11, -5, 38, 50, 48, -45, -52, 81]
# After sorting: [-78, -62, -52, -45, -27, -5, 11, 16, 38, 48, 49, 50, 81]
# Expected result: [-78, -62, -52, -45, -27, -5, 11, 16, 38, 48, 49, 50, 81]
#
# #44 Loop (already passed: 43/100)
# Before sorting: [28, 35, -49, -35, 99, -87, 24, 36, -95]
# After sorting: [-95, -87, -49, -35, 24, 28, 35, 36, 99]
# Expected result: [-95, -87, -49, -35, 24, 28, 35, 36, 99]
#
# #45 Loop (already passed: 44/100)
# Before sorting: [-23, 43, -36, -73, 76, -80]
# After sorting: [-80, -73, -36, -23, 43, 76]
# Expected result: [-80, -73, -36, -23, 43, 76]
#
# #46 Loop (already passed: 45/100)
# Before sorting: [66, 4, 7, 38, 84, -50, -60, 74, 66]
# After sorting: [-60, -50, 4, 7, 38, 66, 66, 74, 84]
# Expected result: [-60, -50, 4, 7, 38, 66, 66, 74, 84]
#
# #47 Loop (already passed: 46/100)
# Before sorting: [11, -26, 23, 78, 93, -59]
# After sorting: [-59, -26, 11, 23, 78, 93]
# Expected result: [-59, -26, 11, 23, 78, 93]
#
# #48 Loop (already passed: 47/100)
# Before sorting: [-65, -73, -63, 91, 28, -85, 21, -9, -69, -42, 86, 48, -82]
# After sorting: [-85, -82, -73, -69, -65, -63, -42, -9, 21, 28, 48, 86, 91]
# Expected result: [-85, -82, -73, -69, -65, -63, -42, -9, 21, 28, 48, 86, 91]
#
# #49 Loop (already passed: 48/100)
# Before sorting: [-97, 45, -84, -2, -8, 9, -17, 88, -3, 18, 21, 6, 53, 78]
# After sorting: [-97, -84, -17, -8, -3, -2, 6, 9, 18, 21, 45, 53, 78, 88]
# Expected result: [-97, -84, -17, -8, -3, -2, 6, 9, 18, 21, 45, 53, 78, 88]
#
# #50 Loop (already passed: 49/100)
# Before sorting: [18, -4, 88, 62, 1, 43, 95, -3, -1, 85, 97, 91]
# After sorting: [-4, -3, -1, 1, 18, 43, 62, 85, 88, 91, 95, 97]
# Expected result: [-4, -3, -1, 1, 18, 43, 62, 85, 88, 91, 95, 97]
#
# #51 Loop (already passed: 50/100)
# Before sorting: [95, 39, -77, 94, 41, -89, -10, -77, 32, 64, -34, 4, -41, -9]
# After sorting: [-89, -77, -77, -41, -34, -10, -9, 4, 32, 39, 41, 64, 94, 95]
# Expected result: [-89, -77, -77, -41, -34, -10, -9, 4, 32, 39, 41, 64, 94, 95]
#
# #52 Loop (already passed: 51/100)
# Before sorting: [-11, 64, 78, 39, 84, -88, 49, -62]
# After sorting: [-88, -62, -11, 39, 49, 64, 78, 84]
# Expected result: [-88, -62, -11, 39, 49, 64, 78, 84]
#
# #53 Loop (already passed: 52/100)
# Before sorting: [-1, -51, 19, 69, 85, 3, 59, 77, 30]
# After sorting: [-51, -1, 3, 19, 30, 59, 69, 77, 85]
# Expected result: [-51, -1, 3, 19, 30, 59, 69, 77, 85]
#
# #54 Loop (already passed: 53/100)
# Before sorting: [-27, 14, -67, -77, -46, -58, -28, 51, 4, -9]
# After sorting: [-77, -67, -58, -46, -28, -27, -9, 4, 14, 51]
# Expected result: [-77, -67, -58, -46, -28, -27, -9, 4, 14, 51]
#
# #55 Loop (already passed: 54/100)
# Before sorting: [-83, -60, 38, 45, -52, 27, 8, 3]
# After sorting: [-83, -60, -52, 3, 8, 27, 38, 45]
# Expected result: [-83, -60, -52, 3, 8, 27, 38, 45]
#
# #56 Loop (already passed: 55/100)
# Before sorting: [-65, -81, 59, -27, 27]
# After sorting: [-81, -65, -27, 27, 59]
# Expected result: [-81, -65, -27, 27, 59]
#
# #57 Loop (already passed: 56/100)
# Before sorting: [-52, -11, 47, 67, 13, -99, -84, 95, -82, -76, 75, 59, -14, -83, -100]
# After sorting: [-100, -99, -84, -83, -82, -76, -52, -14, -11, 13, 47, 59, 67, 75, 95]
# Expected result: [-100, -99, -84, -83, -82, -76, -52, -14, -11, 13, 47, 59, 67, 75, 95]
#
# #58 Loop (already passed: 57/100)
# Before sorting: [88, -39, 98, 92, 52, -14, -93, -34, 77, 28, -88, 78]
# After sorting: [-93, -88, -39, -34, -14, 28, 52, 77, 78, 88, 92, 98]
# Expected result: [-93, -88, -39, -34, -14, 28, 52, 77, 78, 88, 92, 98]
#
# #59 Loop (already passed: 58/100)
# Before sorting: [-74, 27, 59, -74, -60, 18, 76, 72, -78, 10]
# After sorting: [-78, -74, -74, -60, 10, 18, 27, 59, 72, 76]
# Expected result: [-78, -74, -74, -60, 10, 18, 27, 59, 72, 76]
#
# #60 Loop (already passed: 59/100)
# Before sorting: [-89, -63, 59, -39, 77, -51, 46, 21, -1, 49]
# After sorting: [-89, -63, -51, -39, -1, 21, 46, 49, 59, 77]
# Expected result: [-89, -63, -51, -39, -1, 21, 46, 49, 59, 77]
#
# #61 Loop (already passed: 60/100)
# Before sorting: [-2, -18, 32, -56, -54, 70, -57, 1, -51, -86, 79]
# After sorting: [-86, -57, -56, -54, -51, -18, -2, 1, 32, 70, 79]
# Expected result: [-86, -57, -56, -54, -51, -18, -2, 1, 32, 70, 79]
#
# #62 Loop (already passed: 61/100)
# Before sorting: [-61, -8, 48, -23, -75, -62, 44, 44, -5, 32, 80, -11]
# After sorting: [-75, -62, -61, -23, -11, -8, -5, 32, 44, 44, 48, 80]
# Expected result: [-75, -62, -61, -23, -11, -8, -5, 32, 44, 44, 48, 80]
#
# #63 Loop (already passed: 62/100)
# Before sorting: [-86, 11, -14, -18, 15, 25, -27, -23, 55, 90]
# After sorting: [-86, -27, -23, -18, -14, 11, 15, 25, 55, 90]
# Expected result: [-86, -27, -23, -18, -14, 11, 15, 25, 55, 90]
#
# #64 Loop (already passed: 63/100)
# Before sorting: [11, -48, 77, 24, 72, 63, -19, -29]
# After sorting: [-48, -29, -19, 11, 24, 63, 72, 77]
# Expected result: [-48, -29, -19, 11, 24, 63, 72, 77]
#
# #65 Loop (already passed: 64/100)
# Before sorting: [3, -75, 36, -84, -27, 5, -5, 0, -50, 100, -58, -36]
# After sorting: [-84, -75, -58, -50, -36, -27, -5, 0, 3, 5, 36, 100]
# Expected result: [-84, -75, -58, -50, -36, -27, -5, 0, 3, 5, 36, 100]
#
# #66 Loop (already passed: 65/100)
# Before sorting: [-79, 56, -6, 9, 71, 59, -47, 38]
# After sorting: [-79, -47, -6, 9, 38, 56, 59, 71]
# Expected result: [-79, -47, -6, 9, 38, 56, 59, 71]
#
# #67 Loop (already passed: 66/100)
# Before sorting: [85, -4, -74, 68, -40, -89, 5, 41, 15]
# After sorting: [-89, -74, -40, -4, 5, 15, 41, 68, 85]
# Expected result: [-89, -74, -40, -4, 5, 15, 41, 68, 85]
#
# #68 Loop (already passed: 67/100)
# Before sorting: [-80, -84, 92, 7, 2]
# After sorting: [-84, -80, 2, 7, 92]
# Expected result: [-84, -80, 2, 7, 92]
#
# #69 Loop (already passed: 68/100)
# Before sorting: [19, 32, -8, 8, -1, 91, 28, 3, -10, -33, 96, -61, -26, 45, 91]
# After sorting: [-61, -33, -26, -10, -8, -1, 3, 8, 19, 28, 32, 45, 91, 91, 96]
# Expected result: [-61, -33, -26, -10, -8, -1, 3, 8, 19, 28, 32, 45, 91, 91, 96]
#
# #70 Loop (already passed: 69/100)
# Before sorting: [1, -67, 97, -38, 61, -41, 41, -30, 85, 19]
# After sorting: [-67, -41, -38, -30, 1, 19, 41, 61, 85, 97]
# Expected result: [-67, -41, -38, -30, 1, 19, 41, 61, 85, 97]
#
# #71 Loop (already passed: 70/100)
# Before sorting: [-54, 39, 33, 47, -14, 79, -57, -45, 27, -27]
# After sorting: [-57, -54, -45, -27, -14, 27, 33, 39, 47, 79]
# Expected result: [-57, -54, -45, -27, -14, 27, 33, 39, 47, 79]
#
# #72 Loop (already passed: 71/100)
# Before sorting: [-84, 91, 78, 73, -18, 78, 41, 100, -17, -2, 83, -61, 35, 56, 44]
# After sorting: [-84, -61, -18, -17, -2, 35, 41, 44, 56, 73, 78, 78, 83, 91, 100]
# Expected result: [-84, -61, -18, -17, -2, 35, 41, 44, 56, 73, 78, 78, 83, 91, 100]
#
# #73 Loop (already passed: 72/100)
# Before sorting: [64, -24, -39, -53, -39, 99]
# After sorting: [-53, -39, -39, -24, 64, 99]
# Expected result: [-53, -39, -39, -24, 64, 99]
#
# #74 Loop (already passed: 73/100)
# Before sorting: [85, 61, -84, -61, -36, 21, -92, 80, 16, -77, -46, 65]
# After sorting: [-92, -84, -77, -61, -46, -36, 16, 21, 61, 65, 80, 85]
# Expected result: [-92, -84, -77, -61, -46, -36, 16, 21, 61, 65, 80, 85]
#
# #75 Loop (already passed: 74/100)
# Before sorting: [79, 9, -95, 25, -71]
# After sorting: [-95, -71, 9, 25, 79]
# Expected result: [-95, -71, 9, 25, 79]
#
# #76 Loop (already passed: 75/100)
# Before sorting: [93, -20, 52, 6, 93, 65]
# After sorting: [-20, 6, 52, 65, 93, 93]
# Expected result: [-20, 6, 52, 65, 93, 93]
#
# #77 Loop (already passed: 76/100)
# Before sorting: [-78, 57, -74, 96, 73, -66, 60, 99]
# After sorting: [-78, -74, -66, 57, 60, 73, 96, 99]
# Expected result: [-78, -74, -66, 57, 60, 73, 96, 99]
#
# #78 Loop (already passed: 77/100)
# Before sorting: [-55, -87, -27, -27, -39, 36, 25, 6, -96, 16, 45, 70, 41]
# After sorting: [-96, -87, -55, -39, -27, -27, 6, 16, 25, 36, 41, 45, 70]
# Expected result: [-96, -87, -55, -39, -27, -27, 6, 16, 25, 36, 41, 45, 70]
#
# #79 Loop (already passed: 78/100)
# Before sorting: [43, 63, 97, 12, -15, 80, 65, 7, -55, -52, 8, -49]
# After sorting: [-55, -52, -49, -15, 7, 8, 12, 43, 63, 65, 80, 97]
# Expected result: [-55, -52, -49, -15, 7, 8, 12, 43, 63, 65, 80, 97]
#
# #80 Loop (already passed: 79/100)
# Before sorting: [90, -75, 94, 73, -51, -79, 94, -62, 97]
# After sorting: [-79, -75, -62, -51, 73, 90, 94, 94, 97]
# Expected result: [-79, -75, -62, -51, 73, 90, 94, 94, 97]
#
# #81 Loop (already passed: 80/100)
# Before sorting: [42, 42, 89, -16, -45, -65]
# After sorting: [-65, -45, -16, 42, 42, 89]
# Expected result: [-65, -45, -16, 42, 42, 89]
#
# #82 Loop (already passed: 81/100)
# Before sorting: [76, -50, 100, -66, -17, -9, -27, 68]
# After sorting: [-66, -50, -27, -17, -9, 68, 76, 100]
# Expected result: [-66, -50, -27, -17, -9, 68, 76, 100]
#
# #83 Loop (already passed: 82/100)
# Before sorting: [54, 67, 51, 43, -100]
# After sorting: [-100, 43, 51, 54, 67]
# Expected result: [-100, 43, 51, 54, 67]
#
# #84 Loop (already passed: 83/100)
# Before sorting: [16, 85, 79, -27, 47, 76]
# After sorting: [-27, 16, 47, 76, 79, 85]
# Expected result: [-27, 16, 47, 76, 79, 85]
#
# #85 Loop (already passed: 84/100)
# Before sorting: [64, 23, 19, -56, -4, -19, -85, 85, 26]
# After sorting: [-85, -56, -19, -4, 19, 23, 26, 64, 85]
# Expected result: [-85, -56, -19, -4, 19, 23, 26, 64, 85]
#
# #86 Loop (already passed: 85/100)
# Before sorting: [36, -4, -21, 65, 57, -45, 35, 42, -95, 16, 72, -8]
# After sorting: [-95, -45, -21, -8, -4, 16, 35, 36, 42, 57, 65, 72]
# Expected result: [-95, -45, -21, -8, -4, 16, 35, 36, 42, 57, 65, 72]
#
# #87 Loop (already passed: 86/100)
# Before sorting: [41, -41, 42, -20, -22, 42, 86]
# After sorting: [-41, -22, -20, 41, 42, 42, 86]
# Expected result: [-41, -22, -20, 41, 42, 42, 86]
#
# #88 Loop (already passed: 87/100)
# Before sorting: [-5, -40, 45, 0, -76, 47, 89]
# After sorting: [-76, -40, -5, 0, 45, 47, 89]
# Expected result: [-76, -40, -5, 0, 45, 47, 89]
#
# #89 Loop (already passed: 88/100)
# Before sorting: [94, 62, -4, -57, 38, 64, 44, -47, 59, 76, 87, 75]
# After sorting: [-57, -47, -4, 38, 44, 59, 62, 64, 75, 76, 87, 94]
# Expected result: [-57, -47, -4, 38, 44, 59, 62, 64, 75, 76, 87, 94]
#
# #90 Loop (already passed: 89/100)
# Before sorting: [-22, -66, 32, 72, -6, -17, 74]
# After sorting: [-66, -22, -17, -6, 32, 72, 74]
# Expected result: [-66, -22, -17, -6, 32, 72, 74]
#
# #91 Loop (already passed: 90/100)
# Before sorting: [54, 27, 31, -52, -99, -62]
# After sorting: [-99, -62, -52, 27, 31, 54]
# Expected result: [-99, -62, -52, 27, 31, 54]
#
# #92 Loop (already passed: 91/100)
# Before sorting: [5, -30, 91, -43, -17]
# After sorting: [-43, -30, -17, 5, 91]
# Expected result: [-43, -30, -17, 5, 91]
#
# #93 Loop (already passed: 92/100)
# Before sorting: [17, 48, 61, -44, 92, 58, -15]
# After sorting: [-44, -15, 17, 48, 58, 61, 92]
# Expected result: [-44, -15, 17, 48, 58, 61, 92]
#
# #94 Loop (already passed: 93/100)
# Before sorting: [-16, 93, -46, -32, -56, -69, -58, 16, 90, -31, 10, 83, -38, -97]
# After sorting: [-97, -69, -58, -56, -46, -38, -32, -31, -16, 10, 16, 83, 90, 93]
# Expected result: [-97, -69, -58, -56, -46, -38, -32, -31, -16, 10, 16, 83, 90, 93]
#
# #95 Loop (already passed: 94/100)
# Before sorting: [-47, -78, -71, -93, -11, -33, -56, 56, 7, -80, -37, -84, -53]
# After sorting: [-93, -84, -80, -78, -71, -56, -53, -47, -37, -33, -11, 7, 56]
# Expected result: [-93, -84, -80, -78, -71, -56, -53, -47, -37, -33, -11, 7, 56]
#
# #96 Loop (already passed: 95/100)
# Before sorting: [28, 0, 100, -83, -65, -56, -78, -51, 96, 71, -47, 54, -75]
# After sorting: [-83, -78, -75, -65, -56, -51, -47, 0, 28, 54, 71, 96, 100]
# Expected result: [-83, -78, -75, -65, -56, -51, -47, 0, 28, 54, 71, 96, 100]
#
# #97 Loop (already passed: 96/100)
# Before sorting: [64, 81, 99, -14, 1, -14, 79, -38]
# After sorting: [-38, -14, -14, 1, 64, 79, 81, 99]
# Expected result: [-38, -14, -14, 1, 64, 79, 81, 99]
#
# #98 Loop (already passed: 97/100)
# Before sorting: [14, -9, -39, -63, 91, 88, -70, -20, 48, -69, 1, -91]
# After sorting: [-91, -70, -69, -63, -39, -20, -9, 1, 14, 48, 88, 91]
# Expected result: [-91, -70, -69, -63, -39, -20, -9, 1, 14, 48, 88, 91]
#
# #99 Loop (already passed: 98/100)
# Before sorting: [-51, -11, 89, 60, -31, -14, 57, 29, 26, 54, -50, 14, 49, -63]
# After sorting: [-63, -51, -50, -31, -14, -11, 14, 26, 29, 49, 54, 57, 60, 89]
# Expected result: [-63, -51, -50, -31, -14, -11, 14, 26, 29, 49, 54, 57, 60, 89]
#
# #100 Loop (already passed: 99/100)
# Before sorting: [69, 8, -69, 6, -24, -71, -64, -26, -62, -48, 90, 56, -77, -100]
# After sorting: [-100, -77, -71, -69, -64, -62, -48, -26, -24, 6, 8, 56, 69, 90]
# Expected result: [-100, -77, -71, -69, -64, -62, -48, -26, -24, 6, 8, 56, 69, 90]
#
# Sorting algorithm is correct
# Passed tests in total: 100/100

# %% [markdown]
# ### Insertion Sort

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        j = i-1
        temp = arr[i]
        
        while j >= 0 and temp < arr[j]:
            arr[j+1] = arr[j]
            j -= 1
        
        arr[j+1] = temp

# %% [markdown]
# ###### Kilka testów

# %%
test_sort(insertion_sort, samples=100)
# Out:
# #1 Loop (already passed: 0/100)
# Before sorting: [-74, -9, -63, -16, -59, -47, 51, -19, -8, -52, -37, 22, -11, 84, -36]
# After sorting: [-74, -63, -59, -52, -47, -37, -36, -19, -16, -11, -9, -8, 22, 51, 84]
# Expected result: [-74, -63, -59, -52, -47, -37, -36, -19, -16, -11, -9, -8, 22, 51, 84]
#
# #2 Loop (already passed: 1/100)
# Before sorting: [100, 80, -23, -24, 71, 21, 83, -70, -63]
# After sorting: [-70, -63, -24, -23, 21, 71, 80, 83, 100]
# Expected result: [-70, -63, -24, -23, 21, 71, 80, 83, 100]
#
# #3 Loop (already passed: 2/100)
# Before sorting: [0, 35, -58, -7, 72, 20, -44, 30, 41, -27, 79, -58]
# After sorting: [-58, -58, -44, -27, -7, 0, 20, 30, 35, 41, 72, 79]
# Expected result: [-58, -58, -44, -27, -7, 0, 20, 30, 35, 41, 72, 79]
#
# #4 Loop (already passed: 3/100)
# Before sorting: [-88, 54, -6, 87, 94, 80, 97, -28, -77, -95, 2, -68, -16, 49, -5]
# After sorting: [-95, -88, -77, -68, -28, -16, -6, -5, 2, 49, 54, 80, 87, 94, 97]
# Expected result: [-95, -88, -77, -68, -28, -16, -6, -5, 2, 49, 54, 80, 87, 94, 97]
#
# #5 Loop (already passed: 4/100)
# Before sorting: [75, 5, -74, 67, -28, -99]
# After sorting: [-99, -74, -28, 5, 67, 75]
# Expected result: [-99, -74, -28, 5, 67, 75]
#
# #6 Loop (already passed: 5/100)
# Before sorting: [37, -100, 66, 9, -50, 49, -17, 93, -41, -11, -9]
# After sorting: [-100, -50, -41, -17, -11, -9, 9, 37, 49, 66, 93]
# Expected result: [-100, -50, -41, -17, -11, -9, 9, 37, 49, 66, 93]
#
# #7 Loop (already passed: 6/100)
# Before sorting: [100, 54, 29, 25, 80, 79]
# After sorting: [25, 29, 54, 79, 80, 100]
# Expected result: [25, 29, 54, 79, 80, 100]
#
# #8 Loop (already passed: 7/100)
# Before sorting: [-3, 87, 17, -65, -39, 53, -10, 87, -14, 69]
# After sorting: [-65, -39, -14, -10, -3, 17, 53, 69, 87, 87]
# Expected result: [-65, -39, -14, -10, -3, 17, 53, 69, 87, 87]
#
# #9 Loop (already passed: 8/100)
# Before sorting: [-97, 95, -74, -70, 66, 80, 86, -48, 24, 70]
# After sorting: [-97, -74, -70, -48, 24, 66, 70, 80, 86, 95]
# Expected result: [-97, -74, -70, -48, 24, 66, 70, 80, 86, 95]
#
# #10 Loop (already passed: 9/100)
# Before sorting: [63, 11, -77, -2, -13]
# After sorting: [-77, -13, -2, 11, 63]
# Expected result: [-77, -13, -2, 11, 63]
#
# #11 Loop (already passed: 10/100)
# Before sorting: [-55, -2, -7, 11, 93, 60, -88, -18, 5, 91, 56, -83, -93]
# After sorting: [-93, -88, -83, -55, -18, -7, -2, 5, 11, 56, 60, 91, 93]
# Expected result: [-93, -88, -83, -55, -18, -7, -2, 5, 11, 56, 60, 91, 93]
#
# #12 Loop (already passed: 11/100)
# Before sorting: [-26, 0, -34, -81, 8, 66, 58, -33, -63, 99, -60, -22, 19]
# After sorting: [-81, -63, -60, -34, -33, -26, -22, 0, 8, 19, 58, 66, 99]
# Expected result: [-81, -63, -60, -34, -33, -26, -22, 0, 8, 19, 58, 66, 99]
#
# #13 Loop (already passed: 12/100)
# Before sorting: [-53, -96, 59, 69, -76, 84, -37, -30, -11, -99, 15, 73, -72]
# After sorting: [-99, -96, -76, -72, -53, -37, -30, -11, 15, 59, 69, 73, 84]
# Expected result: [-99, -96, -76, -72, -53, -37, -30, -11, 15, 59, 69, 73, 84]
#
# #14 Loop (already passed: 13/100)
# Before sorting: [29, 93, -62, 28, 50, 13, -33, 28]
# After sorting: [-62, -33, 13, 28, 28, 29, 50, 93]
# Expected result: [-62, -33, 13, 28, 28, 29, 50, 93]
#
# #15 Loop (already passed: 14/100)
# Before sorting: [28, -20, -50, -2, -49, -81, 20]
# After sorting: [-81, -50, -49, -20, -2, 20, 28]
# Expected result: [-81, -50, -49, -20, -2, 20, 28]
#
# #16 Loop (already passed: 15/100)
# Before sorting: [96, -24, -31, -10, -52, 32, -57, -12, 90, -71, -62, 21, -70, 0, -15]
# After sorting: [-71, -70, -62, -57, -52, -31, -24, -15, -12, -10, 0, 21, 32, 90, 96]
# Expected result: [-71, -70, -62, -57, -52, -31, -24, -15, -12, -10, 0, 21, 32, 90, 96]
#
# #17 Loop (already passed: 16/100)
# Before sorting: [94, -90, -60, 52, -18, -48, 50, 80, -25]
# After sorting: [-90, -60, -48, -25, -18, 50, 52, 80, 94]
# Expected result: [-90, -60, -48, -25, -18, 50, 52, 80, 94]
#
# #18 Loop (already passed: 17/100)
# Before sorting: [-66, -73, -41, 33, -63, 32, 57, 25, 73, -26]
# After sorting: [-73, -66, -63, -41, -26, 25, 32, 33, 57, 73]
# Expected result: [-73, -66, -63, -41, -26, 25, 32, 33, 57, 73]
#
# #19 Loop (already passed: 18/100)
# Before sorting: [-38, -60, -70, -52, -13, 49, 30, 61, 46, 57, 72, -93, 18]
# After sorting: [-93, -70, -60, -52, -38, -13, 18, 30, 46, 49, 57, 61, 72]
# Expected result: [-93, -70, -60, -52, -38, -13, 18, 30, 46, 49, 57, 61, 72]
#
# #20 Loop (already passed: 19/100)
# Before sorting: [22, 42, 5, 43, -44, 12, -56, -100]
# After sorting: [-100, -56, -44, 5, 12, 22, 42, 43]
# Expected result: [-100, -56, -44, 5, 12, 22, 42, 43]
#
# #21 Loop (already passed: 20/100)
# Before sorting: [-69, 54, -7, 77, 10]
# After sorting: [-69, -7, 10, 54, 77]
# Expected result: [-69, -7, 10, 54, 77]
#
# #22 Loop (already passed: 21/100)
# Before sorting: [33, 78, -39, 29, 4, -26, -46, 48, 77, 49, -25, -45]
# After sorting: [-46, -45, -39, -26, -25, 4, 29, 33, 48, 49, 77, 78]
# Expected result: [-46, -45, -39, -26, -25, 4, 29, 33, 48, 49, 77, 78]
#
# #23 Loop (already passed: 22/100)
# Before sorting: [23, 1, -70, 30, -67, 7, -85, -46, 45, -97, 76, -90]
# After sorting: [-97, -90, -85, -70, -67, -46, 1, 7, 23, 30, 45, 76]
# Expected result: [-97, -90, -85, -70, -67, -46, 1, 7, 23, 30, 45, 76]
#
# #24 Loop (already passed: 23/100)
# Before sorting: [91, 13, -68, -14, -71]
# After sorting: [-71, -68, -14, 13, 91]
# Expected result: [-71, -68, -14, 13, 91]
#
# #25 Loop (already passed: 24/100)
# Before sorting: [97, -21, 49, -33, -58, 60, -82, -76, 35, 82, 19, -7, -11]
# After sorting: [-82, -76, -58, -33, -21, -11, -7, 19, 35, 49, 60, 82, 97]
# Expected result: [-82, -76, -58, -33, -21, -11, -7, 19, 35, 49, 60, 82, 97]
#
# #26 Loop (already passed: 25/100)
# Before sorting: [-30, -64, -70, -94, -78, 11, -15, 34, 41, 89, 95, 98, -52, 45, -36]
# After sorting: [-94, -78, -70, -64, -52, -36, -30, -15, 11, 34, 41, 45, 89, 95, 98]
# Expected result: [-94, -78, -70, -64, -52, -36, -30, -15, 11, 34, 41, 45, 89, 95, 98]
#
# #27 Loop (already passed: 26/100)
# Before sorting: [-82, 29, 38, -22, -4]
# After sorting: [-82, -22, -4, 29, 38]
# Expected result: [-82, -22, -4, 29, 38]
#
# #28 Loop (already passed: 27/100)
# Before sorting: [78, -31, -21, 17, -40, 89, 12, 25, -66, 67, 27]
# After sorting: [-66, -40, -31, -21, 12, 17, 25, 27, 67, 78, 89]
# Expected result: [-66, -40, -31, -21, 12, 17, 25, 27, 67, 78, 89]
#
# #29 Loop (already passed: 28/100)
# Before sorting: [50, 63, 5, -15, -48, 42, -19, 42]
# After sorting: [-48, -19, -15, 5, 42, 42, 50, 63]
# Expected result: [-48, -19, -15, 5, 42, 42, 50, 63]
#
# #30 Loop (already passed: 29/100)
# Before sorting: [40, -54, 70, -98, 73, -13, 87, -60, 30, 13, 66, 26]
# After sorting: [-98, -60, -54, -13, 13, 26, 30, 40, 66, 70, 73, 87]
# Expected result: [-98, -60, -54, -13, 13, 26, 30, 40, 66, 70, 73, 87]
#
# #31 Loop (already passed: 30/100)
# Before sorting: [-47, -65, -17, -27, 33, 44]
# After sorting: [-65, -47, -27, -17, 33, 44]
# Expected result: [-65, -47, -27, -17, 33, 44]
#
# #32 Loop (already passed: 31/100)
# Before sorting: [62, -73, -49, -90, 41, 41, -46, 0, -8, -19]
# After sorting: [-90, -73, -49, -46, -19, -8, 0, 41, 41, 62]
# Expected result: [-90, -73, -49, -46, -19, -8, 0, 41, 41, 62]
#
# #33 Loop (already passed: 32/100)
# Before sorting: [-42, -84, -36, -42, 85, -100]
# After sorting: [-100, -84, -42, -42, -36, 85]
# Expected result: [-100, -84, -42, -42, -36, 85]
#
# #34 Loop (already passed: 33/100)
# Before sorting: [40, 93, -4, -82, -18]
# After sorting: [-82, -18, -4, 40, 93]
# Expected result: [-82, -18, -4, 40, 93]
#
# #35 Loop (already passed: 34/100)
# Before sorting: [44, -10, -51, 14, 78, 36, 25, 93]
# After sorting: [-51, -10, 14, 25, 36, 44, 78, 93]
# Expected result: [-51, -10, 14, 25, 36, 44, 78, 93]
#
# #36 Loop (already passed: 35/100)
# Before sorting: [69, -36, 15, 77, 3, 91, 94, 30, -21, 100, 25, 9]
# After sorting: [-36, -21, 3, 9, 15, 25, 30, 69, 77, 91, 94, 100]
# Expected result: [-36, -21, 3, 9, 15, 25, 30, 69, 77, 91, 94, 100]
#
# #37 Loop (already passed: 36/100)
# Before sorting: [17, -80, -16, -70, 34, 44, 23, -99, 21, 53, 81, 44, -17, -61]
# After sorting: [-99, -80, -70, -61, -17, -16, 17, 21, 23, 34, 44, 44, 53, 81]
# Expected result: [-99, -80, -70, -61, -17, -16, 17, 21, 23, 34, 44, 44, 53, 81]
#
# #38 Loop (already passed: 37/100)
# Before sorting: [76, -41, 10, -60, -7, 69, 80, 23, -98, -13, 93, -58, -69, -36]
# After sorting: [-98, -69, -60, -58, -41, -36, -13, -7, 10, 23, 69, 76, 80, 93]
# Expected result: [-98, -69, -60, -58, -41, -36, -13, -7, 10, 23, 69, 76, 80, 93]
#
# #39 Loop (already passed: 38/100)
# Before sorting: [-82, -50, -44, 45, 52, 62, 50, 14, -67, -85, 55, -73, 86]
# After sorting: [-85, -82, -73, -67, -50, -44, 14, 45, 50, 52, 55, 62, 86]
# Expected result: [-85, -82, -73, -67, -50, -44, 14, 45, 50, 52, 55, 62, 86]
#
# #40 Loop (already passed: 39/100)
# Before sorting: [-54, -73, 14, -36, -5, -78]
# After sorting: [-78, -73, -54, -36, -5, 14]
# Expected result: [-78, -73, -54, -36, -5, 14]
#
# #41 Loop (already passed: 40/100)
# Before sorting: [-67, 98, -78, -87, -5, -11, -16, -11, 25, -29, -100, 96, -3, 100, 12]
# After sorting: [-100, -87, -78, -67, -29, -16, -11, -11, -5, -3, 12, 25, 96, 98, 100]
# Expected result: [-100, -87, -78, -67, -29, -16, -11, -11, -5, -3, 12, 25, 96, 98, 100]
#
# #42 Loop (already passed: 41/100)
# Before sorting: [-65, 43, -93, -36, 58, -82, 35, -19, 44, -89, -50, -61, 37, -76, -39]
# After sorting: [-93, -89, -82, -76, -65, -61, -50, -39, -36, -19, 35, 37, 43, 44, 58]
# Expected result: [-93, -89, -82, -76, -65, -61, -50, -39, -36, -19, 35, 37, 43, 44, 58]
#
# #43 Loop (already passed: 42/100)
# Before sorting: [69, 7, 39, 24, -45, -37, 3, 40, -69, 44, 54, 84, -32, -22, 23]
# After sorting: [-69, -45, -37, -32, -22, 3, 7, 23, 24, 39, 40, 44, 54, 69, 84]
# Expected result: [-69, -45, -37, -32, -22, 3, 7, 23, 24, 39, 40, 44, 54, 69, 84]
#
# #44 Loop (already passed: 43/100)
# Before sorting: [60, -55, -29, 50, 52]
# After sorting: [-55, -29, 50, 52, 60]
# Expected result: [-55, -29, 50, 52, 60]
#
# #45 Loop (already passed: 44/100)
# Before sorting: [18, 72, 5, 88, -68, 30, -3, -41, 82, 40, 98]
# After sorting: [-68, -41, -3, 5, 18, 30, 40, 72, 82, 88, 98]
# Expected result: [-68, -41, -3, 5, 18, 30, 40, 72, 82, 88, 98]
#
# #46 Loop (already passed: 45/100)
# Before sorting: [94, -7, -36, 52, 47, 61, -89, -42, 21, -50, 44]
# After sorting: [-89, -50, -42, -36, -7, 21, 44, 47, 52, 61, 94]
# Expected result: [-89, -50, -42, -36, -7, 21, 44, 47, 52, 61, 94]
#
# #47 Loop (already passed: 46/100)
# Before sorting: [75, 2, -83, -80, 9]
# After sorting: [-83, -80, 2, 9, 75]
# Expected result: [-83, -80, 2, 9, 75]
#
# #48 Loop (already passed: 47/100)
# Before sorting: [0, -30, 84, -94, -2, -59, 78, -38, -16, 88, -83, 82, -56, -92, -67]
# After sorting: [-94, -92, -83, -67, -59, -56, -38, -30, -16, -2, 0, 78, 82, 84, 88]
# Expected result: [-94, -92, -83, -67, -59, -56, -38, -30, -16, -2, 0, 78, 82, 84, 88]
#
# #49 Loop (already passed: 48/100)
# Before sorting: [-68, -38, -27, -50, -84, 10, -62, -43, 60]
# After sorting: [-84, -68, -62, -50, -43, -38, -27, 10, 60]
# Expected result: [-84, -68, -62, -50, -43, -38, -27, 10, 60]
#
# #50 Loop (already passed: 49/100)
# Before sorting: [90, 6, -22, -76, -58, 4, -24, -60, 60, -67, -27]
# After sorting: [-76, -67, -60, -58, -27, -24, -22, 4, 6, 60, 90]
# Expected result: [-76, -67, -60, -58, -27, -24, -22, 4, 6, 60, 90]
#
# #51 Loop (already passed: 50/100)
# Before sorting: [73, -24, -49, 25, -8, 54, -26, 30, 16, 22, -31, -7]
# After sorting: [-49, -31, -26, -24, -8, -7, 16, 22, 25, 30, 54, 73]
# Expected result: [-49, -31, -26, -24, -8, -7, 16, 22, 25, 30, 54, 73]
#
# #52 Loop (already passed: 51/100)
# Before sorting: [-67, -2, -32, -97, 5, 2, -99, 91, 17, 44, -7, 13]
# After sorting: [-99, -97, -67, -32, -7, -2, 2, 5, 13, 17, 44, 91]
# Expected result: [-99, -97, -67, -32, -7, -2, 2, 5, 13, 17, 44, 91]
#
# #53 Loop (already passed: 52/100)
# Before sorting: [51, 63, -82, -2, -81, -96, 81, -28, 83, 3, -63, -49, -3, 0, 13]
# After sorting: [-96, -82, -81, -63, -49, -28, -3, -2, 0, 3, 13, 51, 63, 81, 83]
# Expected result: [-96, -82, -81, -63, -49, -28, -3, -2, 0, 3, 13, 51, 63, 81, 83]
#
# #54 Loop (already passed: 53/100)
# Before sorting: [4, 79, 10, -33, -20, 59, 95, -36, -17, -24, -70, -68]
# After sorting: [-70, -68, -36, -33, -24, -20, -17, 4, 10, 59, 79, 95]
# Expected result: [-70, -68, -36, -33, -24, -20, -17, 4, 10, 59, 79, 95]
#
# #55 Loop (already passed: 54/100)
# Before sorting: [92, -60, 42, -85, 41, 99, -25, 51, 40, -17, -16, 43, -75]
# After sorting: [-85, -75, -60, -25, -17, -16, 40, 41, 42, 43, 51, 92, 99]
# Expected result: [-85, -75, -60, -25, -17, -16, 40, 41, 42, 43, 51, 92, 99]
#
# #56 Loop (already passed: 55/100)
# Before sorting: [-4, 76, 23, -94, 37, -31, -61, -63, 79, 57, -35, 22]
# After sorting: [-94, -63, -61, -35, -31, -4, 22, 23, 37, 57, 76, 79]
# Expected result: [-94, -63, -61, -35, -31, -4, 22, 23, 37, 57, 76, 79]
#
# #57 Loop (already passed: 56/100)
# Before sorting: [-52, 5, -37, 69, 28, -47, -93, 85, -8, -18, 73, -9, -86, -53, -65]
# After sorting: [-93, -86, -65, -53, -52, -47, -37, -18, -9, -8, 5, 28, 69, 73, 85]
# Expected result: [-93, -86, -65, -53, -52, -47, -37, -18, -9, -8, 5, 28, 69, 73, 85]
#
# #58 Loop (already passed: 57/100)
# Before sorting: [-83, 19, -55, 43, 80, -1, -29, 5, 23, 47]
# After sorting: [-83, -55, -29, -1, 5, 19, 23, 43, 47, 80]
# Expected result: [-83, -55, -29, -1, 5, 19, 23, 43, 47, 80]
#
# #59 Loop (already passed: 58/100)
# Before sorting: [-76, 7, -59, -9, 70, 57, -22, 23, 55, 1, 8, 89, 13, 39, -81]
# After sorting: [-81, -76, -59, -22, -9, 1, 7, 8, 13, 23, 39, 55, 57, 70, 89]
# Expected result: [-81, -76, -59, -22, -9, 1, 7, 8, 13, 23, 39, 55, 57, 70, 89]
#
# #60 Loop (already passed: 59/100)
# Before sorting: [-3, -29, -58, 7, -70, 41, 57, 87, -59, 39, 56, 74, -9, -74, -18]
# After sorting: [-74, -70, -59, -58, -29, -18, -9, -3, 7, 39, 41, 56, 57, 74, 87]
# Expected result: [-74, -70, -59, -58, -29, -18, -9, -3, 7, 39, 41, 56, 57, 74, 87]
#
# #61 Loop (already passed: 60/100)
# Before sorting: [-10, -22, -26, -85, 76, 69, -29, -19, 50, -94]
# After sorting: [-94, -85, -29, -26, -22, -19, -10, 50, 69, 76]
# Expected result: [-94, -85, -29, -26, -22, -19, -10, 50, 69, 76]
#
# #62 Loop (already passed: 61/100)
# Before sorting: [18, 41, -81, 42, 75, 35, 4, 36, 99, 81, 95, 44, -24]
# After sorting: [-81, -24, 4, 18, 35, 36, 41, 42, 44, 75, 81, 95, 99]
# Expected result: [-81, -24, 4, 18, 35, 36, 41, 42, 44, 75, 81, 95, 99]
#
# #63 Loop (already passed: 62/100)
# Before sorting: [20, -40, -17, -11, -16, 10, 0]
# After sorting: [-40, -17, -16, -11, 0, 10, 20]
# Expected result: [-40, -17, -16, -11, 0, 10, 20]
#
# #64 Loop (already passed: 63/100)
# Before sorting: [65, 31, 25, 22, 5, 88]
# After sorting: [5, 22, 25, 31, 65, 88]
# Expected result: [5, 22, 25, 31, 65, 88]
#
# #65 Loop (already passed: 64/100)
# Before sorting: [-95, 51, -79, 14, -31, 38]
# After sorting: [-95, -79, -31, 14, 38, 51]
# Expected result: [-95, -79, -31, 14, 38, 51]
#
# #66 Loop (already passed: 65/100)
# Before sorting: [38, 33, 31, 56, 28, -68, 94, 69, 7, 59]
# After sorting: [-68, 7, 28, 31, 33, 38, 56, 59, 69, 94]
# Expected result: [-68, 7, 28, 31, 33, 38, 56, 59, 69, 94]
#
# #67 Loop (already passed: 66/100)
# Before sorting: [-49, -24, -36, -74, -35, 6, -5, -75, 56, 70, 54, 14, 24]
# After sorting: [-75, -74, -49, -36, -35, -24, -5, 6, 14, 24, 54, 56, 70]
# Expected result: [-75, -74, -49, -36, -35, -24, -5, 6, 14, 24, 54, 56, 70]
#
# #68 Loop (already passed: 67/100)
# Before sorting: [67, -20, 50, 45, 62]
# After sorting: [-20, 45, 50, 62, 67]
# Expected result: [-20, 45, 50, 62, 67]
#
# #69 Loop (already passed: 68/100)
# Before sorting: [-14, -98, 77, 37, -76, -44, -57, -29, 37, 28]
# After sorting: [-98, -76, -57, -44, -29, -14, 28, 37, 37, 77]
# Expected result: [-98, -76, -57, -44, -29, -14, 28, 37, 37, 77]
#
# #70 Loop (already passed: 69/100)
# Before sorting: [54, 56, -23, -6, -77, -27, 60, 74, -29, 65]
# After sorting: [-77, -29, -27, -23, -6, 54, 56, 60, 65, 74]
# Expected result: [-77, -29, -27, -23, -6, 54, 56, 60, 65, 74]
#
# #71 Loop (already passed: 70/100)
# Before sorting: [38, -16, 67, 64, -99, 68, -27, -55, -32, -70, -88, -11, 57, -20]
# After sorting: [-99, -88, -70, -55, -32, -27, -20, -16, -11, 38, 57, 64, 67, 68]
# Expected result: [-99, -88, -70, -55, -32, -27, -20, -16, -11, 38, 57, 64, 67, 68]
#
# #72 Loop (already passed: 71/100)
# Before sorting: [84, -92, -76, 79, -76, -91]
# After sorting: [-92, -91, -76, -76, 79, 84]
# Expected result: [-92, -91, -76, -76, 79, 84]
#
# #73 Loop (already passed: 72/100)
# Before sorting: [-19, -25, -8, 68, 94, -94]
# After sorting: [-94, -25, -19, -8, 68, 94]
# Expected result: [-94, -25, -19, -8, 68, 94]
#
# #74 Loop (already passed: 73/100)
# Before sorting: [73, -69, 57, 56, -74, -87, -24, -72, -50, -57, 42, -66, -63]
# After sorting: [-87, -74, -72, -69, -66, -63, -57, -50, -24, 42, 56, 57, 73]
# Expected result: [-87, -74, -72, -69, -66, -63, -57, -50, -24, 42, 56, 57, 73]
#
# #75 Loop (already passed: 74/100)
# Before sorting: [-28, -74, -50, 93, 55]
# After sorting: [-74, -50, -28, 55, 93]
# Expected result: [-74, -50, -28, 55, 93]
#
# #76 Loop (already passed: 75/100)
# Before sorting: [-81, 74, -73, -63, 59, 7, 46, -85, -93, 55, 33, 81, 13]
# After sorting: [-93, -85, -81, -73, -63, 7, 13, 33, 46, 55, 59, 74, 81]
# Expected result: [-93, -85, -81, -73, -63, 7, 13, 33, 46, 55, 59, 74, 81]
#
# #77 Loop (already passed: 76/100)
# Before sorting: [9, 61, 46, -34, 16, -9]
# After sorting: [-34, -9, 9, 16, 46, 61]
# Expected result: [-34, -9, 9, 16, 46, 61]
#
# #78 Loop (already passed: 77/100)
# Before sorting: [32, 14, -1, 76, -86, -36, 85, -51]
# After sorting: [-86, -51, -36, -1, 14, 32, 76, 85]
# Expected result: [-86, -51, -36, -1, 14, 32, 76, 85]
#
# #79 Loop (already passed: 78/100)
# Before sorting: [78, 77, -25, 43, -88, 18, 2, -45, -20]
# After sorting: [-88, -45, -25, -20, 2, 18, 43, 77, 78]
# Expected result: [-88, -45, -25, -20, 2, 18, 43, 77, 78]
#
# #80 Loop (already passed: 79/100)
# Before sorting: [47, 29, -25, -51, 25, 46]
# After sorting: [-51, -25, 25, 29, 46, 47]
# Expected result: [-51, -25, 25, 29, 46, 47]
#
# #81 Loop (already passed: 80/100)
# Before sorting: [45, 5, 19, -28, 87, 33, 0, -58, 81, -18, -43, -63]
# After sorting: [-63, -58, -43, -28, -18, 0, 5, 19, 33, 45, 81, 87]
# Expected result: [-63, -58, -43, -28, -18, 0, 5, 19, 33, 45, 81, 87]
#
# #82 Loop (already passed: 81/100)
# Before sorting: [10, 25, -87, 77, -52, 29, -81, 58]
# After sorting: [-87, -81, -52, 10, 25, 29, 58, 77]
# Expected result: [-87, -81, -52, 10, 25, 29, 58, 77]
#
# #83 Loop (already passed: 82/100)
# Before sorting: [9, 56, -22, 4, -97, 78, 5]
# After sorting: [-97, -22, 4, 5, 9, 56, 78]
# Expected result: [-97, -22, 4, 5, 9, 56, 78]
#
# #84 Loop (already passed: 83/100)
# Before sorting: [-95, 19, -27, -6, 29]
# After sorting: [-95, -27, -6, 19, 29]
# Expected result: [-95, -27, -6, 19, 29]
#
# #85 Loop (already passed: 84/100)
# Before sorting: [22, -72, -4, 51, -55, 65]
# After sorting: [-72, -55, -4, 22, 51, 65]
# Expected result: [-72, -55, -4, 22, 51, 65]
#
# #86 Loop (already passed: 85/100)
# Before sorting: [-3, -72, -49, -87, 60, -49, -22, -9, 70, -1, -20]
# After sorting: [-87, -72, -49, -49, -22, -20, -9, -3, -1, 60, 70]
# Expected result: [-87, -72, -49, -49, -22, -20, -9, -3, -1, 60, 70]
#
# #87 Loop (already passed: 86/100)
# Before sorting: [55, 78, 15, 60, 3, -28, 30, -51, 28, -21, -19, -99]
# After sorting: [-99, -51, -28, -21, -19, 3, 15, 28, 30, 55, 60, 78]
# Expected result: [-99, -51, -28, -21, -19, 3, 15, 28, 30, 55, 60, 78]
#
# #88 Loop (already passed: 87/100)
# Before sorting: [-23, -7, -1, 43, -88, -27, 91, 75, 30, 82, -66, -43, -60]
# After sorting: [-88, -66, -60, -43, -27, -23, -7, -1, 30, 43, 75, 82, 91]
# Expected result: [-88, -66, -60, -43, -27, -23, -7, -1, 30, 43, 75, 82, 91]
#
# #89 Loop (already passed: 88/100)
# Before sorting: [-23, 7, -78, 58, 0, -22, -26, 74, 50, 25]
# After sorting: [-78, -26, -23, -22, 0, 7, 25, 50, 58, 74]
# Expected result: [-78, -26, -23, -22, 0, 7, 25, 50, 58, 74]
#
# #90 Loop (already passed: 89/100)
# Before sorting: [-25, -20, -14, 54, -13, -17, 41, -46, -93, 1]
# After sorting: [-93, -46, -25, -20, -17, -14, -13, 1, 41, 54]
# Expected result: [-93, -46, -25, -20, -17, -14, -13, 1, 41, 54]
#
# #91 Loop (already passed: 90/100)
# Before sorting: [82, 97, -19, 1, 85, -70, -69, -34, -17, 12, -33, -44]
# After sorting: [-70, -69, -44, -34, -33, -19, -17, 1, 12, 82, 85, 97]
# Expected result: [-70, -69, -44, -34, -33, -19, -17, 1, 12, 82, 85, 97]
#
# #92 Loop (already passed: 91/100)
# Before sorting: [-82, -96, -42, 57, -65, 73, -53, -90, -10, 88, 81, 32]
# After sorting: [-96, -90, -82, -65, -53, -42, -10, 32, 57, 73, 81, 88]
# Expected result: [-96, -90, -82, -65, -53, -42, -10, 32, 57, 73, 81, 88]
#
# #93 Loop (already passed: 92/100)
# Before sorting: [53, 90, 97, 52, 78, -20, 73, -41, 31, -1, -29, 35, -92, -23]
# After sorting: [-92, -41, -29, -23, -20, -1, 31, 35, 52, 53, 73, 78, 90, 97]
# Expected result: [-92, -41, -29, -23, -20, -1, 31, 35, 52, 53, 73, 78, 90, 97]
#
# #94 Loop (already passed: 93/100)
# Before sorting: [-84, 90, -63, 43, 0, -80, -80, 91, -48]
# After sorting: [-84, -80, -80, -63, -48, 0, 43, 90, 91]
# Expected result: [-84, -80, -80, -63, -48, 0, 43, 90, 91]
#
# #95 Loop (already passed: 94/100)
# Before sorting: [-27, 97, 35, -12, 75, 1, 62, 82]
# After sorting: [-27, -12, 1, 35, 62, 75, 82, 97]
# Expected result: [-27, -12, 1, 35, 62, 75, 82, 97]
#
# #96 Loop (already passed: 95/100)
# Before sorting: [-44, 64, -44, 57, -22, 89, 85, 75, -43, 49]
# After sorting: [-44, -44, -43, -22, 49, 57, 64, 75, 85, 89]
# Expected result: [-44, -44, -43, -22, 49, 57, 64, 75, 85, 89]
#
# #97 Loop (already passed: 96/100)
# Before sorting: [-24, 49, 75, -88, -47, -100, -3, 85, 23, 78, -48]
# After sorting: [-100, -88, -48, -47, -24, -3, 23, 49, 75, 78, 85]
# Expected result: [-100, -88, -48, -47, -24, -3, 23, 49, 75, 78, 85]
#
# #98 Loop (already passed: 97/100)
# Before sorting: [-34, 22, -42, -12, -25, 33, -72]
# After sorting: [-72, -42, -34, -25, -12, 22, 33]
# Expected result: [-72, -42, -34, -25, -12, 22, 33]
#
# #99 Loop (already passed: 98/100)
# Before sorting: [-40, 79, -36, 94, 86, -34, -95, 95, 76, -97, 69, -89]
# After sorting: [-97, -95, -89, -40, -36, -34, 69, 76, 79, 86, 94, 95]
# Expected result: [-97, -95, -89, -40, -36, -34, 69, 76, 79, 86, 94, 95]
#
# #100 Loop (already passed: 99/100)
# Before sorting: [82, 81, -47, 38, -7, 89, -71, -2, -62, 52, -27, -14]
# After sorting: [-71, -62, -47, -27, -14, -7, -2, 38, 52, 81, 82, 89]
# Expected result: [-71, -62, -47, -27, -14, -7, -2, 38, 52, 81, 82, 89]
#
# Sorting algorithm is correct
# Passed tests in total: 100/100

# %% [markdown]
# ### Selection Sort

# %%
def selection_sort(arr):
    for i in range(len(arr)-1):
        min_idx = i
        for j in range(i+1, len(arr)):
            if arr[j] < arr[min_idx]: min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

# %% [markdown]
# ###### Kilka testów

# %%
test_sort(selection_sort, samples=100)
# Out:
# #1 Loop (already passed: 0/100)
# Before sorting: [-49, -20, 50, -73, 6, 75, 61, -71, 19, -78, 3, 59, 90]
# After sorting: [-78, -73, -71, -49, -20, 3, 6, 19, 50, 59, 61, 75, 90]
# Expected result: [-78, -73, -71, -49, -20, 3, 6, 19, 50, 59, 61, 75, 90]
#
# #2 Loop (already passed: 1/100)
# Before sorting: [-60, 88, 22, 73, 71, 10, -75, -87, -58, 85, -16, 17, 77, 53]
# After sorting: [-87, -75, -60, -58, -16, 10, 17, 22, 53, 71, 73, 77, 85, 88]
# Expected result: [-87, -75, -60, -58, -16, 10, 17, 22, 53, 71, 73, 77, 85, 88]
#
# #3 Loop (already passed: 2/100)
# Before sorting: [71, -48, -99, -34, -95, 32]
# After sorting: [-99, -95, -48, -34, 32, 71]
# Expected result: [-99, -95, -48, -34, 32, 71]
#
# #4 Loop (already passed: 3/100)
# Before sorting: [93, 6, 87, 40, -62, 3, 49, 12, -97]
# After sorting: [-97, -62, 3, 6, 12, 40, 49, 87, 93]
# Expected result: [-97, -62, 3, 6, 12, 40, 49, 87, 93]
#
# #5 Loop (already passed: 4/100)
# Before sorting: [16, 26, -55, 2, -6]
# After sorting: [-55, -6, 2, 16, 26]
# Expected result: [-55, -6, 2, 16, 26]
#
# #6 Loop (already passed: 5/100)
# Before sorting: [51, -6, 50, 60, -45, 96]
# After sorting: [-45, -6, 50, 51, 60, 96]
# Expected result: [-45, -6, 50, 51, 60, 96]
#
# #7 Loop (already passed: 6/100)
# Before sorting: [-86, 12, 59, 8, -2, -42, -42, 69, 21, 54]
# After sorting: [-86, -42, -42, -2, 8, 12, 21, 54, 59, 69]
# Expected result: [-86, -42, -42, -2, 8, 12, 21, 54, 59, 69]
#
# #8 Loop (already passed: 7/100)
# Before sorting: [91, 49, 17, 26, -45, 42, -65, -92, -30, 34, 38, -76, -87]
# After sorting: [-92, -87, -76, -65, -45, -30, 17, 26, 34, 38, 42, 49, 91]
# Expected result: [-92, -87, -76, -65, -45, -30, 17, 26, 34, 38, 42, 49, 91]
#
# #9 Loop (already passed: 8/100)
# Before sorting: [17, 92, 59, -95, -72, -8, 20, -35, -68, -34]
# After sorting: [-95, -72, -68, -35, -34, -8, 17, 20, 59, 92]
# Expected result: [-95, -72, -68, -35, -34, -8, 17, 20, 59, 92]
#
# #10 Loop (already passed: 9/100)
# Before sorting: [-32, -50, 63, -16, 80]
# After sorting: [-50, -32, -16, 63, 80]
# Expected result: [-50, -32, -16, 63, 80]
#
# #11 Loop (already passed: 10/100)
# Before sorting: [-93, 21, 57, -66, -15, -16, -82, 1, -43, 51, 66, 72, 84, -96, -84]
# After sorting: [-96, -93, -84, -82, -66, -43, -16, -15, 1, 21, 51, 57, 66, 72, 84]
# Expected result: [-96, -93, -84, -82, -66, -43, -16, -15, 1, 21, 51, 57, 66, 72, 84]
#
# #12 Loop (already passed: 11/100)
# Before sorting: [-73, -78, 85, 5, -73, -59, -38, 4, 54]
# After sorting: [-78, -73, -73, -59, -38, 4, 5, 54, 85]
# Expected result: [-78, -73, -73, -59, -38, 4, 5, 54, 85]
#
# #13 Loop (already passed: 12/100)
# Before sorting: [-16, -10, 54, 68, -58, 22, 82, -50, -21, 49, 28, 55, 56]
# After sorting: [-58, -50, -21, -16, -10, 22, 28, 49, 54, 55, 56, 68, 82]
# Expected result: [-58, -50, -21, -16, -10, 22, 28, 49, 54, 55, 56, 68, 82]
#
# #14 Loop (already passed: 13/100)
# Before sorting: [94, -18, -93, -94, -6, -83, 92, -61, 82, -27]
# After sorting: [-94, -93, -83, -61, -27, -18, -6, 82, 92, 94]
# Expected result: [-94, -93, -83, -61, -27, -18, -6, 82, 92, 94]
#
# #15 Loop (already passed: 14/100)
# Before sorting: [14, -76, -62, 66, -72, 91, 66, 51, -30, 98, 78, -17, 10, -59]
# After sorting: [-76, -72, -62, -59, -30, -17, 10, 14, 51, 66, 66, 78, 91, 98]
# Expected result: [-76, -72, -62, -59, -30, -17, 10, 14, 51, 66, 66, 78, 91, 98]
#
# #16 Loop (already passed: 15/100)
# Before sorting: [-32, -45, 54, -5, 47, -90, 100, -75, 99, -77]
# After sorting: [-90, -77, -75, -45, -32, -5, 47, 54, 99, 100]
# Expected result: [-90, -77, -75, -45, -32, -5, 47, 54, 99, 100]
#
# #17 Loop (already passed: 16/100)
# Before sorting: [49, 38, -93, 24, 97, 7, -5, -1, -38]
# After sorting: [-93, -38, -5, -1, 7, 24, 38, 49, 97]
# Expected result: [-93, -38, -5, -1, 7, 24, 38, 49, 97]
#
# #18 Loop (already passed: 17/100)
# Before sorting: [24, -69, 23, 76, 85, -70, 100, -18, -71, 54]
# After sorting: [-71, -70, -69, -18, 23, 24, 54, 76, 85, 100]
# Expected result: [-71, -70, -69, -18, 23, 24, 54, 76, 85, 100]
#
# #19 Loop (already passed: 18/100)
# Before sorting: [77, 11, 89, -97, -21, 43, 100, 61, -63]
# After sorting: [-97, -63, -21, 11, 43, 61, 77, 89, 100]
# Expected result: [-97, -63, -21, 11, 43, 61, 77, 89, 100]
#
# #20 Loop (already passed: 19/100)
# Before sorting: [-29, -15, -69, 35, -96, 87, 82, 97, 96, -43, 81, -85]
# After sorting: [-96, -85, -69, -43, -29, -15, 35, 81, 82, 87, 96, 97]
# Expected result: [-96, -85, -69, -43, -29, -15, 35, 81, 82, 87, 96, 97]
#
# #21 Loop (already passed: 20/100)
# Before sorting: [1, -68, 44, 0, -90, -96, -99, -18, 79, -95, 11, 2, 7, -45, -4]
# After sorting: [-99, -96, -95, -90, -68, -45, -18, -4, 0, 1, 2, 7, 11, 44, 79]
# Expected result: [-99, -96, -95, -90, -68, -45, -18, -4, 0, 1, 2, 7, 11, 44, 79]
#
# #22 Loop (already passed: 21/100)
# Before sorting: [-55, -64, -46, -68, -57, 16, 79, 28, 82, -59, 75]
# After sorting: [-68, -64, -59, -57, -55, -46, 16, 28, 75, 79, 82]
# Expected result: [-68, -64, -59, -57, -55, -46, 16, 28, 75, 79, 82]
#
# #23 Loop (already passed: 22/100)
# Before sorting: [40, -40, -1, 26, -79, -18, 35, 54, -13, 90, -3, 5, 47]
# After sorting: [-79, -40, -18, -13, -3, -1, 5, 26, 35, 40, 47, 54, 90]
# Expected result: [-79, -40, -18, -13, -3, -1, 5, 26, 35, 40, 47, 54, 90]
#
# #24 Loop (already passed: 23/100)
# Before sorting: [-11, 28, -14, 42, -45]
# After sorting: [-45, -14, -11, 28, 42]
# Expected result: [-45, -14, -11, 28, 42]
#
# #25 Loop (already passed: 24/100)
# Before sorting: [64, 55, -18, 37, -45, -57, -47, -46, 8, 13, -39, 16, -20]
# After sorting: [-57, -47, -46, -45, -39, -20, -18, 8, 13, 16, 37, 55, 64]
# Expected result: [-57, -47, -46, -45, -39, -20, -18, 8, 13, 16, 37, 55, 64]
#
# #26 Loop (already passed: 25/100)
# Before sorting: [0, 9, -14, 51, 40, -75, -100, 64, 27, -20]
# After sorting: [-100, -75, -20, -14, 0, 9, 27, 40, 51, 64]
# Expected result: [-100, -75, -20, -14, 0, 9, 27, 40, 51, 64]
#
# #27 Loop (already passed: 26/100)
# Before sorting: [-93, -3, 30, 49, 42, -68, -4, -63, 38, -78, 26, 23]
# After sorting: [-93, -78, -68, -63, -4, -3, 23, 26, 30, 38, 42, 49]
# Expected result: [-93, -78, -68, -63, -4, -3, 23, 26, 30, 38, 42, 49]
#
# #28 Loop (already passed: 27/100)
# Before sorting: [46, 69, -50, 36, 86]
# After sorting: [-50, 36, 46, 69, 86]
# Expected result: [-50, 36, 46, 69, 86]
#
# #29 Loop (already passed: 28/100)
# Before sorting: [-16, 92, 71, 34, 39, 56]
# After sorting: [-16, 34, 39, 56, 71, 92]
# Expected result: [-16, 34, 39, 56, 71, 92]
#
# #30 Loop (already passed: 29/100)
# Before sorting: [16, 57, -94, -21, -81, 43, -99]
# After sorting: [-99, -94, -81, -21, 16, 43, 57]
# Expected result: [-99, -94, -81, -21, 16, 43, 57]
#
# #31 Loop (already passed: 30/100)
# Before sorting: [24, 12, 10, 65, 69, -62, 60, 5]
# After sorting: [-62, 5, 10, 12, 24, 60, 65, 69]
# Expected result: [-62, 5, 10, 12, 24, 60, 65, 69]
#
# #32 Loop (already passed: 31/100)
# Before sorting: [28, 44, -86, -8, -39, 28, 58, 1, 12, -12, -64, 5, -73]
# After sorting: [-86, -73, -64, -39, -12, -8, 1, 5, 12, 28, 28, 44, 58]
# Expected result: [-86, -73, -64, -39, -12, -8, 1, 5, 12, 28, 28, 44, 58]
#
# #33 Loop (already passed: 32/100)
# Before sorting: [7, 75, 11, 8, -27, 3, 94, 88, 15, -15, -22, -6, -63, -32, 91]
# After sorting: [-63, -32, -27, -22, -15, -6, 3, 7, 8, 11, 15, 75, 88, 91, 94]
# Expected result: [-63, -32, -27, -22, -15, -6, 3, 7, 8, 11, 15, 75, 88, 91, 94]
#
# #34 Loop (already passed: 33/100)
# Before sorting: [88, -59, -67, 0, 78, 36, -53, -66, 49, 66, 5, -98, -38, 10]
# After sorting: [-98, -67, -66, -59, -53, -38, 0, 5, 10, 36, 49, 66, 78, 88]
# Expected result: [-98, -67, -66, -59, -53, -38, 0, 5, 10, 36, 49, 66, 78, 88]
#
# #35 Loop (already passed: 34/100)
# Before sorting: [53, -68, -7, 88, -91, -21, 64, -96, -97]
# After sorting: [-97, -96, -91, -68, -21, -7, 53, 64, 88]
# Expected result: [-97, -96, -91, -68, -21, -7, 53, 64, 88]
#
# #36 Loop (already passed: 35/100)
# Before sorting: [73, -22, -79, 23, 38, -17, -19, 12, 14, -17, -50]
# After sorting: [-79, -50, -22, -19, -17, -17, 12, 14, 23, 38, 73]
# Expected result: [-79, -50, -22, -19, -17, -17, 12, 14, 23, 38, 73]
#
# #37 Loop (already passed: 36/100)
# Before sorting: [37, 6, 36, -44, 16, -89, -9, -47, -32, -88, -32, 51]
# After sorting: [-89, -88, -47, -44, -32, -32, -9, 6, 16, 36, 37, 51]
# Expected result: [-89, -88, -47, -44, -32, -32, -9, 6, 16, 36, 37, 51]
#
# #38 Loop (already passed: 37/100)
# Before sorting: [-82, 6, 56, -79, -43, 16, -76, -2, -46, -27, 86, 46, 94, -56, 58]
# After sorting: [-82, -79, -76, -56, -46, -43, -27, -2, 6, 16, 46, 56, 58, 86, 94]
# Expected result: [-82, -79, -76, -56, -46, -43, -27, -2, 6, 16, 46, 56, 58, 86, 94]
#
# #39 Loop (already passed: 38/100)
# Before sorting: [0, -58, -36, -18, -98, 22, -82, -87]
# After sorting: [-98, -87, -82, -58, -36, -18, 0, 22]
# Expected result: [-98, -87, -82, -58, -36, -18, 0, 22]
#
# #40 Loop (already passed: 39/100)
# Before sorting: [82, -18, -8, -69, 14, 50, -100, 26, 43, -72, -100, -44]
# After sorting: [-100, -100, -72, -69, -44, -18, -8, 14, 26, 43, 50, 82]
# Expected result: [-100, -100, -72, -69, -44, -18, -8, 14, 26, 43, 50, 82]
#
# #41 Loop (already passed: 40/100)
# Before sorting: [-36, -52, 68, -93, 89, -28, -64, 64]
# After sorting: [-93, -64, -52, -36, -28, 64, 68, 89]
# Expected result: [-93, -64, -52, -36, -28, 64, 68, 89]
#
# #42 Loop (already passed: 41/100)
# Before sorting: [-54, 62, -41, 53, -53, -35, -45, 84, 59, -20, 38]
# After sorting: [-54, -53, -45, -41, -35, -20, 38, 53, 59, 62, 84]
# Expected result: [-54, -53, -45, -41, -35, -20, 38, 53, 59, 62, 84]
#
# #43 Loop (already passed: 42/100)
# Before sorting: [70, -66, -27, 17, 76, 19, -90, -13, -11]
# After sorting: [-90, -66, -27, -13, -11, 17, 19, 70, 76]
# Expected result: [-90, -66, -27, -13, -11, 17, 19, 70, 76]
#
# #44 Loop (already passed: 43/100)
# Before sorting: [-1, 42, -35, -42, 45, 38, 71, -21, 90, 64, 51, -71, 44, 95, -45]
# After sorting: [-71, -45, -42, -35, -21, -1, 38, 42, 44, 45, 51, 64, 71, 90, 95]
# Expected result: [-71, -45, -42, -35, -21, -1, 38, 42, 44, 45, 51, 64, 71, 90, 95]
#
# #45 Loop (already passed: 44/100)
# Before sorting: [49, 29, -35, 51, 57, 95, -76, -14, 12, -17, 37, -16, 90, -65, 13]
# After sorting: [-76, -65, -35, -17, -16, -14, 12, 13, 29, 37, 49, 51, 57, 90, 95]
# Expected result: [-76, -65, -35, -17, -16, -14, 12, 13, 29, 37, 49, 51, 57, 90, 95]
#
# #46 Loop (already passed: 45/100)
# Before sorting: [-27, -97, 64, 25, -15, -96, -15, 72, 98, 68, 77, 44, -42]
# After sorting: [-97, -96, -42, -27, -15, -15, 25, 44, 64, 68, 72, 77, 98]
# Expected result: [-97, -96, -42, -27, -15, -15, 25, 44, 64, 68, 72, 77, 98]
#
# #47 Loop (already passed: 46/100)
# Before sorting: [-79, 18, -57, 69, 25, 96, -4, -46, 60, 40]
# After sorting: [-79, -57, -46, -4, 18, 25, 40, 60, 69, 96]
# Expected result: [-79, -57, -46, -4, 18, 25, 40, 60, 69, 96]
#
# #48 Loop (already passed: 47/100)
# Before sorting: [-36, -40, 99, 96, -52, 52, 35, 6, -71, -37, 46, -82, 18, 71, -23]
# After sorting: [-82, -71, -52, -40, -37, -36, -23, 6, 18, 35, 46, 52, 71, 96, 99]
# Expected result: [-82, -71, -52, -40, -37, -36, -23, 6, 18, 35, 46, 52, 71, 96, 99]
#
# #49 Loop (already passed: 48/100)
# Before sorting: [86, -67, -34, -57, 3]
# After sorting: [-67, -57, -34, 3, 86]
# Expected result: [-67, -57, -34, 3, 86]
#
# #50 Loop (already passed: 49/100)
# Before sorting: [20, 33, 58, -76, -73, -30, 57, -26, 2, -56, 100, 93, 82]
# After sorting: [-76, -73, -56, -30, -26, 2, 20, 33, 57, 58, 82, 93, 100]
# Expected result: [-76, -73, -56, -30, -26, 2, 20, 33, 57, 58, 82, 93, 100]
#
# #51 Loop (already passed: 50/100)
# Before sorting: [-10, 95, 10, -76, -54, -1]
# After sorting: [-76, -54, -10, -1, 10, 95]
# Expected result: [-76, -54, -10, -1, 10, 95]
#
# #52 Loop (already passed: 51/100)
# Before sorting: [-49, -85, 53, -56, -98, -7, 17, 55, 67, -96, 97, 59, 29, -47, -29]
# After sorting: [-98, -96, -85, -56, -49, -47, -29, -7, 17, 29, 53, 55, 59, 67, 97]
# Expected result: [-98, -96, -85, -56, -49, -47, -29, -7, 17, 29, 53, 55, 59, 67, 97]
#
# #53 Loop (already passed: 52/100)
# Before sorting: [-72, -89, 84, -92, 7, -75, 73, -34, -26, -57, -93, -79]
# After sorting: [-93, -92, -89, -79, -75, -72, -57, -34, -26, 7, 73, 84]
# Expected result: [-93, -92, -89, -79, -75, -72, -57, -34, -26, 7, 73, 84]
#
# #54 Loop (already passed: 53/100)
# Before sorting: [-27, 99, 73, 32, -45, 93, 8, 27, 88, 43, -32, -62]
# After sorting: [-62, -45, -32, -27, 8, 27, 32, 43, 73, 88, 93, 99]
# Expected result: [-62, -45, -32, -27, 8, 27, 32, 43, 73, 88, 93, 99]
#
# #55 Loop (already passed: 54/100)
# Before sorting: [-67, 52, 5, 23, -4, -5, 2, -16, 38, -94, 7, 16, -47]
# After sorting: [-94, -67, -47, -16, -5, -4, 2, 5, 7, 16, 23, 38, 52]
# Expected result: [-94, -67, -47, -16, -5, -4, 2, 5, 7, 16, 23, 38, 52]
#
# #56 Loop (already passed: 55/100)
# Before sorting: [46, -4, 86, -70, -31, 67, 23, -54, -46, 11, -70, -42, 2, -79]
# After sorting: [-79, -70, -70, -54, -46, -42, -31, -4, 2, 11, 23, 46, 67, 86]
# Expected result: [-79, -70, -70, -54, -46, -42, -31, -4, 2, 11, 23, 46, 67, 86]
#
# #57 Loop (already passed: 56/100)
# Before sorting: [71, -1, 1, 15, -26, -90]
# After sorting: [-90, -26, -1, 1, 15, 71]
# Expected result: [-90, -26, -1, 1, 15, 71]
#
# #58 Loop (already passed: 57/100)
# Before sorting: [-49, -38, -71, 0, 59, -70, 43, 81, 53, -50, -32, 5]
# After sorting: [-71, -70, -50, -49, -38, -32, 0, 5, 43, 53, 59, 81]
# Expected result: [-71, -70, -50, -49, -38, -32, 0, 5, 43, 53, 59, 81]
#
# #59 Loop (already passed: 58/100)
# Before sorting: [-44, 25, -56, 9, -55, 24, 37, -5]
# After sorting: [-56, -55, -44, -5, 9, 24, 25, 37]
# Expected result: [-56, -55, -44, -5, 9, 24, 25, 37]
#
# #60 Loop (already passed: 59/100)
# Before sorting: [-52, -68, 68, 56, 3, -27, -42, 77, 54, -29, 82, -17, 30]
# After sorting: [-68, -52, -42, -29, -27, -17, 3, 30, 54, 56, 68, 77, 82]
# Expected result: [-68, -52, -42, -29, -27, -17, 3, 30, 54, 56, 68, 77, 82]
#
# #61 Loop (already passed: 60/100)
# Before sorting: [-58, 69, 26, -85, 82, -17, -62, -70, 49, 97, 21, -25, 21, -76]
# After sorting: [-85, -76, -70, -62, -58, -25, -17, 21, 21, 26, 49, 69, 82, 97]
# Expected result: [-85, -76, -70, -62, -58, -25, -17, 21, 21, 26, 49, 69, 82, 97]
#
# #62 Loop (already passed: 61/100)
# Before sorting: [48, -12, -64, 17, 100]
# After sorting: [-64, -12, 17, 48, 100]
# Expected result: [-64, -12, 17, 48, 100]
#
# #63 Loop (already passed: 62/100)
# Before sorting: [-14, 25, 32, -84, 63, -72, 29, -74, 11, -18, -78, -53, 68]
# After sorting: [-84, -78, -74, -72, -53, -18, -14, 11, 25, 29, 32, 63, 68]
# Expected result: [-84, -78, -74, -72, -53, -18, -14, 11, 25, 29, 32, 63, 68]
#
# #64 Loop (already passed: 63/100)
# Before sorting: [-97, -12, -71, -8, -98, 22, 76, -67, 53, 57, 20]
# After sorting: [-98, -97, -71, -67, -12, -8, 20, 22, 53, 57, 76]
# Expected result: [-98, -97, -71, -67, -12, -8, 20, 22, 53, 57, 76]
#
# #65 Loop (already passed: 64/100)
# Before sorting: [93, -46, -54, -50, 62, 47, -12, 81, -7, 34, 44, -93, 25, 58]
# After sorting: [-93, -54, -50, -46, -12, -7, 25, 34, 44, 47, 58, 62, 81, 93]
# Expected result: [-93, -54, -50, -46, -12, -7, 25, 34, 44, 47, 58, 62, 81, 93]
#
# #66 Loop (already passed: 65/100)
# Before sorting: [-5, -76, 72, -82, 99, -46]
# After sorting: [-82, -76, -46, -5, 72, 99]
# Expected result: [-82, -76, -46, -5, 72, 99]
#
# #67 Loop (already passed: 66/100)
# Before sorting: [-47, 73, -18, 84, -15, 70, 37, -40, -36, 0]
# After sorting: [-47, -40, -36, -18, -15, 0, 37, 70, 73, 84]
# Expected result: [-47, -40, -36, -18, -15, 0, 37, 70, 73, 84]
#
# #68 Loop (already passed: 67/100)
# Before sorting: [28, 80, -20, 19, 4, -29, -86]
# After sorting: [-86, -29, -20, 4, 19, 28, 80]
# Expected result: [-86, -29, -20, 4, 19, 28, 80]
#
# #69 Loop (already passed: 68/100)
# Before sorting: [18, -72, 88, -9, -20, -73, -2, -43, -77, -72, 16, 66, 20]
# After sorting: [-77, -73, -72, -72, -43, -20, -9, -2, 16, 18, 20, 66, 88]
# Expected result: [-77, -73, -72, -72, -43, -20, -9, -2, 16, 18, 20, 66, 88]
#
# #70 Loop (already passed: 69/100)
# Before sorting: [-10, -5, 62, -23, -50, -75, -77, -59, 28, -40, -74]
# After sorting: [-77, -75, -74, -59, -50, -40, -23, -10, -5, 28, 62]
# Expected result: [-77, -75, -74, -59, -50, -40, -23, -10, -5, 28, 62]
#
# #71 Loop (already passed: 70/100)
# Before sorting: [56, -34, -71, -52, -26, 56, 0, -55, 7, -16, -26, -66, 63, -58]
# After sorting: [-71, -66, -58, -55, -52, -34, -26, -26, -16, 0, 7, 56, 56, 63]
# Expected result: [-71, -66, -58, -55, -52, -34, -26, -26, -16, 0, 7, 56, 56, 63]
#
# #72 Loop (already passed: 71/100)
# Before sorting: [-13, 46, 21, -38, -64, 95, 30, 83]
# After sorting: [-64, -38, -13, 21, 30, 46, 83, 95]
# Expected result: [-64, -38, -13, 21, 30, 46, 83, 95]
#
# #73 Loop (already passed: 72/100)
# Before sorting: [22, -10, 57, -39, 74, 59, 4, -41, 86, 50, -41, 18, 96, -60]
# After sorting: [-60, -41, -41, -39, -10, 4, 18, 22, 50, 57, 59, 74, 86, 96]
# Expected result: [-60, -41, -41, -39, -10, 4, 18, 22, 50, 57, 59, 74, 86, 96]
#
# #74 Loop (already passed: 73/100)
# Before sorting: [2, 93, 21, -80, -96, -10, 21, -74]
# After sorting: [-96, -80, -74, -10, 2, 21, 21, 93]
# Expected result: [-96, -80, -74, -10, 2, 21, 21, 93]
#
# #75 Loop (already passed: 74/100)
# Before sorting: [-47, 70, 13, -66, -91, 35]
# After sorting: [-91, -66, -47, 13, 35, 70]
# Expected result: [-91, -66, -47, 13, 35, 70]
#
# #76 Loop (already passed: 75/100)
# Before sorting: [-69, -91, -4, -91, 38, 34, 6, 2, -2, -71, 39, 71, 25, -80]
# After sorting: [-91, -91, -80, -71, -69, -4, -2, 2, 6, 25, 34, 38, 39, 71]
# Expected result: [-91, -91, -80, -71, -69, -4, -2, 2, 6, 25, 34, 38, 39, 71]
#
# #77 Loop (already passed: 76/100)
# Before sorting: [-52, -71, 51, 66, -63, -28, -91, 32, -87]
# After sorting: [-91, -87, -71, -63, -52, -28, 32, 51, 66]
# Expected result: [-91, -87, -71, -63, -52, -28, 32, 51, 66]
#
# #78 Loop (already passed: 77/100)
# Before sorting: [98, 100, 14, -74, 65, -16, 89, -42, 13, 16, 89]
# After sorting: [-74, -42, -16, 13, 14, 16, 65, 89, 89, 98, 100]
# Expected result: [-74, -42, -16, 13, 14, 16, 65, 89, 89, 98, 100]
#
# #79 Loop (already passed: 78/100)
# Before sorting: [-62, 98, -7, -94, -26, -78, 55, 48, 52, -48, 37, -1, -33, -11, -38]
# After sorting: [-94, -78, -62, -48, -38, -33, -26, -11, -7, -1, 37, 48, 52, 55, 98]
# Expected result: [-94, -78, -62, -48, -38, -33, -26, -11, -7, -1, 37, 48, 52, 55, 98]
#
# #80 Loop (already passed: 79/100)
# Before sorting: [-83, 49, -68, 9, 83, 4, -73, 35, -30, -65, 35, -30, 31, 96, -64]
# After sorting: [-83, -73, -68, -65, -64, -30, -30, 4, 9, 31, 35, 35, 49, 83, 96]
# Expected result: [-83, -73, -68, -65, -64, -30, -30, 4, 9, 31, 35, 35, 49, 83, 96]
#
# #81 Loop (already passed: 80/100)
# Before sorting: [-32, -30, -71, 37, -84, -30, 35, -88, -26, 94, 90, -40, -37, 13]
# After sorting: [-88, -84, -71, -40, -37, -32, -30, -30, -26, 13, 35, 37, 90, 94]
# Expected result: [-88, -84, -71, -40, -37, -32, -30, -30, -26, 13, 35, 37, 90, 94]
#
# #82 Loop (already passed: 81/100)
# Before sorting: [-93, 54, 92, 4, 60, 71, 87, 40, -100]
# After sorting: [-100, -93, 4, 40, 54, 60, 71, 87, 92]
# Expected result: [-100, -93, 4, 40, 54, 60, 71, 87, 92]
#
# #83 Loop (already passed: 82/100)
# Before sorting: [-27, -21, 67, -44, 16, -34]
# After sorting: [-44, -34, -27, -21, 16, 67]
# Expected result: [-44, -34, -27, -21, 16, 67]
#
# #84 Loop (already passed: 83/100)
# Before sorting: [17, -15, -91, 40, 47, 11, 56, 87, -3, -7, 46, -80, -53, -61]
# After sorting: [-91, -80, -61, -53, -15, -7, -3, 11, 17, 40, 46, 47, 56, 87]
# Expected result: [-91, -80, -61, -53, -15, -7, -3, 11, 17, 40, 46, 47, 56, 87]
#
# #85 Loop (already passed: 84/100)
# Before sorting: [-53, -50, -18, 0, -58, 2, -36, -31]
# After sorting: [-58, -53, -50, -36, -31, -18, 0, 2]
# Expected result: [-58, -53, -50, -36, -31, -18, 0, 2]
#
# #86 Loop (already passed: 85/100)
# Before sorting: [14, 25, 34, -10, 90]
# After sorting: [-10, 14, 25, 34, 90]
# Expected result: [-10, 14, 25, 34, 90]
#
# #87 Loop (already passed: 86/100)
# Before sorting: [20, -56, 4, -48, 56, 20, 11, 59]
# After sorting: [-56, -48, 4, 11, 20, 20, 56, 59]
# Expected result: [-56, -48, 4, 11, 20, 20, 56, 59]
#
# #88 Loop (already passed: 87/100)
# Before sorting: [-90, 85, 3, -64, 75, -15, 31, 56, -4, -47, 80]
# After sorting: [-90, -64, -47, -15, -4, 3, 31, 56, 75, 80, 85]
# Expected result: [-90, -64, -47, -15, -4, 3, 31, 56, 75, 80, 85]
#
# #89 Loop (already passed: 88/100)
# Before sorting: [-78, 94, -68, 44, 12, -94, -71, 82, -68, 43, 16, -53, 93, 44]
# After sorting: [-94, -78, -71, -68, -68, -53, 12, 16, 43, 44, 44, 82, 93, 94]
# Expected result: [-94, -78, -71, -68, -68, -53, 12, 16, 43, 44, 44, 82, 93, 94]
#
# #90 Loop (already passed: 89/100)
# Before sorting: [-64, 93, -94, -66, -41]
# After sorting: [-94, -66, -64, -41, 93]
# Expected result: [-94, -66, -64, -41, 93]
#
# #91 Loop (already passed: 90/100)
# Before sorting: [-1, 73, 77, -7, 35, -14, 69]
# After sorting: [-14, -7, -1, 35, 69, 73, 77]
# Expected result: [-14, -7, -1, 35, 69, 73, 77]
#
# #92 Loop (already passed: 91/100)
# Before sorting: [59, -35, -100, -1, 2, 18, 69, 27, 72, -60, 28, -22, -91, 26]
# After sorting: [-100, -91, -60, -35, -22, -1, 2, 18, 26, 27, 28, 59, 69, 72]
# Expected result: [-100, -91, -60, -35, -22, -1, 2, 18, 26, 27, 28, 59, 69, 72]
#
# #93 Loop (already passed: 92/100)
# Before sorting: [-92, 61, -99, -73, 14, -99, -79, 29, 85, 95, -15, -6, 30, -65, 80]
# After sorting: [-99, -99, -92, -79, -73, -65, -15, -6, 14, 29, 30, 61, 80, 85, 95]
# Expected result: [-99, -99, -92, -79, -73, -65, -15, -6, 14, 29, 30, 61, 80, 85, 95]
#
# #94 Loop (already passed: 93/100)
# Before sorting: [-68, 87, -66, -36, -58, 52, 61, 31, 29, 36, 21, 10, 71, -85, 6]
# After sorting: [-85, -68, -66, -58, -36, 6, 10, 21, 29, 31, 36, 52, 61, 71, 87]
# Expected result: [-85, -68, -66, -58, -36, 6, 10, 21, 29, 31, 36, 52, 61, 71, 87]
#
# #95 Loop (already passed: 94/100)
# Before sorting: [17, -57, 18, -69, -75, 11, 27, 82, 90]
# After sorting: [-75, -69, -57, 11, 17, 18, 27, 82, 90]
# Expected result: [-75, -69, -57, 11, 17, 18, 27, 82, 90]
#
# #96 Loop (already passed: 95/100)
# Before sorting: [-70, 32, -66, -93, -52, -33, 32, -8, 50, -94]
# After sorting: [-94, -93, -70, -66, -52, -33, -8, 32, 32, 50]
# Expected result: [-94, -93, -70, -66, -52, -33, -8, 32, 32, 50]
#
# #97 Loop (already passed: 96/100)
# Before sorting: [68, 35, -51, -1, -81, 93, 39, 58, -70, -84]
# After sorting: [-84, -81, -70, -51, -1, 35, 39, 58, 68, 93]
# Expected result: [-84, -81, -70, -51, -1, 35, 39, 58, 68, 93]
#
# #98 Loop (already passed: 97/100)
# Before sorting: [-46, 77, 16, 22, 10, -40, 73, -76, 3, -27, 66, 25]
# After sorting: [-76, -46, -40, -27, 3, 10, 16, 22, 25, 66, 73, 77]
# Expected result: [-76, -46, -40, -27, 3, 10, 16, 22, 25, 66, 73, 77]
#
# #99 Loop (already passed: 98/100)
# Before sorting: [-62, 79, -65, 49, 68, -58, -11, 33, 53, 38, -73, -87, -33, 54]
# After sorting: [-87, -73, -65, -62, -58, -33, -11, 33, 38, 49, 53, 54, 68, 79]
# Expected result: [-87, -73, -65, -62, -58, -33, -11, 33, 38, 49, 53, 54, 68, 79]
#
# #100 Loop (already passed: 99/100)
# Before sorting: [99, 52, 55, -37, -66, -99, 95]
# After sorting: [-99, -66, -37, 52, 55, 95, 99]
# Expected result: [-99, -66, -37, 52, 55, 95, 99]
#
# Sorting algorithm is correct
# Passed tests in total: 100/100
