# %% [markdown]
# ### Treść zadania

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ###### UWAGA

# %% [markdown]
# To jest zadanie bardziej opisowe a sama implementacja nie jest prosta.
