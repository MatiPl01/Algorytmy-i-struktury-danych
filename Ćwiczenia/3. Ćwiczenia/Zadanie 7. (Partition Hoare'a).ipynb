# %% [markdown]
# > Proszę zaimplementować funkcję partition z algorytmu QuickSort według pomysłu Hoare’a (tj. mamy dwa indeksy, i oraz j, wędrujące z obu końców tablicy w stronę środka i zamieniamy elementy tablicy pod nimi jeśli mniejszy indeks wskazuje na wartość większą od piwota, a większy na mniejszą.

# %% [markdown]
# ### Kilka wyjaśnień

# %% [markdown]
# Korzystamy z implementacji rekurencyjnej zoptymalizowanej tak, że złożoność pamięciowa wynosi tylko $ O(log(n)) $. Implementowanie stosu jest w tym przypadku bez sensu, bo:

# %%
import math

math.log(1_000_000_000_000_000_000_000_000_000_000, 2)
# Out:
# 99.65784284662087

# %% [markdown]
# Dopiero sortowanie tablicy o rozmiarze ok $ 10^30 $ wymaga maksymalnie $ 100 $ wywołań rekurencyjnych jednocześnie (tzn. odłożonych jednocześnie na stosie rekurencyjnym). Przepełnienie stosu jest prawie niemożliwe.

# %% [markdown]
# ##### Funkcja testująca poprawność algorytmu

# %%
import random

def test_sort(sorting_fn, *, 
              samples=20,         # A number of tests that will be performed
              val_counts=(0, 50), # A minimum and maximum number of values to sort that will be generated
              range_=(-100, 100), # A range which will be used to create a random list of values from this range
              in_place=True,      # Information whether an algorithm runs in place or not
              failed_only=False,  # Show only failed tests. Works only if no_results is set to False
              print_out_fn=None,  # An user-defined function to print additional information. Works only if no_results is set to False
              no_results=False    # When set to True, no results will be printed (useful only for benchmark)
             ):                  
    passed = 0                   
    for i in range(samples):
        random_lst = [random.randint(*range_) for _ in range(random.randint(*val_counts))]
        random_lst_before = random_lst[:]
        expected = sorted(random_lst)
        output = sorting_fn(random_lst)
        if not in_place:
            random_lst = output
        is_correct = random_lst == expected
        passed += is_correct
        
        if not no_results:
            if not failed_only or (failed_only and not is_correct):
                print(f'TEST #{i+1}:')
                print(f'Before sorting: {random_lst_before}')
                print(f'After sorting: {random_lst}')
                print(f'Expected result: {expected}')
                print(f'Test {"PASSED" if is_correct else "FAILED"}')
                print(f'Current passed-to-tested ratio: {passed}/{i+1}')
                if print_out_fn:
                    print(f'========== Additional results after sorting  ==========')
                    print_out_fn(random_lst)
                print()
                
    if not no_results:
        print(f'Sorting algorithms is {"correct" if passed == samples else "wrong"}')
        print(f'Passed tests in total: {passed}/{samples}')

# %% [markdown]
# ### Implementacja algorytmu

# %%
import random


def quick_sort(arr):
    _quick_sort(arr, 0, len(arr) - 1)
    

def _quick_sort(arr, left_idx, right_idx):
    while left_idx < right_idx:
        pivot_position = _partition(arr, left_idx, right_idx)
        
        if pivot_position - left_idx < right_idx - pivot_position:
            _quick_sort(arr, left_idx, pivot_position)
            left_idx = pivot_position + 1  # I removed a tailing recursion
        else:
            _quick_sort(arr, pivot_position + 1, right_idx)
            right_idx = pivot_position  # I removed a tailing recursion
        
        
def _partition(arr, left_idx, right_idx):
    pivot = arr[random.randint(left_idx, right_idx)]
    
    # Partition an array into 2 subarrays of elements lower than or
    # equal to a pivot and of elements greater than a pivot (in this
    # partition algorithm pivot isn't placed on a fixed position but
    # can be also swapped like all the remaining values)
    i = left_idx - 1
    j = right_idx + 1
    while True:
        i += 1
        while arr[i] < pivot: i += 1
            
        j -= 1
        while arr[j] > pivot: j -= 1
        
        if i < j:
            _swap(arr, i, j)
        else:
            return j  # Return a pivot position after the last swap

    
def _swap(arr, i, j):
    arr[i], arr[j] = arr[j], arr[i]

# %% [markdown]
# ###### Kilka testów

# %%
test_sort(quick_sort, samples=100)
# Out:
# TEST #1:
# Before sorting: []
# After sorting: []
# Expected result: []
# Test PASSED
# Current passed-to-tested ratio: 1/1
#
# TEST #2:
# Before sorting: [57, -37, 20, -12, 49, -27, -100, -75, 79, -18, -81, -34, -30, -94, -38]
# After sorting: [-100, -94, -81, -75, -38, -37, -34, -30, -27, -18, -12, 20, 49, 57, 79]
# Expected result: [-100, -94, -81, -75, -38, -37, -34, -30, -27, -18, -12, 20, 49, 57, 79]
# Test PASSED
# Current passed-to-tested ratio: 2/2
#
# TEST #3:
# Before sorting: [-75, -91, 14, -25, 2, -81, -71, 49, -29, -3, 27, -37, 93, -96, 33, -95, -44, -33, 19, -73, -12, -9, -7, 2, -10, 62, 44, 24, 84, 27, -5, 3, -51]
# After sorting: [-96, -95, -91, -81, -75, -73, -71, -51, -44, -37, -33, -29, -25, -12, -10, -9, -7, -5, -3, 2, 2, 3, 14, 19, 24, 27, 27, 33, 44, 49, 62, 84, 93]
# Expected result: [-96, -95, -91, -81, -75, -73, -71, -51, -44, -37, -33, -29, -25, -12, -10, -9, -7, -5, -3, 2, 2, 3, 14, 19, 24, 27, 27, 33, 44, 49, 62, 84, 93]
# Test PASSED
# Current passed-to-tested ratio: 3/3
#
# TEST #4:
# Before sorting: [26, -8, -80, -53, 62, -89, 20, -50, -15, -41, -25, 21, -7, 4, 29, -81, 38, 99, -48, 29, -41, -66, 0, -83, -91, -99, 12]
# After sorting: [-99, -91, -89, -83, -81, -80, -66, -53, -50, -48, -41, -41, -25, -15, -8, -7, 0, 4, 12, 20, 21, 26, 29, 29, 38, 62, 99]
# Expected result: [-99, -91, -89, -83, -81, -80, -66, -53, -50, -48, -41, -41, -25, -15, -8, -7, 0, 4, 12, 20, 21, 26, 29, 29, 38, 62, 99]
# Test PASSED
# Current passed-to-tested ratio: 4/4
#
# TEST #5:
# Before sorting: [-65, -27, 22, 92]
# After sorting: [-65, -27, 22, 92]
# Expected result: [-65, -27, 22, 92]
# Test PASSED
# Current passed-to-tested ratio: 5/5
#
# TEST #6:
# Before sorting: [-47, -13, 18, -55, 30, 0, -73, 65, 65, 33, 26, 90, 56, -64, -29, -61, -80, -44, 72, 64, -8, 12, 82, 55, -47, -74, 25, -74, 70, 76, 47, -76, -96, 10, 94, -47, 0, -80]
# After sorting: [-96, -80, -80, -76, -74, -74, -73, -64, -61, -55, -47, -47, -47, -44, -29, -13, -8, 0, 0, 10, 12, 18, 25, 26, 30, 33, 47, 55, 56, 64, 65, 65, 70, 72, 76, 82, 90, 94]
# Expected result: [-96, -80, -80, -76, -74, -74, -73, -64, -61, -55, -47, -47, -47, -44, -29, -13, -8, 0, 0, 10, 12, 18, 25, 26, 30, 33, 47, 55, 56, 64, 65, 65, 70, 72, 76, 82, 90, 94]
# Test PASSED
# Current passed-to-tested ratio: 6/6
#
# TEST #7:
# Before sorting: [-47, -31, -17, -8, -36, -68, 97, 18, 4, -20, 18, -97]
# After sorting: [-97, -68, -47, -36, -31, -20, -17, -8, 4, 18, 18, 97]
# Expected result: [-97, -68, -47, -36, -31, -20, -17, -8, 4, 18, 18, 97]
# Test PASSED
# Current passed-to-tested ratio: 7/7
#
# TEST #8:
# Before sorting: [-75, -70, 19, -79, 15, -81, -87, -12, 3, -97]
# After sorting: [-97, -87, -81, -79, -75, -70, -12, 3, 15, 19]
# Expected result: [-97, -87, -81, -79, -75, -70, -12, 3, 15, 19]
# Test PASSED
# Current passed-to-tested ratio: 8/8
#
# TEST #9:
# Before sorting: [62, 46, 13, 83, -87]
# After sorting: [-87, 13, 46, 62, 83]
# Expected result: [-87, 13, 46, 62, 83]
# Test PASSED
# Current passed-to-tested ratio: 9/9
#
# TEST #10:
# Before sorting: [-56, 5, 42, 59, -63, -1, -59, -79, -93, -78, -20, 13]
# After sorting: [-93, -79, -78, -63, -59, -56, -20, -1, 5, 13, 42, 59]
# Expected result: [-93, -79, -78, -63, -59, -56, -20, -1, 5, 13, 42, 59]
# Test PASSED
# Current passed-to-tested ratio: 10/10
#
# TEST #11:
# Before sorting: [89, -25, -52, -84, 24, -25, 80, 59, 54, 90, 49, -50, 88, -2, 76, 34, -94, 27, 46, 3, 37, -93, 37, 14, -4]
# After sorting: [-94, -93, -84, -52, -50, -25, -25, -4, -2, 3, 14, 24, 27, 34, 37, 37, 46, 49, 54, 59, 76, 80, 88, 89, 90]
# Expected result: [-94, -93, -84, -52, -50, -25, -25, -4, -2, 3, 14, 24, 27, 34, 37, 37, 46, 49, 54, 59, 76, 80, 88, 89, 90]
# Test PASSED
# Current passed-to-tested ratio: 11/11
#
# TEST #12:
# Before sorting: [-27]
# After sorting: [-27]
# Expected result: [-27]
# Test PASSED
# Current passed-to-tested ratio: 12/12
#
# TEST #13:
# Before sorting: [29, -89, -70, -2, -99, -14, 26, -63]
# After sorting: [-99, -89, -70, -63, -14, -2, 26, 29]
# Expected result: [-99, -89, -70, -63, -14, -2, 26, 29]
# Test PASSED
# Current passed-to-tested ratio: 13/13
#
# TEST #14:
# Before sorting: [-17, -51, 91, 24, -11, -31, 2, -2, 70, -48, -16, 78, 28, 10, -59, 54, 10, -85, 77, -90, -12, 46, 7, -10, 38, 55, -12, 66, -94, -84, 95, -56, -18, 15, 71, -66, 56, 76, -92, -53, -35, 5, -61, 9, -76, -55, 75, -40, 9]
# After sorting: [-94, -92, -90, -85, -84, -76, -66, -61, -59, -56, -55, -53, -51, -48, -40, -35, -31, -18, -17, -16, -12, -12, -11, -10, -2, 2, 5, 7, 9, 9, 10, 10, 15, 24, 28, 38, 46, 54, 55, 56, 66, 70, 71, 75, 76, 77, 78, 91, 95]
# Expected result: [-94, -92, -90, -85, -84, -76, -66, -61, -59, -56, -55, -53, -51, -48, -40, -35, -31, -18, -17, -16, -12, -12, -11, -10, -2, 2, 5, 7, 9, 9, 10, 10, 15, 24, 28, 38, 46, 54, 55, 56, 66, 70, 71, 75, 76, 77, 78, 91, 95]
# Test PASSED
# Current passed-to-tested ratio: 14/14
#
# TEST #15:
# Before sorting: [40, -53, 20, -8, -39, 41, 28, -22, 74, -74, 96, -13, -1, -85, -78, 39, -41, 82, -80, 34, -81, 47]
# After sorting: [-85, -81, -80, -78, -74, -53, -41, -39, -22, -13, -8, -1, 20, 28, 34, 39, 40, 41, 47, 74, 82, 96]
# Expected result: [-85, -81, -80, -78, -74, -53, -41, -39, -22, -13, -8, -1, 20, 28, 34, 39, 40, 41, 47, 74, 82, 96]
# Test PASSED
# Current passed-to-tested ratio: 15/15
#
# TEST #16:
# Before sorting: [-51, -45, -9, 44, 33, -45, -82, -57, 10, -27, -36, 65, -50, -60, 88, -76, -85, -55, 50, -58, 27, -28, -9, -66, 100, 5, -76, -34, -52, 94, -77, -55, -86, -23, 80, 5, 5, 11]
# After sorting: [-86, -85, -82, -77, -76, -76, -66, -60, -58, -57, -55, -55, -52, -51, -50, -45, -45, -36, -34, -28, -27, -23, -9, -9, 5, 5, 5, 10, 11, 27, 33, 44, 50, 65, 80, 88, 94, 100]
# Expected result: [-86, -85, -82, -77, -76, -76, -66, -60, -58, -57, -55, -55, -52, -51, -50, -45, -45, -36, -34, -28, -27, -23, -9, -9, 5, 5, 5, 10, 11, 27, 33, 44, 50, 65, 80, 88, 94, 100]
# Test PASSED
# Current passed-to-tested ratio: 16/16
#
# TEST #17:
# Before sorting: [-31, -79, 52, -85, -30, 15, 86, -21, -60, -32, -77, -36, 85, -42, 57, 66, -32, 11, -51, 39]
# After sorting: [-85, -79, -77, -60, -51, -42, -36, -32, -32, -31, -30, -21, 11, 15, 39, 52, 57, 66, 85, 86]
# Expected result: [-85, -79, -77, -60, -51, -42, -36, -32, -32, -31, -30, -21, 11, 15, 39, 52, 57, 66, 85, 86]
# Test PASSED
# Current passed-to-tested ratio: 17/17
#
# TEST #18:
# Before sorting: [19, 46, -6, -12, 40, 46, 52, 24, 35, -95, 11, 23, 96, 1, 81, -64, 56, -73, 98, -96, 71, -93, 77, 72, 38, -36, 59, 91, 76, -79, -8, -20, -35]
# After sorting: [-96, -95, -93, -79, -73, -64, -36, -35, -20, -12, -8, -6, 1, 11, 19, 23, 24, 35, 38, 40, 46, 46, 52, 56, 59, 71, 72, 76, 77, 81, 91, 96, 98]
# Expected result: [-96, -95, -93, -79, -73, -64, -36, -35, -20, -12, -8, -6, 1, 11, 19, 23, 24, 35, 38, 40, 46, 46, 52, 56, 59, 71, 72, 76, 77, 81, 91, 96, 98]
# Test PASSED
# Current passed-to-tested ratio: 18/18
#
# TEST #19:
# Before sorting: [56, -2, -32, -1, 42, -75, 29, -9, 97, 41, -42, 78, -54, -45, -83, 42, 10, -50, 53, -5, 87, 55, -51, -39, -14, 97, -90, -18, 19, 90, 7, -9]
# After sorting: [-90, -83, -75, -54, -51, -50, -45, -42, -39, -32, -18, -14, -9, -9, -5, -2, -1, 7, 10, 19, 29, 41, 42, 42, 53, 55, 56, 78, 87, 90, 97, 97]
# Expected result: [-90, -83, -75, -54, -51, -50, -45, -42, -39, -32, -18, -14, -9, -9, -5, -2, -1, 7, 10, 19, 29, 41, 42, 42, 53, 55, 56, 78, 87, 90, 97, 97]
# Test PASSED
# Current passed-to-tested ratio: 19/19
#
# TEST #20:
# Before sorting: [55, 94, 83, -48, -47, 69]
# After sorting: [-48, -47, 55, 69, 83, 94]
# Expected result: [-48, -47, 55, 69, 83, 94]
# Test PASSED
# Current passed-to-tested ratio: 20/20
#
# TEST #21:
# Before sorting: [-44, -77, -95, 38, 48, 86, -75, -63, 14, 97, 35, 44, -56, -46, -45, -57, -73, -68, 67, -77, -1, -19, -62, 67, -12, 21, -79, 21, -15, -57, -89, 77, -50, -10]
# After sorting: [-95, -89, -79, -77, -77, -75, -73, -68, -63, -62, -57, -57, -56, -50, -46, -45, -44, -19, -15, -12, -10, -1, 14, 21, 21, 35, 38, 44, 48, 67, 67, 77, 86, 97]
# Expected result: [-95, -89, -79, -77, -77, -75, -73, -68, -63, -62, -57, -57, -56, -50, -46, -45, -44, -19, -15, -12, -10, -1, 14, 21, 21, 35, 38, 44, 48, 67, 67, 77, 86, 97]
# Test PASSED
# Current passed-to-tested ratio: 21/21
#
# TEST #22:
# Before sorting: [22, -60, 9, -59, 35, -25, 56, -26, 66, 2, 32, -67, 65, -28, -84]
# After sorting: [-84, -67, -60, -59, -28, -26, -25, 2, 9, 22, 32, 35, 56, 65, 66]
# Expected result: [-84, -67, -60, -59, -28, -26, -25, 2, 9, 22, 32, 35, 56, 65, 66]
# Test PASSED
# Current passed-to-tested ratio: 22/22
#
# TEST #23:
# Before sorting: [-49, -42, -66, 72, 48, 10, 68, -82, -51, -43, -31, 94, 50, 35, 42, -58, -12, -83, 16, -76, 29]
# After sorting: [-83, -82, -76, -66, -58, -51, -49, -43, -42, -31, -12, 10, 16, 29, 35, 42, 48, 50, 68, 72, 94]
# Expected result: [-83, -82, -76, -66, -58, -51, -49, -43, -42, -31, -12, 10, 16, 29, 35, 42, 48, 50, 68, 72, 94]
# Test PASSED
# Current passed-to-tested ratio: 23/23
#
# TEST #24:
# Before sorting: [-69, 4, -6, -98, 21, 78, -100, -32, 8, -48, -28, 94, -88, -3, 82, 33, 78, 23, 18, -48, 63, -38, -55, 75, -26, -25, 21, -74, 77, -52, 74, 1, 60, -88, 89, -78, 99, 30, 36]
# After sorting: [-100, -98, -88, -88, -78, -74, -69, -55, -52, -48, -48, -38, -32, -28, -26, -25, -6, -3, 1, 4, 8, 18, 21, 21, 23, 30, 33, 36, 60, 63, 74, 75, 77, 78, 78, 82, 89, 94, 99]
# Expected result: [-100, -98, -88, -88, -78, -74, -69, -55, -52, -48, -48, -38, -32, -28, -26, -25, -6, -3, 1, 4, 8, 18, 21, 21, 23, 30, 33, 36, 60, 63, 74, 75, 77, 78, 78, 82, 89, 94, 99]
# Test PASSED
# Current passed-to-tested ratio: 24/24
#
# TEST #25:
# Before sorting: [16, 44, -53, 37, -17, -25, 24, -12, -26, -53, -5, 18, 11, -38, -49, -63, -59, -6, 18, 22, 42]
# After sorting: [-63, -59, -53, -53, -49, -38, -26, -25, -17, -12, -6, -5, 11, 16, 18, 18, 22, 24, 37, 42, 44]
# Expected result: [-63, -59, -53, -53, -49, -38, -26, -25, -17, -12, -6, -5, 11, 16, 18, 18, 22, 24, 37, 42, 44]
# Test PASSED
# Current passed-to-tested ratio: 25/25
#
# TEST #26:
# Before sorting: [-97, 38, 36, 86, 46, 39, 87, -28, -42, -39, 25, 32, -55, -99, -77, -18, -81, 69, -44, 0, -70, 72, 73, 70, -77, 91]
# After sorting: [-99, -97, -81, -77, -77, -70, -55, -44, -42, -39, -28, -18, 0, 25, 32, 36, 38, 39, 46, 69, 70, 72, 73, 86, 87, 91]
# Expected result: [-99, -97, -81, -77, -77, -70, -55, -44, -42, -39, -28, -18, 0, 25, 32, 36, 38, 39, 46, 69, 70, 72, 73, 86, 87, 91]
# Test PASSED
# Current passed-to-tested ratio: 26/26
#
# TEST #27:
# Before sorting: [43, 73, 96, 90, 76, -93, 72, 7, -55, -11, 14, 45, 14, 57, 65, -45, -4, 35]
# After sorting: [-93, -55, -45, -11, -4, 7, 14, 14, 35, 43, 45, 57, 65, 72, 73, 76, 90, 96]
# Expected result: [-93, -55, -45, -11, -4, 7, 14, 14, 35, 43, 45, 57, 65, 72, 73, 76, 90, 96]
# Test PASSED
# Current passed-to-tested ratio: 27/27
#
# TEST #28:
# Before sorting: [43, -71, -20, -36, -26, 22, 19, 31, 90, -84, 61, -72, 13, 63, -46, 75, -62, -24, -41, -5, -87, -37, -36, -14, -73, -37, -96, -64, -94, 93, 42, -6, -41, -4]
# After sorting: [-96, -94, -87, -84, -73, -72, -71, -64, -62, -46, -41, -41, -37, -37, -36, -36, -26, -24, -20, -14, -6, -5, -4, 13, 19, 22, 31, 42, 43, 61, 63, 75, 90, 93]
# Expected result: [-96, -94, -87, -84, -73, -72, -71, -64, -62, -46, -41, -41, -37, -37, -36, -36, -26, -24, -20, -14, -6, -5, -4, 13, 19, 22, 31, 42, 43, 61, 63, 75, 90, 93]
# Test PASSED
# Current passed-to-tested ratio: 28/28
#
# TEST #29:
# Before sorting: [95, 15, -13, -15, -11, -32, -4, 20, 60, -14, 95, -2]
# After sorting: [-32, -15, -14, -13, -11, -4, -2, 15, 20, 60, 95, 95]
# Expected result: [-32, -15, -14, -13, -11, -4, -2, 15, 20, 60, 95, 95]
# Test PASSED
# Current passed-to-tested ratio: 29/29
#
# TEST #30:
# Before sorting: [-9, -72, -94, -99, 6, 27, 72, 82, -17, -48, -18, 82, -4, 22, 6, 52, -11, -96, -25, 69, -44, -11, 5, -22, 49, 90, 26, -94, -43, -6, -29, 24, -18, -15, -77, -47, -53, -80, -36, 17, -60, -85]
# After sorting: [-99, -96, -94, -94, -85, -80, -77, -72, -60, -53, -48, -47, -44, -43, -36, -29, -25, -22, -18, -18, -17, -15, -11, -11, -9, -6, -4, 5, 6, 6, 17, 22, 24, 26, 27, 49, 52, 69, 72, 82, 82, 90]
# Expected result: [-99, -96, -94, -94, -85, -80, -77, -72, -60, -53, -48, -47, -44, -43, -36, -29, -25, -22, -18, -18, -17, -15, -11, -11, -9, -6, -4, 5, 6, 6, 17, 22, 24, 26, 27, 49, 52, 69, 72, 82, 82, 90]
# Test PASSED
# Current passed-to-tested ratio: 30/30
#
# TEST #31:
# Before sorting: [-71, -33, -74, -69, -89, -92, 64, -86, 41, -77, -53, 10, 33, 48, 10, 13, -48, -20, 23, 95, -84, 25, 78, -2]
# After sorting: [-92, -89, -86, -84, -77, -74, -71, -69, -53, -48, -33, -20, -2, 10, 10, 13, 23, 25, 33, 41, 48, 64, 78, 95]
# Expected result: [-92, -89, -86, -84, -77, -74, -71, -69, -53, -48, -33, -20, -2, 10, 10, 13, 23, 25, 33, 41, 48, 64, 78, 95]
# Test PASSED
# Current passed-to-tested ratio: 31/31
#
# TEST #32:
# Before sorting: [18, 77, -84, -79, 69]
# After sorting: [-84, -79, 18, 69, 77]
# Expected result: [-84, -79, 18, 69, 77]
# Test PASSED
# Current passed-to-tested ratio: 32/32
#
# TEST #33:
# Before sorting: [55, 58, -51, -62, 19, 38, -50, -12, 1, 84]
# After sorting: [-62, -51, -50, -12, 1, 19, 38, 55, 58, 84]
# Expected result: [-62, -51, -50, -12, 1, 19, 38, 55, 58, 84]
# Test PASSED
# Current passed-to-tested ratio: 33/33
#
# TEST #34:
# Before sorting: [87, -100, -92, 53, 100, -52, -41, -80, -42, -100, -4]
# After sorting: [-100, -100, -92, -80, -52, -42, -41, -4, 53, 87, 100]
# Expected result: [-100, -100, -92, -80, -52, -42, -41, -4, 53, 87, 100]
# Test PASSED
# Current passed-to-tested ratio: 34/34
#
# TEST #35:
# Before sorting: [-79, -97, 96, 4, 3, -41, 18, -96, 35, -9, 11, 47, -75, -39, 73, -84, 27, -72, -82, 50, -26, 18, 82, -85, -28, 60, 7, -24, -2, 2, -41, 56, 16, -36, 88, -59, 12, 93, 63, -39, -11, 98, -60, -40]
# After sorting: [-97, -96, -85, -84, -82, -79, -75, -72, -60, -59, -41, -41, -40, -39, -39, -36, -28, -26, -24, -11, -9, -2, 2, 3, 4, 7, 11, 12, 16, 18, 18, 27, 35, 47, 50, 56, 60, 63, 73, 82, 88, 93, 96, 98]
# Expected result: [-97, -96, -85, -84, -82, -79, -75, -72, -60, -59, -41, -41, -40, -39, -39, -36, -28, -26, -24, -11, -9, -2, 2, 3, 4, 7, 11, 12, 16, 18, 18, 27, 35, 47, 50, 56, 60, 63, 73, 82, 88, 93, 96, 98]
# Test PASSED
# Current passed-to-tested ratio: 35/35
#
# TEST #36:
# Before sorting: [-61, 77, -32, -5, -65, 54, 27, 57, 28]
# After sorting: [-65, -61, -32, -5, 27, 28, 54, 57, 77]
# Expected result: [-65, -61, -32, -5, 27, 28, 54, 57, 77]
# Test PASSED
# Current passed-to-tested ratio: 36/36
#
# TEST #37:
# Before sorting: [-65, -24, -35, -51, -57, 1, 55, -46, 86, -15, 13, -2, 41, -90, 92, 34, 89, -41, 65, -48, 74, 42, 57, 76, -34, -49]
# After sorting: [-90, -65, -57, -51, -49, -48, -46, -41, -35, -34, -24, -15, -2, 1, 13, 34, 41, 42, 55, 57, 65, 74, 76, 86, 89, 92]
# Expected result: [-90, -65, -57, -51, -49, -48, -46, -41, -35, -34, -24, -15, -2, 1, 13, 34, 41, 42, 55, 57, 65, 74, 76, 86, 89, 92]
# Test PASSED
# Current passed-to-tested ratio: 37/37
#
# TEST #38:
# Before sorting: [86, 65, 6, 86, 80, 17, 59, 18, 42, -16, -28, 26, 45, 93, 60, -92, -99, -1, 27, 11, -15, -85, -59, 1, 52, -69, -42, 64, -38, -13, 47, -49, -78, -72, -90, 62, 34, -33, 12, 39, -43, 32, -56, -81]
# After sorting: [-99, -92, -90, -85, -81, -78, -72, -69, -59, -56, -49, -43, -42, -38, -33, -28, -16, -15, -13, -1, 1, 6, 11, 12, 17, 18, 26, 27, 32, 34, 39, 42, 45, 47, 52, 59, 60, 62, 64, 65, 80, 86, 86, 93]
# Expected result: [-99, -92, -90, -85, -81, -78, -72, -69, -59, -56, -49, -43, -42, -38, -33, -28, -16, -15, -13, -1, 1, 6, 11, 12, 17, 18, 26, 27, 32, 34, 39, 42, 45, 47, 52, 59, 60, 62, 64, 65, 80, 86, 86, 93]
# Test PASSED
# Current passed-to-tested ratio: 38/38
#
# TEST #39:
# Before sorting: [7, 72, -5, -58, 10, 30, -32, 81, -93, -56, 50, -30, -10, 36, -58, 7, -39, 8, 65, -66, 26, 95, 75, 77, -36, -32, 27, 27, 73, -32, 6, 27, 82, -55, 37, -65]
# After sorting: [-93, -66, -65, -58, -58, -56, -55, -39, -36, -32, -32, -32, -30, -10, -5, 6, 7, 7, 8, 10, 26, 27, 27, 27, 30, 36, 37, 50, 65, 72, 73, 75, 77, 81, 82, 95]
# Expected result: [-93, -66, -65, -58, -58, -56, -55, -39, -36, -32, -32, -32, -30, -10, -5, 6, 7, 7, 8, 10, 26, 27, 27, 27, 30, 36, 37, 50, 65, 72, 73, 75, 77, 81, 82, 95]
# Test PASSED
# Current passed-to-tested ratio: 39/39
#
# TEST #40:
# Before sorting: [-75, 51, 51]
# After sorting: [-75, 51, 51]
# Expected result: [-75, 51, 51]
# Test PASSED
# Current passed-to-tested ratio: 40/40
#
# TEST #41:
# Before sorting: [2, -43, 68, 4, 44, 79, 92, 50]
# After sorting: [-43, 2, 4, 44, 50, 68, 79, 92]
# Expected result: [-43, 2, 4, 44, 50, 68, 79, 92]
# Test PASSED
# Current passed-to-tested ratio: 41/41
#
# TEST #42:
# Before sorting: [64, -36, 19, 91, -45, -41]
# After sorting: [-45, -41, -36, 19, 64, 91]
# Expected result: [-45, -41, -36, 19, 64, 91]
# Test PASSED
# Current passed-to-tested ratio: 42/42
#
# TEST #43:
# Before sorting: [-89, 78, -35, -12, 7, 64, 96, -36, -84, 66, -18, 68, -66, 94, -59, 94, 73, 100, -91, 13, -56, -1, -58, 79, 23]
# After sorting: [-91, -89, -84, -66, -59, -58, -56, -36, -35, -18, -12, -1, 7, 13, 23, 64, 66, 68, 73, 78, 79, 94, 94, 96, 100]
# Expected result: [-91, -89, -84, -66, -59, -58, -56, -36, -35, -18, -12, -1, 7, 13, 23, 64, 66, 68, 73, 78, 79, 94, 94, 96, 100]
# Test PASSED
# Current passed-to-tested ratio: 43/43
#
# TEST #44:
# Before sorting: [-25, 44, -48, 2, -20, -44, 94, -60, -81, 4, 89, 36, 33, -14, -42, 58, 46, 78, -41, -32, 40, -70, -14, -59, -30, 58, 48, -53, 78, 45, -35, -21, -79, 9, 85, 54, -91, -2, -50, 64, -35, -74, -43, -36]
# After sorting: [-91, -81, -79, -74, -70, -60, -59, -53, -50, -48, -44, -43, -42, -41, -36, -35, -35, -32, -30, -25, -21, -20, -14, -14, -2, 2, 4, 9, 33, 36, 40, 44, 45, 46, 48, 54, 58, 58, 64, 78, 78, 85, 89, 94]
# Expected result: [-91, -81, -79, -74, -70, -60, -59, -53, -50, -48, -44, -43, -42, -41, -36, -35, -35, -32, -30, -25, -21, -20, -14, -14, -2, 2, 4, 9, 33, 36, 40, 44, 45, 46, 48, 54, 58, 58, 64, 78, 78, 85, 89, 94]
# Test PASSED
# Current passed-to-tested ratio: 44/44
#
# TEST #45:
# Before sorting: [93, -60, -66, 65, 63, -19, 11, -51, 91, -34, -41, 82, -36, -44, 42, -79, -5, -71, -17, 71, -52, 24, -21]
# After sorting: [-79, -71, -66, -60, -52, -51, -44, -41, -36, -34, -21, -19, -17, -5, 11, 24, 42, 63, 65, 71, 82, 91, 93]
# Expected result: [-79, -71, -66, -60, -52, -51, -44, -41, -36, -34, -21, -19, -17, -5, 11, 24, 42, 63, 65, 71, 82, 91, 93]
# Test PASSED
# Current passed-to-tested ratio: 45/45
#
# TEST #46:
# Before sorting: [-85, 99, -36, 12, -43, -18, -63, 99, -16, -69, 55, -12, -74]
# After sorting: [-85, -74, -69, -63, -43, -36, -18, -16, -12, 12, 55, 99, 99]
# Expected result: [-85, -74, -69, -63, -43, -36, -18, -16, -12, 12, 55, 99, 99]
# Test PASSED
# Current passed-to-tested ratio: 46/46
#
# TEST #47:
# Before sorting: [72, -63, 93, 23, -71, 73, 13, -48, -46, -67, 0, -26, -32, 71, -30, 61, 24, 51, -88, 18, 75, -14, -57, -22]
# After sorting: [-88, -71, -67, -63, -57, -48, -46, -32, -30, -26, -22, -14, 0, 13, 18, 23, 24, 51, 61, 71, 72, 73, 75, 93]
# Expected result: [-88, -71, -67, -63, -57, -48, -46, -32, -30, -26, -22, -14, 0, 13, 18, 23, 24, 51, 61, 71, 72, 73, 75, 93]
# Test PASSED
# Current passed-to-tested ratio: 47/47
#
# TEST #48:
# Before sorting: [29, 56, 27, 75, 68]
# After sorting: [27, 29, 56, 68, 75]
# Expected result: [27, 29, 56, 68, 75]
# Test PASSED
# Current passed-to-tested ratio: 48/48
#
# TEST #49:
# Before sorting: [-28, 47, 52, 99, -80, -66, 41, -3, 98, -24]
# After sorting: [-80, -66, -28, -24, -3, 41, 47, 52, 98, 99]
# Expected result: [-80, -66, -28, -24, -3, 41, 47, 52, 98, 99]
# Test PASSED
# Current passed-to-tested ratio: 49/49
#
# TEST #50:
# Before sorting: [17, -53, 100, -43, -14, -37, -2, -8, -22, 30, -41, 28, -42, -65, -67, 49, 1, 0, -75, 92, 39, 69, 24, 82, -10, -18, 21, 44, 19, 77, -40, -61, 64, 53, -43, 50, 95]
# After sorting: [-75, -67, -65, -61, -53, -43, -43, -42, -41, -40, -37, -22, -18, -14, -10, -8, -2, 0, 1, 17, 19, 21, 24, 28, 30, 39, 44, 49, 50, 53, 64, 69, 77, 82, 92, 95, 100]
# Expected result: [-75, -67, -65, -61, -53, -43, -43, -42, -41, -40, -37, -22, -18, -14, -10, -8, -2, 0, 1, 17, 19, 21, 24, 28, 30, 39, 44, 49, 50, 53, 64, 69, 77, 82, 92, 95, 100]
# Test PASSED
# Current passed-to-tested ratio: 50/50
#
# TEST #51:
# Before sorting: [-97, -9, 9, -52, 4, 57, -89, 14, -41, 65, 26, -54, -46, -8, 40, -92, -69, 92, -82, 31, -38, 73, 39, 66, -93, -12, -23, 20, -81, 43, -21, 27, 83]
# After sorting: [-97, -93, -92, -89, -82, -81, -69, -54, -52, -46, -41, -38, -23, -21, -12, -9, -8, 4, 9, 14, 20, 26, 27, 31, 39, 40, 43, 57, 65, 66, 73, 83, 92]
# Expected result: [-97, -93, -92, -89, -82, -81, -69, -54, -52, -46, -41, -38, -23, -21, -12, -9, -8, 4, 9, 14, 20, 26, 27, 31, 39, 40, 43, 57, 65, 66, 73, 83, 92]
# Test PASSED
# Current passed-to-tested ratio: 51/51
#
# TEST #52:
# Before sorting: [-28, 86, 29, -89, -82, -87, -2, -92, -35, -96, 71, 5, 53, -90, 100, -56, -95, -88]
# After sorting: [-96, -95, -92, -90, -89, -88, -87, -82, -56, -35, -28, -2, 5, 29, 53, 71, 86, 100]
# Expected result: [-96, -95, -92, -90, -89, -88, -87, -82, -56, -35, -28, -2, 5, 29, 53, 71, 86, 100]
# Test PASSED
# Current passed-to-tested ratio: 52/52
#
# TEST #53:
# Before sorting: [-98, -60, 26, -28, -95, -95, 67, 49, 19, 97, 0, 3, 78, 80, 67, 54, 7, -21, 74, 100, -48, -27, 45, 88, -80, -25, 55, 27, 91, -97]
# After sorting: [-98, -97, -95, -95, -80, -60, -48, -28, -27, -25, -21, 0, 3, 7, 19, 26, 27, 45, 49, 54, 55, 67, 67, 74, 78, 80, 88, 91, 97, 100]
# Expected result: [-98, -97, -95, -95, -80, -60, -48, -28, -27, -25, -21, 0, 3, 7, 19, 26, 27, 45, 49, 54, 55, 67, 67, 74, 78, 80, 88, 91, 97, 100]
# Test PASSED
# Current passed-to-tested ratio: 53/53
#
# TEST #54:
# Before sorting: [-99, 80, 61, -12, -81, -90, 12, -56, 87, 70, -34, -7, -21, 22, -15]
# After sorting: [-99, -90, -81, -56, -34, -21, -15, -12, -7, 12, 22, 61, 70, 80, 87]
# Expected result: [-99, -90, -81, -56, -34, -21, -15, -12, -7, 12, 22, 61, 70, 80, 87]
# Test PASSED
# Current passed-to-tested ratio: 54/54
#
# TEST #55:
# Before sorting: [-100, -87, -27, 70, -84, -2, -73, 30, 68, 99, 70, -25, 3, 98, -71, 90]
# After sorting: [-100, -87, -84, -73, -71, -27, -25, -2, 3, 30, 68, 70, 70, 90, 98, 99]
# Expected result: [-100, -87, -84, -73, -71, -27, -25, -2, 3, 30, 68, 70, 70, 90, 98, 99]
# Test PASSED
# Current passed-to-tested ratio: 55/55
#
# TEST #56:
# Before sorting: [-61, -23, -20, -83, 55, 87, -9, -24, 98, 30, 47, 35, 27, -16, -41, -20, 96, 58, 83, 3, 57, 81, 56, -36, -68, 67, 95, 11, -15, 33, 91, 22, 60, 10, -51, -7, 42, 89, 49, 64, -93, -44, 76, -13, -67]
# After sorting: [-93, -83, -68, -67, -61, -51, -44, -41, -36, -24, -23, -20, -20, -16, -15, -13, -9, -7, 3, 10, 11, 22, 27, 30, 33, 35, 42, 47, 49, 55, 56, 57, 58, 60, 64, 67, 76, 81, 83, 87, 89, 91, 95, 96, 98]
# Expected result: [-93, -83, -68, -67, -61, -51, -44, -41, -36, -24, -23, -20, -20, -16, -15, -13, -9, -7, 3, 10, 11, 22, 27, 30, 33, 35, 42, 47, 49, 55, 56, 57, 58, 60, 64, 67, 76, 81, 83, 87, 89, 91, 95, 96, 98]
# Test PASSED
# Current passed-to-tested ratio: 56/56
#
# TEST #57:
# Before sorting: [28, -65, -34, 86, 48, -6, 4, -15, 22, -11, 4, -52, -26, -50, 8, 35, 95, 21, 95, 49, 9, -16, -23, -56, -46, -41, 12, 88, -80, -6, -56, -62, 78, -93, -51, -36, -83, -99]
# After sorting: [-99, -93, -83, -80, -65, -62, -56, -56, -52, -51, -50, -46, -41, -36, -34, -26, -23, -16, -15, -11, -6, -6, 4, 4, 8, 9, 12, 21, 22, 28, 35, 48, 49, 78, 86, 88, 95, 95]
# Expected result: [-99, -93, -83, -80, -65, -62, -56, -56, -52, -51, -50, -46, -41, -36, -34, -26, -23, -16, -15, -11, -6, -6, 4, 4, 8, 9, 12, 21, 22, 28, 35, 48, 49, 78, 86, 88, 95, 95]
# Test PASSED
# Current passed-to-tested ratio: 57/57
#
# TEST #58:
# Before sorting: [-59, -15, -20, -9, -59, 86, -22, -57, -85, 8, -81, 5, 22, -57, -38, 51, -42, -1, 30, -84, 3, -24, -31, 1, 95, 77, -57, 85, 13, -20, 80, -98, -83, -5, -85, 65, -75, -18, -25, -35, -40, 88, -66, 9, -100, 100, -70, -24, -69, 68]
# After sorting: [-100, -98, -85, -85, -84, -83, -81, -75, -70, -69, -66, -59, -59, -57, -57, -57, -42, -40, -38, -35, -31, -25, -24, -24, -22, -20, -20, -18, -15, -9, -5, -1, 1, 3, 5, 8, 9, 13, 22, 30, 51, 65, 68, 77, 80, 85, 86, 88, 95, 100]
# Expected result: [-100, -98, -85, -85, -84, -83, -81, -75, -70, -69, -66, -59, -59, -57, -57, -57, -42, -40, -38, -35, -31, -25, -24, -24, -22, -20, -20, -18, -15, -9, -5, -1, 1, 3, 5, 8, 9, 13, 22, 30, 51, 65, 68, 77, 80, 85, 86, 88, 95, 100]
# Test PASSED
# Current passed-to-tested ratio: 58/58
#
# TEST #59:
# Before sorting: [52, 32, 20, -14, 25, -76, 22, 59, 52, 59, 81, -62, -10, 90, 13, -58, 73, 10, -8, -37, 61, 81, -11, 74, 3, 5, 22, 74, 100, -16, 52, -5, 9, 29, -85, 28, -31, 86, -94, 93, -54, -79]
# After sorting: [-94, -85, -79, -76, -62, -58, -54, -37, -31, -16, -14, -11, -10, -8, -5, 3, 5, 9, 10, 13, 20, 22, 22, 25, 28, 29, 32, 52, 52, 52, 59, 59, 61, 73, 74, 74, 81, 81, 86, 90, 93, 100]
# Expected result: [-94, -85, -79, -76, -62, -58, -54, -37, -31, -16, -14, -11, -10, -8, -5, 3, 5, 9, 10, 13, 20, 22, 22, 25, 28, 29, 32, 52, 52, 52, 59, 59, 61, 73, 74, 74, 81, 81, 86, 90, 93, 100]
# Test PASSED
# Current passed-to-tested ratio: 59/59
#
# TEST #60:
# Before sorting: [-88, 79, -10, 19, -68, -94, 66, 45, 79, -7, -24, 73, 66, -73, 77, 50, 43, 68, 91, -65, 44, -99, 32, -86, 14, -37]
# After sorting: [-99, -94, -88, -86, -73, -68, -65, -37, -24, -10, -7, 14, 19, 32, 43, 44, 45, 50, 66, 66, 68, 73, 77, 79, 79, 91]
# Expected result: [-99, -94, -88, -86, -73, -68, -65, -37, -24, -10, -7, 14, 19, 32, 43, 44, 45, 50, 66, 66, 68, 73, 77, 79, 79, 91]
# Test PASSED
# Current passed-to-tested ratio: 60/60
#
# TEST #61:
# Before sorting: [96, 80, 27, 53, 30, 91, -76, 48, 65, 82, 15, -44, 45, -90, 71, 55, 74, 100, -64, 39, -73, -30, 36, 27]
# After sorting: [-90, -76, -73, -64, -44, -30, 15, 27, 27, 30, 36, 39, 45, 48, 53, 55, 65, 71, 74, 80, 82, 91, 96, 100]
# Expected result: [-90, -76, -73, -64, -44, -30, 15, 27, 27, 30, 36, 39, 45, 48, 53, 55, 65, 71, 74, 80, 82, 91, 96, 100]
# Test PASSED
# Current passed-to-tested ratio: 61/61
#
# TEST #62:
# Before sorting: [-59, -15, 45, 14, 14, 74, -67, 85, -21, 74, 91, -54, 94, -77, -94, 96, -25, 58, -2]
# After sorting: [-94, -77, -67, -59, -54, -25, -21, -15, -2, 14, 14, 45, 58, 74, 74, 85, 91, 94, 96]
# Expected result: [-94, -77, -67, -59, -54, -25, -21, -15, -2, 14, 14, 45, 58, 74, 74, 85, 91, 94, 96]
# Test PASSED
# Current passed-to-tested ratio: 62/62
#
# TEST #63:
# Before sorting: [17, -24, 38, -100, -61, -4, 55, -77, -73, 98, -35, 99, 91, -69, 40, -12, 25, 11, -39, 63, -73, 50, -28, 29, 24, -47, 49, -52, 8, -89, -96, -37, 90, 50, 79, 5, -47, -44, 58, -89, -57, -50]
# After sorting: [-100, -96, -89, -89, -77, -73, -73, -69, -61, -57, -52, -50, -47, -47, -44, -39, -37, -35, -28, -24, -12, -4, 5, 8, 11, 17, 24, 25, 29, 38, 40, 49, 50, 50, 55, 58, 63, 79, 90, 91, 98, 99]
# Expected result: [-100, -96, -89, -89, -77, -73, -73, -69, -61, -57, -52, -50, -47, -47, -44, -39, -37, -35, -28, -24, -12, -4, 5, 8, 11, 17, 24, 25, 29, 38, 40, 49, 50, 50, 55, 58, 63, 79, 90, 91, 98, 99]
# Test PASSED
# Current passed-to-tested ratio: 63/63
#
# TEST #64:
# Before sorting: [-27, 92, -83, 70, 40, 25, -29, 22]
# After sorting: [-83, -29, -27, 22, 25, 40, 70, 92]
# Expected result: [-83, -29, -27, 22, 25, 40, 70, 92]
# Test PASSED
# Current passed-to-tested ratio: 64/64
#
# TEST #65:
# Before sorting: [-58, -14, 13, 67, -15, 37, -28, -33, -90, 41, -34, 77, 48, 80, -81, -82, 67, 68, -34, 94, -70, -41, 68, 29, -46, 6, 48, 86, 95, 42, 50, 81, -25, 20, 73, 10, 91, 30, -29, -92, 85, 24, -57, 49, 95, 55, -81, -2]
# After sorting: [-92, -90, -82, -81, -81, -70, -58, -57, -46, -41, -34, -34, -33, -29, -28, -25, -15, -14, -2, 6, 10, 13, 20, 24, 29, 30, 37, 41, 42, 48, 48, 49, 50, 55, 67, 67, 68, 68, 73, 77, 80, 81, 85, 86, 91, 94, 95, 95]
# Expected result: [-92, -90, -82, -81, -81, -70, -58, -57, -46, -41, -34, -34, -33, -29, -28, -25, -15, -14, -2, 6, 10, 13, 20, 24, 29, 30, 37, 41, 42, 48, 48, 49, 50, 55, 67, 67, 68, 68, 73, 77, 80, 81, 85, 86, 91, 94, 95, 95]
# Test PASSED
# Current passed-to-tested ratio: 65/65
#
# TEST #66:
# Before sorting: [-38, 8, -66, 22, -11, 85, 100, 14, -34, -19, 70, 63, -87, -72, -46, 51, 61, -92, -36, -30, -30, -51, -31, -84, 80, -48, 46, -37, -47, -22, -14, 77, 10, 23, -28, -61, -53, -42, -74, -63, -79, 52, 69, -52, 23, -64, -83, 18]
# After sorting: [-92, -87, -84, -83, -79, -74, -72, -66, -64, -63, -61, -53, -52, -51, -48, -47, -46, -42, -38, -37, -36, -34, -31, -30, -30, -28, -22, -19, -14, -11, 8, 10, 14, 18, 22, 23, 23, 46, 51, 52, 61, 63, 69, 70, 77, 80, 85, 100]
# Expected result: [-92, -87, -84, -83, -79, -74, -72, -66, -64, -63, -61, -53, -52, -51, -48, -47, -46, -42, -38, -37, -36, -34, -31, -30, -30, -28, -22, -19, -14, -11, 8, 10, 14, 18, 22, 23, 23, 46, 51, 52, 61, 63, 69, 70, 77, 80, 85, 100]
# Test PASSED
# Current passed-to-tested ratio: 66/66
#
# TEST #67:
# Before sorting: [-2, -88, -46, 19, 61, -65, -90, -19, 49, -25, -81, 61, 87, 100, -91, -2, -46, 45, -7, 17, 31, -71, 0, -76, 66, 2, 85, -30, 64, 95, 24, 59, -29, -41, 59, 81, -97, -48, -38, -21, -19, -16, 49, -24, -6, -20, -6]
# After sorting: [-97, -91, -90, -88, -81, -76, -71, -65, -48, -46, -46, -41, -38, -30, -29, -25, -24, -21, -20, -19, -19, -16, -7, -6, -6, -2, -2, 0, 2, 17, 19, 24, 31, 45, 49, 49, 59, 59, 61, 61, 64, 66, 81, 85, 87, 95, 100]
# Expected result: [-97, -91, -90, -88, -81, -76, -71, -65, -48, -46, -46, -41, -38, -30, -29, -25, -24, -21, -20, -19, -19, -16, -7, -6, -6, -2, -2, 0, 2, 17, 19, 24, 31, 45, 49, 49, 59, 59, 61, 61, 64, 66, 81, 85, 87, 95, 100]
# Test PASSED
# Current passed-to-tested ratio: 67/67
#
# TEST #68:
# Before sorting: [-69, -72, 86, -6, 80, -89, -100, 92, -31, 0, 89, 35, -40, 33, 69, 62, -14, -92, 14, 44, 55, 17, -12, 55, 80]
# After sorting: [-100, -92, -89, -72, -69, -40, -31, -14, -12, -6, 0, 14, 17, 33, 35, 44, 55, 55, 62, 69, 80, 80, 86, 89, 92]
# Expected result: [-100, -92, -89, -72, -69, -40, -31, -14, -12, -6, 0, 14, 17, 33, 35, 44, 55, 55, 62, 69, 80, 80, 86, 89, 92]
# Test PASSED
# Current passed-to-tested ratio: 68/68
#
# TEST #69:
# Before sorting: [-17, 47, -11, -34, -26, -41, 85, -64, 100, -99, -77, -75, -34, -72]
# After sorting: [-99, -77, -75, -72, -64, -41, -34, -34, -26, -17, -11, 47, 85, 100]
# Expected result: [-99, -77, -75, -72, -64, -41, -34, -34, -26, -17, -11, 47, 85, 100]
# Test PASSED
# Current passed-to-tested ratio: 69/69
#
# TEST #70:
# Before sorting: [-83, 42, -81, 30, -48, 78, -70, 66, 86, 89, 56, 89, -67, -73, 100, -12, -56, -44, 95, -100, -30, -48, 39, 92, 84, -17, -35]
# After sorting: [-100, -83, -81, -73, -70, -67, -56, -48, -48, -44, -35, -30, -17, -12, 30, 39, 42, 56, 66, 78, 84, 86, 89, 89, 92, 95, 100]
# Expected result: [-100, -83, -81, -73, -70, -67, -56, -48, -48, -44, -35, -30, -17, -12, 30, 39, 42, 56, 66, 78, 84, 86, 89, 89, 92, 95, 100]
# Test PASSED
# Current passed-to-tested ratio: 70/70
#
# TEST #71:
# Before sorting: [66, -65, -54, 39, 57, 22, 29, 11]
# After sorting: [-65, -54, 11, 22, 29, 39, 57, 66]
# Expected result: [-65, -54, 11, 22, 29, 39, 57, 66]
# Test PASSED
# Current passed-to-tested ratio: 71/71
#
# TEST #72:
# Before sorting: [29, -96, -47, 9, 57, -22, -48, 73, 17, 30, 96, -72, 5, -9, -93, -30, -76, -24, 6, -24, -69, -99, -90, -10, -99, -16, 28, 30, -23, 54, -19]
# After sorting: [-99, -99, -96, -93, -90, -76, -72, -69, -48, -47, -30, -24, -24, -23, -22, -19, -16, -10, -9, 5, 6, 9, 17, 28, 29, 30, 30, 54, 57, 73, 96]
# Expected result: [-99, -99, -96, -93, -90, -76, -72, -69, -48, -47, -30, -24, -24, -23, -22, -19, -16, -10, -9, 5, 6, 9, 17, 28, 29, 30, 30, 54, 57, 73, 96]
# Test PASSED
# Current passed-to-tested ratio: 72/72
#
# TEST #73:
# Before sorting: [-38, 96, 69, 60, -22, 1, -32, 10, 61, -93, 48, 32, 90, 74, -80, 26, -87, -95, 86, -47, 93, 89, -74, 39, 78, -54, -99, 99, -100, 74, 94, -46, -25]
# After sorting: [-100, -99, -95, -93, -87, -80, -74, -54, -47, -46, -38, -32, -25, -22, 1, 10, 26, 32, 39, 48, 60, 61, 69, 74, 74, 78, 86, 89, 90, 93, 94, 96, 99]
# Expected result: [-100, -99, -95, -93, -87, -80, -74, -54, -47, -46, -38, -32, -25, -22, 1, 10, 26, 32, 39, 48, 60, 61, 69, 74, 74, 78, 86, 89, 90, 93, 94, 96, 99]
# Test PASSED
# Current passed-to-tested ratio: 73/73
#
# TEST #74:
# Before sorting: [-87, 27, 9, -30, -31, 9, -12, -26, -41, 40, 19, 35, 92, 4, 36, 10, -45, 37, 50, -6, 100, -78, 33, -68, 82, 25]
# After sorting: [-87, -78, -68, -45, -41, -31, -30, -26, -12, -6, 4, 9, 9, 10, 19, 25, 27, 33, 35, 36, 37, 40, 50, 82, 92, 100]
# Expected result: [-87, -78, -68, -45, -41, -31, -30, -26, -12, -6, 4, 9, 9, 10, 19, 25, 27, 33, 35, 36, 37, 40, 50, 82, 92, 100]
# Test PASSED
# Current passed-to-tested ratio: 74/74
#
# TEST #75:
# Before sorting: [-61]
# After sorting: [-61]
# Expected result: [-61]
# Test PASSED
# Current passed-to-tested ratio: 75/75
#
# TEST #76:
# Before sorting: [-56, -80, -25, 75, -75, 76, 4, 14, -54, 87, 32, 21, 54, 10, 31, 30]
# After sorting: [-80, -75, -56, -54, -25, 4, 10, 14, 21, 30, 31, 32, 54, 75, 76, 87]
# Expected result: [-80, -75, -56, -54, -25, 4, 10, 14, 21, 30, 31, 32, 54, 75, 76, 87]
# Test PASSED
# Current passed-to-tested ratio: 76/76
#
# TEST #77:
# Before sorting: [-61, -82, -88, 37, 15, -54, 78, -99, -14, -61, 71, -20, -75, 65, 14, -20, 43, 10, 77, -93]
# After sorting: [-99, -93, -88, -82, -75, -61, -61, -54, -20, -20, -14, 10, 14, 15, 37, 43, 65, 71, 77, 78]
# Expected result: [-99, -93, -88, -82, -75, -61, -61, -54, -20, -20, -14, 10, 14, 15, 37, 43, 65, 71, 77, 78]
# Test PASSED
# Current passed-to-tested ratio: 77/77
#
# TEST #78:
# Before sorting: [82, 7, -85, 60, 58, 73, -14, 10, -10, -52, 95, -36, 38, -4, -98, -23, -97, -3, 20, -4, -69, 42, -2, 77, 42, 58, -79, 1, -97, -8, -71, -74, 8, 80]
# After sorting: [-98, -97, -97, -85, -79, -74, -71, -69, -52, -36, -23, -14, -10, -8, -4, -4, -3, -2, 1, 7, 8, 10, 20, 38, 42, 42, 58, 58, 60, 73, 77, 80, 82, 95]
# Expected result: [-98, -97, -97, -85, -79, -74, -71, -69, -52, -36, -23, -14, -10, -8, -4, -4, -3, -2, 1, 7, 8, 10, 20, 38, 42, 42, 58, 58, 60, 73, 77, 80, 82, 95]
# Test PASSED
# Current passed-to-tested ratio: 78/78
#
# TEST #79:
# Before sorting: [55, 0, 100, -79, 51, -37, 66, 65, -68, -56, -30, -27, -72, -53, -33, 16, 80, -25, 51, 16, 25, -76, -6, -1, -90, 31, 42, -4, 70, -17, -48, 44]
# After sorting: [-90, -79, -76, -72, -68, -56, -53, -48, -37, -33, -30, -27, -25, -17, -6, -4, -1, 0, 16, 16, 25, 31, 42, 44, 51, 51, 55, 65, 66, 70, 80, 100]
# Expected result: [-90, -79, -76, -72, -68, -56, -53, -48, -37, -33, -30, -27, -25, -17, -6, -4, -1, 0, 16, 16, 25, 31, 42, 44, 51, 51, 55, 65, 66, 70, 80, 100]
# Test PASSED
# Current passed-to-tested ratio: 79/79
#
# TEST #80:
# Before sorting: [69, 7, -39, 4, -69, -46, -76, -63, -33, 1, 100, -65, 39, -53, 5, 80]
# After sorting: [-76, -69, -65, -63, -53, -46, -39, -33, 1, 4, 5, 7, 39, 69, 80, 100]
# Expected result: [-76, -69, -65, -63, -53, -46, -39, -33, 1, 4, 5, 7, 39, 69, 80, 100]
# Test PASSED
# Current passed-to-tested ratio: 80/80
#
# TEST #81:
# Before sorting: [-49, -51, 6, 57, -95, -5, 64, -14, -73, 57, -38, 75, 97, -10, -20, 76, 65, -55, -64, -1, -26, 15, -70, -16, -10, -3, -18, 54, 25, 64, -37, -91, 10, 54, 85, 72, -12, -7, -66, 96, 45, 81, 92, 94, 65, 60, 58, -2, -32]
# After sorting: [-95, -91, -73, -70, -66, -64, -55, -51, -49, -38, -37, -32, -26, -20, -18, -16, -14, -12, -10, -10, -7, -5, -3, -2, -1, 6, 10, 15, 25, 45, 54, 54, 57, 57, 58, 60, 64, 64, 65, 65, 72, 75, 76, 81, 85, 92, 94, 96, 97]
# Expected result: [-95, -91, -73, -70, -66, -64, -55, -51, -49, -38, -37, -32, -26, -20, -18, -16, -14, -12, -10, -10, -7, -5, -3, -2, -1, 6, 10, 15, 25, 45, 54, 54, 57, 57, 58, 60, 64, 64, 65, 65, 72, 75, 76, 81, 85, 92, 94, 96, 97]
# Test PASSED
# Current passed-to-tested ratio: 81/81
#
# TEST #82:
# Before sorting: [-47, -80, 72, -34, -80, 27, 2, 55, -2, 51, -4, -32, 33, 87, 42, -81, 99, 22, -90, -21, -85, 53, 67, -89, -92, 76, -91, 65, 73, -48, 47, -35, -63, 93, 8, 70, -91, -34, -48]
# After sorting: [-92, -91, -91, -90, -89, -85, -81, -80, -80, -63, -48, -48, -47, -35, -34, -34, -32, -21, -4, -2, 2, 8, 22, 27, 33, 42, 47, 51, 53, 55, 65, 67, 70, 72, 73, 76, 87, 93, 99]
# Expected result: [-92, -91, -91, -90, -89, -85, -81, -80, -80, -63, -48, -48, -47, -35, -34, -34, -32, -21, -4, -2, 2, 8, 22, 27, 33, 42, 47, 51, 53, 55, 65, 67, 70, 72, 73, 76, 87, 93, 99]
# Test PASSED
# Current passed-to-tested ratio: 82/82
#
# TEST #83:
# Before sorting: [-63, 41, -10, 11, 73, 53, 6, -54, -98, 100, -46, -32, -73, -82, -28, 82, -66, 41, -80, 84, -63, -29, -77, 21, -87, -1]
# After sorting: [-98, -87, -82, -80, -77, -73, -66, -63, -63, -54, -46, -32, -29, -28, -10, -1, 6, 11, 21, 41, 41, 53, 73, 82, 84, 100]
# Expected result: [-98, -87, -82, -80, -77, -73, -66, -63, -63, -54, -46, -32, -29, -28, -10, -1, 6, 11, 21, 41, 41, 53, 73, 82, 84, 100]
# Test PASSED
# Current passed-to-tested ratio: 83/83
#
# TEST #84:
# Before sorting: [20, -12, -23, 30, -2, 52, 49, 81, -39, 93, 72, -63, -10, 42, -10, 35, -15, 6, 89, -97, 50, 36, 22, 32, -28, 8, 89, 56, 34, -18, 31, 12, 89, -67, -99, -15, 40, 65, 95, 6, -35, 44, -99, 97, -71, -82]
# After sorting: [-99, -99, -97, -82, -71, -67, -63, -39, -35, -28, -23, -18, -15, -15, -12, -10, -10, -2, 6, 6, 8, 12, 20, 22, 30, 31, 32, 34, 35, 36, 40, 42, 44, 49, 50, 52, 56, 65, 72, 81, 89, 89, 89, 93, 95, 97]
# Expected result: [-99, -99, -97, -82, -71, -67, -63, -39, -35, -28, -23, -18, -15, -15, -12, -10, -10, -2, 6, 6, 8, 12, 20, 22, 30, 31, 32, 34, 35, 36, 40, 42, 44, 49, 50, 52, 56, 65, 72, 81, 89, 89, 89, 93, 95, 97]
# Test PASSED
# Current passed-to-tested ratio: 84/84
#
# TEST #85:
# Before sorting: [24, 71, 58, -45, -74, 61]
# After sorting: [-74, -45, 24, 58, 61, 71]
# Expected result: [-74, -45, 24, 58, 61, 71]
# Test PASSED
# Current passed-to-tested ratio: 85/85
#
# TEST #86:
# Before sorting: [38, 51, 54, 95, -33, 81, -94, -26, 62, 26, -1, -64, -7, -58, 69, -84, 12, -85, -40, -33, 8, 42, -16, -55, 41, -45, -67, -37, -85, -11, -90, 45, -91]
# After sorting: [-94, -91, -90, -85, -85, -84, -67, -64, -58, -55, -45, -40, -37, -33, -33, -26, -16, -11, -7, -1, 8, 12, 26, 38, 41, 42, 45, 51, 54, 62, 69, 81, 95]
# Expected result: [-94, -91, -90, -85, -85, -84, -67, -64, -58, -55, -45, -40, -37, -33, -33, -26, -16, -11, -7, -1, 8, 12, 26, 38, 41, 42, 45, 51, 54, 62, 69, 81, 95]
# Test PASSED
# Current passed-to-tested ratio: 86/86
#
# TEST #87:
# Before sorting: [4, 48, 81, -62, -54, 44, -45, 65, -5, -69, 24, 29, 86, 65, 69, -29, -66, -4, 24, 5, -45, 10, 78, -46]
# After sorting: [-69, -66, -62, -54, -46, -45, -45, -29, -5, -4, 4, 5, 10, 24, 24, 29, 44, 48, 65, 65, 69, 78, 81, 86]
# Expected result: [-69, -66, -62, -54, -46, -45, -45, -29, -5, -4, 4, 5, 10, 24, 24, 29, 44, 48, 65, 65, 69, 78, 81, 86]
# Test PASSED
# Current passed-to-tested ratio: 87/87
#
# TEST #88:
# Before sorting: [-72, -44, -16, 20, 82, 47, 27, 20, -72, -39, 23, -79, 89, -37, -25, -39, -17, 97, -43, 15, 84, 67, 87, -89]
# After sorting: [-89, -79, -72, -72, -44, -43, -39, -39, -37, -25, -17, -16, 15, 20, 20, 23, 27, 47, 67, 82, 84, 87, 89, 97]
# Expected result: [-89, -79, -72, -72, -44, -43, -39, -39, -37, -25, -17, -16, 15, 20, 20, 23, 27, 47, 67, 82, 84, 87, 89, 97]
# Test PASSED
# Current passed-to-tested ratio: 88/88
#
# TEST #89:
# Before sorting: [78, 81, 38, -92, 79, 33, -65, 80, -46, 79, 24, -92, 61, -6, 72, 89, 80, -6, -51, -4, -84, -10, -71, 25, -82, -61, -66, 68, 27, -47, -5, -34, 91, 54, 91, 58, -29, 69, 63, 40, -46, 76, -51, 95, 27, -29, -57]
# After sorting: [-92, -92, -84, -82, -71, -66, -65, -61, -57, -51, -51, -47, -46, -46, -34, -29, -29, -10, -6, -6, -5, -4, 24, 25, 27, 27, 33, 38, 40, 54, 58, 61, 63, 68, 69, 72, 76, 78, 79, 79, 80, 80, 81, 89, 91, 91, 95]
# Expected result: [-92, -92, -84, -82, -71, -66, -65, -61, -57, -51, -51, -47, -46, -46, -34, -29, -29, -10, -6, -6, -5, -4, 24, 25, 27, 27, 33, 38, 40, 54, 58, 61, 63, 68, 69, 72, 76, 78, 79, 79, 80, 80, 81, 89, 91, 91, 95]
# Test PASSED
# Current passed-to-tested ratio: 89/89
#
# TEST #90:
# Before sorting: [56, -39, -8]
# After sorting: [-39, -8, 56]
# Expected result: [-39, -8, 56]
# Test PASSED
# Current passed-to-tested ratio: 90/90
#
# TEST #91:
# Before sorting: [-9, -89, 72, -99, 100, 63, -69, 1, 4, -69, 59, 68, -65, 53, -69, -55, -33]
# After sorting: [-99, -89, -69, -69, -69, -65, -55, -33, -9, 1, 4, 53, 59, 63, 68, 72, 100]
# Expected result: [-99, -89, -69, -69, -69, -65, -55, -33, -9, 1, 4, 53, 59, 63, 68, 72, 100]
# Test PASSED
# Current passed-to-tested ratio: 91/91
#
# TEST #92:
# Before sorting: [-58, 11, 32, 48]
# After sorting: [-58, 11, 32, 48]
# Expected result: [-58, 11, 32, 48]
# Test PASSED
# Current passed-to-tested ratio: 92/92
#
# TEST #93:
# Before sorting: [97, 79, 65, 92, 18, -23, 36, 40, -66, -50, -83, -41, -19, 74, 33, 40, -92, 35, -96, 4, -79, 14, -30]
# After sorting: [-96, -92, -83, -79, -66, -50, -41, -30, -23, -19, 4, 14, 18, 33, 35, 36, 40, 40, 65, 74, 79, 92, 97]
# Expected result: [-96, -92, -83, -79, -66, -50, -41, -30, -23, -19, 4, 14, 18, 33, 35, 36, 40, 40, 65, 74, 79, 92, 97]
# Test PASSED
# Current passed-to-tested ratio: 93/93
#
# TEST #94:
# Before sorting: [19, -22, -23, -15, -98, -12, 72, -41, 26, 43, -29, 30, -3, 59, 47, 77, -73, 1, 89, 7, -66, -21, 11, 65, -79, -48, 81, 65, -89, 23, 44, 24, 55, 1, -84, -21, -18, -51, 93, 15, -11, -94]
# After sorting: [-98, -94, -89, -84, -79, -73, -66, -51, -48, -41, -29, -23, -22, -21, -21, -18, -15, -12, -11, -3, 1, 1, 7, 11, 15, 19, 23, 24, 26, 30, 43, 44, 47, 55, 59, 65, 65, 72, 77, 81, 89, 93]
# Expected result: [-98, -94, -89, -84, -79, -73, -66, -51, -48, -41, -29, -23, -22, -21, -21, -18, -15, -12, -11, -3, 1, 1, 7, 11, 15, 19, 23, 24, 26, 30, 43, 44, 47, 55, 59, 65, 65, 72, 77, 81, 89, 93]
# Test PASSED
# Current passed-to-tested ratio: 94/94
#
# TEST #95:
# Before sorting: []
# After sorting: []
# Expected result: []
# Test PASSED
# Current passed-to-tested ratio: 95/95
#
# TEST #96:
# Before sorting: [-82, -9, -76]
# After sorting: [-82, -76, -9]
# Expected result: [-82, -76, -9]
# Test PASSED
# Current passed-to-tested ratio: 96/96
#
# TEST #97:
# Before sorting: [13, -40, -35, -29, -11, -58, -19, 24, -9, 39, 3, -7, -41, 21, 6, -37, -51, -28, 75, 42, 63, -32, 13, -41, -76, 79, -45, -68]
# After sorting: [-76, -68, -58, -51, -45, -41, -41, -40, -37, -35, -32, -29, -28, -19, -11, -9, -7, 3, 6, 13, 13, 21, 24, 39, 42, 63, 75, 79]
# Expected result: [-76, -68, -58, -51, -45, -41, -41, -40, -37, -35, -32, -29, -28, -19, -11, -9, -7, 3, 6, 13, 13, 21, 24, 39, 42, 63, 75, 79]
# Test PASSED
# Current passed-to-tested ratio: 97/97
#
# TEST #98:
# Before sorting: [18, 70, 64, -82, -57, 76, -87, 70, -98, -41, 43, 52, 81, -68, 59, -21, 85, -77, 20, 45, -29, -21, 16, -75, 84, 91]
# After sorting: [-98, -87, -82, -77, -75, -68, -57, -41, -29, -21, -21, 16, 18, 20, 43, 45, 52, 59, 64, 70, 70, 76, 81, 84, 85, 91]
# Expected result: [-98, -87, -82, -77, -75, -68, -57, -41, -29, -21, -21, 16, 18, 20, 43, 45, 52, 59, 64, 70, 70, 76, 81, 84, 85, 91]
# Test PASSED
# Current passed-to-tested ratio: 98/98
#
# TEST #99:
# Before sorting: [-18, 26, 60, -48, -21, -74, 5, -100, 16, 6, 79, -1, -32, 54, 11, -74, -94, 80, -43, 84, -37, -57, 100, 74, 44, -43, 79, -21]
# After sorting: [-100, -94, -74, -74, -57, -48, -43, -43, -37, -32, -21, -21, -18, -1, 5, 6, 11, 16, 26, 44, 54, 60, 74, 79, 79, 80, 84, 100]
# Expected result: [-100, -94, -74, -74, -57, -48, -43, -43, -37, -32, -21, -21, -18, -1, 5, 6, 11, 16, 26, 44, 54, 60, 74, 79, 79, 80, 84, 100]
# Test PASSED
# Current passed-to-tested ratio: 99/99
#
# TEST #100:
# Before sorting: [70, 33, -64, 28, -78, 10, -81, -51, 88, -32, -22, 46, -25, 23, -17, -25, 35, 70, -32, -62, -36]
# After sorting: [-81, -78, -64, -62, -51, -36, -32, -32, -25, -25, -22, -17, 10, 23, 28, 33, 35, 46, 70, 70, 88]
# Expected result: [-81, -78, -64, -62, -51, -36, -32, -32, -25, -25, -22, -17, 10, 23, 28, 33, 35, 46, 70, 70, 88]
# Test PASSED
# Current passed-to-tested ratio: 100/100
#
# Sorting algorithms is correct
# Passed tests in total: 100/100
