# %% [markdown]
# > Dana jest posortowana tablica A[1...n] oraz liczba x. Proszę napisać program, który stwierdza czy istnieją indeksy i oraz j takie, że A[i] +A[j] = x.

# %% [markdown]
# ### Implementacja algorytmu

# %% [markdown]
# Ponieważ wiemy, że sekwencja jest posortowana (jeżeli nie jest powiedziane inaczej, zakładamy, że jest to porządek niemalejący), możemy przeszukać tablicę w czasie liniowym. Wynika to stąd, że poruszając się wskaźnikiem od lewej storny sekwencji, w każdym następnym kroku przemieszczamy się na element taki sam lub większy, natomiast przesuwając się wskażnikiem od prawej strony, w każdym następnym kroku przemieszczamy się na element o wartości takiej samej lub mniejszej niż poprzedni. Łatwo można zauważyć, że jeżeli dla bieżącego ułożenia wskażników i oraz j suma jest za mała, musimy zwiększyć sumę, przesuwając wskażnik lewy ($ i $) w prawą stronę. Jeżeli ta suma jest zbyt duża, przesuwamy prawy wskażnik ($ j $) w lewo, aby zmniejszyć sumę.

# %%
def find_indices(arr, target_sum):
    i = 0
    j = len(arr) - 1
    
    while i < j:
        curr_sum = arr[i] + arr[j]
        if curr_sum == target_sum: return i, j
        if curr_sum < target_sum: i += 1
        else: j -= 1
            
    return None, None

# %% [markdown]
# ###### Przykładowy test

# %%
import random

reps = 50
for k in range(reps):
    values = sorted(random.randint(-50, 50) for _ in range(random.randint(10, 30)))
    target_sum = random.randint(-100, 100)
    i, j = find_indices(values, target_sum)
    print(f'#{k+1} Loop:')
    print('Values:', values)
    print('Target sum:', target_sum)
    val_i = f"(values[{i}]={values[i]})" if i is not None else ''
    val_j = f"(values[{j}]={values[j]})" if j is not None else ''
    print(f'Found indices: i={i} {val_i}, j={j} {val_j}')
# Out:
# #1 Loop:
# Values: [-47, -45, -29, -22, -21, -20, -19, -15, -14, -13, -10, -9, -6, 2, 7, 7, 10, 13, 23, 27, 28, 35, 36, 43, 46, 48, 49]
# Target sum: -3
# Found indices: i=9 (values[9]=-13), j=16 (values[16]=10)
# #2 Loop:
# Values: [-50, -40, -40, -38, -32, -30, -29, -26, -25, -22, -13, -10, -6, -1, 0, 2, 8, 10, 10, 14, 19, 23, 26, 27, 27, 28, 30, 31, 32, 45]
# Target sum: 73
# Found indices: i=25 (values[25]=28), j=29 (values[29]=45)
# #3 Loop:
# Values: [-40, -34, -32, -27, -17, -13, -7, 3, 5, 11, 17, 18, 30, 41, 47, 47]
# Target sum: 12
# Found indices: i=None , j=None
# #4 Loop:
# Values: [-43, -41, -38, -37, -36, -29, -29, -28, -26, -21, -16, -10, -9, -9, -6, 1, 10, 11, 12, 22, 22, 25, 25, 30, 31, 34, 47, 50]
# Target sum: -97
# Found indices: i=None , j=None
# #5 Loop:
# Values: [-49, -47, -46, -46, -43, -41, -40, -34, -34, -29, -26, -23, -21, -13, -10, 5, 10, 11, 13, 16, 21, 22, 24, 33, 36, 36, 40, 41, 46]
# Target sum: 27
# Found indices: i=13 (values[13]=-13), j=26 (values[26]=40)
# #6 Loop:
# Values: [-41, -22, -12, -10, -9, -8, 7, 17, 24, 28, 29, 32, 41, 42]
# Target sum: 44
# Found indices: i=None , j=None
# #7 Loop:
# Values: [-49, -43, -35, -31, -28, -27, -26, -25, -24, -22, -22, -16, -11, -3, 3, 6, 17, 18, 28, 39, 39, 40, 42, 43, 45, 50, 50]
# Target sum: -96
# Found indices: i=None , j=None
# #8 Loop:
# Values: [-12, -12, 3, 3, 8, 10, 16, 16, 34, 40]
# Target sum: -7
# Found indices: i=None , j=None
# #9 Loop:
# Values: [-49, -48, -45, -35, -32, -30, -22, -19, -12, -5, -4, 16, 19, 20, 22, 26, 38, 48]
# Target sum: 46
# Found indices: i=13 (values[13]=20), j=15 (values[15]=26)
# #10 Loop:
# Values: [-47, -38, -37, -30, -23, -17, -8, 1, 7, 8, 8, 12, 30, 33, 35, 39, 43]
# Target sum: -7
# Found indices: i=2 (values[2]=-37), j=12 (values[12]=30)
# #11 Loop:
# Values: [-49, -46, -45, -34, -25, -21, -12, -12, -11, -8, -7, -5, -2, 6, 9, 11, 15, 20, 28, 28, 29, 31, 40, 46, 48]
# Target sum: -71
# Found indices: i=1 (values[1]=-46), j=4 (values[4]=-25)
# #12 Loop:
# Values: [-48, -40, -36, -33, -31, -30, -29, -25, -24, -20, -18, 12, 21, 22, 23, 24, 28, 30, 39]
# Target sum: -57
# Found indices: i=3 (values[3]=-33), j=8 (values[8]=-24)
# #13 Loop:
# Values: [-44, -43, -20, 5, 11, 22, 23, 28, 29, 38, 39]
# Target sum: 97
# Found indices: i=None , j=None
# #14 Loop:
# Values: [-50, -41, -34, -24, -20, -7, -1, 0, 12, 12, 13, 25, 30, 33, 37, 39, 41]
# Target sum: 40
# Found indices: i=6 (values[6]=-1), j=16 (values[16]=41)
# #15 Loop:
# Values: [-50, -49, -47, -41, -38, -28, -24, -24, -22, 0, 4, 7, 20, 29, 34, 36, 38, 42, 47, 49, 49]
# Target sum: 72
# Found indices: i=14 (values[14]=34), j=16 (values[16]=38)
# #16 Loop:
# Values: [-49, -45, -41, -32, -31, -25, -22, -20, -16, -10, -7, -7, 8, 11, 12, 16, 18, 21, 21, 24, 26, 26, 31, 31, 31, 34, 35, 43]
# Target sum: -57
# Found indices: i=2 (values[2]=-41), j=8 (values[8]=-16)
# #17 Loop:
# Values: [-43, -41, -41, -36, -23, -22, -14, -14, -12, -10, -3, -2, 1, 8, 13, 42, 45]
# Target sum: 86
# Found indices: i=None , j=None
# #18 Loop:
# Values: [-49, -47, -44, -40, -39, -31, -31, -29, -26, -18, -18, -5, -2, -2, 3, 7, 10, 11, 11, 14, 16, 22, 32, 36, 37, 38, 39, 40]
# Target sum: 95
# Found indices: i=None , j=None
# #19 Loop:
# Values: [-48, -46, -45, -43, -30, -27, -23, -11, -6, -5, -5, -4, -3, 0, 1, 2, 7, 18, 21, 33, 43, 46, 46, 46, 47]
# Target sum: 77
# Found indices: i=None , j=None
# #20 Loop:
# Values: [-49, -39, -31, -27, -26, -15, -4, 12, 19, 30, 43]
# Target sum: -69
# Found indices: i=None , j=None
# #21 Loop:
# Values: [-34, -33, -30, -29, -28, -27, -20, -17, -16, -11, -11, -11, -6, -5, -4, -2, 8, 11, 13, 18, 22, 26, 28, 31, 37, 39, 40, 42, 42]
# Target sum: 98
# Found indices: i=None , j=None
# #22 Loop:
# Values: [-40, -37, -36, -30, -21, -21, 10, 16, 25, 35]
# Target sum: -68
# Found indices: i=None , j=None
# #23 Loop:
# Values: [-43, -42, -41, -41, -32, -23, -21, -20, -20, -19, -11, -10, -8, 0, 8, 25, 26, 32, 40, 43, 45]
# Target sum: -28
# Found indices: i=7 (values[7]=-20), j=12 (values[12]=-8)
# #24 Loop:
# Values: [-49, -37, -24, -20, -15, -10, -8, -8, 6, 12, 13, 16, 20, 27, 33, 41, 47]
# Target sum: 76
# Found indices: i=None , j=None
# #25 Loop:
# Values: [-30, -13, -13, -1, 2, 11, 18, 20, 28, 34, 35, 35, 35, 37, 39]
# Target sum: -70
# Found indices: i=None , j=None
# #26 Loop:
# Values: [-48, -41, -40, -38, -32, -22, -18, -18, -6, -2, 0, 9, 11, 13, 20, 25, 39, 42, 43, 47]
# Target sum: -77
# Found indices: i=None , j=None
# #27 Loop:
# Values: [-48, -43, -35, -27, -26, -24, -22, -22, -6, -1, -1, 3, 8, 12, 14, 23, 26, 28, 38, 40, 46, 50]
# Target sum: 3
# Found indices: i=1 (values[1]=-43), j=20 (values[20]=46)
# #28 Loop:
# Values: [-50, -48, -31, -26, -12, -12, 3, 7, 24, 26, 27, 32, 34, 42]
# Target sum: 70
# Found indices: i=None , j=None
# #29 Loop:
# Values: [-49, -47, -46, -46, -45, -37, -29, -29, -27, -25, -24, -24, -18, -16, -14, -3, 9, 9, 10, 24, 26, 31, 32, 33, 33, 33, 43, 47]
# Target sum: -16
# Found indices: i=0 (values[0]=-49), j=25 (values[25]=33)
# #30 Loop:
# Values: [-48, -46, -40, -38, -35, -35, -34, -33, -29, -29, -27, -19, -16, -12, -10, 3, 15, 16, 17, 17, 24, 37, 49]
# Target sum: 69
# Found indices: i=None , j=None
# #31 Loop:
# Values: [-26, -12, -11, -11, -10, -6, 19, 27, 29, 30, 41, 49]
# Target sum: 34
# Found indices: i=None , j=None
# #32 Loop:
# Values: [-47, -39, -35, -35, -22, -20, -17, -17, -15, -2, 5, 10, 16, 16, 18, 34, 35, 46]
# Target sum: -36
# Found indices: i=None , j=None
# #33 Loop:
# Values: [-50, -47, -46, -40, -36, -35, -33, -18, -17, -15, -8, -8, -8, 4, 7, 11, 14, 19, 22, 29, 32, 37, 39, 41, 44, 45, 48, 49]
# Target sum: 35
# Found indices: i=None , j=None
# #34 Loop:
# Values: [-43, -39, -34, -22, -10, -10, -10, -5, -4, 6, 9, 9, 14, 17, 19, 26, 34, 36, 42]
# Target sum: 13
# Found indices: i=8 (values[8]=-4), j=13 (values[13]=17)
# #35 Loop:
# Values: [-50, -50, -47, -40, -35, -20, -15, -10, -10, -2, -2, 10, 25, 26, 30, 34, 37, 43, 44]
# Target sum: -6
# Found indices: i=0 (values[0]=-50), j=18 (values[18]=44)
# #36 Loop:
# Values: [-39, -39, -26, -11, -3, 0, 5, 16, 33, 42, 47, 48]
# Target sum: 10
# Found indices: i=None , j=None
# #37 Loop:
# Values: [-37, -32, -30, -29, -23, -11, -8, 0, 2, 10, 12, 17, 21, 29, 30, 36, 40, 40, 46, 47]
# Target sum: -51
# Found indices: i=None , j=None
# #38 Loop:
# Values: [-45, -39, -34, -33, -28, -27, -6, 2, 10, 14, 19, 20, 27, 34, 41, 41, 42, 44, 49, 50]
# Target sum: -59
# Found indices: i=None , j=None
# #39 Loop:
# Values: [-50, -29, -21, -15, -14, 6, 28, 36, 46, 49]
# Target sum: -42
# Found indices: i=None , j=None
# #40 Loop:
# Values: [-49, -42, -37, -35, -33, -26, -24, -24, -15, -9, -7, -4, 1, 1, 8, 21, 24, 25, 27, 28, 30, 32, 34, 36, 44, 46, 46, 50]
# Target sum: -91
# Found indices: i=0 (values[0]=-49), j=1 (values[1]=-42)
# #41 Loop:
# Values: [-47, -46, -37, -31, -27, -26, -24, -20, -13, -12, -10, -7, -5, 3, 7, 13, 16, 19, 20, 22, 25, 30, 36, 38, 39, 42, 45, 50]
# Target sum: -22
# Found indices: i=0 (values[0]=-47), j=20 (values[20]=25)
# #42 Loop:
# Values: [-48, -42, -41, -34, -33, -31, -28, -25, -24, -17, -15, -10, -8, -6, 2, 5, 10, 19, 32, 38, 46, 47]
# Target sum: -29
# Found indices: i=0 (values[0]=-48), j=17 (values[17]=19)
# #43 Loop:
# Values: [-44, -33, -32, -24, -20, -16, -13, -9, -9, -8, 9, 21, 23, 32, 40, 50]
# Target sum: -45
# Found indices: i=2 (values[2]=-32), j=6 (values[6]=-13)
# #44 Loop:
# Values: [-43, -37, -33, -27, -25, -24, -19, -14, -11, 6, 6, 6, 9, 11, 16, 20, 21, 22, 22, 22, 32, 33, 33, 38, 39, 40, 47, 47]
# Target sum: -43
# Found indices: i=5 (values[5]=-24), j=6 (values[6]=-19)
# #45 Loop:
# Values: [-43, -39, -39, -38, -34, -25, -22, -21, -9, 12, 15, 26, 49]
# Target sum: -28
# Found indices: i=0 (values[0]=-43), j=10 (values[10]=15)
# #46 Loop:
# Values: [-50, -48, -47, -35, -29, -22, -22, -13, -6, -1, 1, 8, 8, 20, 21, 22, 30, 30, 34, 39, 40, 45, 45]
# Target sum: 61
# Found indices: i=14 (values[14]=21), j=20 (values[20]=40)
# #47 Loop:
# Values: [-40, -28, -27, -25, -20, -18, -11, -9, -8, -6, -5, 7, 11, 24, 26, 27, 27, 30, 35]
# Target sum: -31
# Found indices: i=3 (values[3]=-25), j=9 (values[9]=-6)
# #48 Loop:
# Values: [-47, -45, -43, -43, -38, -32, -31, -28, -17, -10, -2, -1, 11, 19, 23, 28, 28, 47]
# Target sum: 57
# Found indices: i=None , j=None
# #49 Loop:
# Values: [-48, -46, -43, -40, -36, -27, -26, -25, -24, -16, -13, -13, -10, -5, -4, -2, 0, 5, 9, 15, 18, 34, 38, 42, 44, 47, 48]
# Target sum: -56
# Found indices: i=1 (values[1]=-46), j=12 (values[12]=-10)
# #50 Loop:
# Values: [-44, -43, -42, -4, 0, 9, 10, 21, 28, 31, 40]
# Target sum: -59
# Found indices: i=None , j=None
