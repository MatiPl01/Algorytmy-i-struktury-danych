# %% [markdown]
# ### Treść zadania

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Omówienie algorytmu

# %% [markdown]
# Omówienie algorytmu znajduje się tutaj: <br>
# https://www.geeksforgeeks.org/determine-whether-universal-sink-exists-directed-graph/
