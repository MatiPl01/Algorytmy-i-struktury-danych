# %% [markdown]
# > Proszę zaimplementować algorytm QuickSort do sortowania n elementowej tablicy tak, żeby zawsze używał najwyżej O(log n) dodatkowej pamięci na stosie, niezależnie od jakości podziałów w funkcji partition.

# %% [markdown]
# ##### Funkcja testująca poprawność algorytmu

# %%
import random

def test_sort(sorting_fn, *, 
              samples=20,         # A number of tests that will be performed
              val_counts=(0, 50), # A minimum and maximum number of values to sort that will be generated
              range_=(-100, 100), # A range which will be used to create a random list of values from this range
              in_place=True,      # Information whether an algorithm runs in place or not
              failed_only=False,  # Show only failed tests. Works only if no_results is set to False
              print_out_fn=None,  # An user-defined function to print additional information. Works only if no_results is set to False
              no_results=False    # When set to True, no results will be printed (useful only for benchmark)
             ):                  
    passed = 0                   
    for i in range(samples):
        random_lst = [random.randint(*range_) for _ in range(random.randint(*val_counts))]
        random_lst_before = random_lst[:]
        expected = sorted(random_lst)
        output = sorting_fn(random_lst)
        if not in_place:
            random_lst = output
        is_correct = random_lst == expected
        passed += is_correct
        
        if not no_results:
            if not failed_only or (failed_only and not is_correct):
                print(f'TEST #{i+1}:')
                print(f'Before sorting: {random_lst_before}')
                print(f'After sorting: {random_lst}')
                print(f'Expected result: {expected}')
                print(f'Test {"PASSED" if is_correct else "FAILED"}')
                print(f'Current passed-to-tested ratio: {passed}/{i+1}')
                if print_out_fn:
                    print(f'========== Additional results after sorting  ==========')
                    print_out_fn(random_lst)
                print()
                
    if not no_results:
        print(f'Sorting algorithms is {"correct" if passed == samples else "wrong"}')
        print(f'Passed tests in total: {passed}/{samples}')

# %% [markdown]
# ### Implementacja algorytmu

# %% [markdown]
# Ponieważ nie jest powiedziane, że należy samemu utworzyć stos, uznaję, że należy skorzystać ze stosu systemowego, a więc z rekurencji. Ponieważ również nie można importować dodatkowych bibliotek w tych zadaniach, zdecydowałem się na sztywne ustalenie pivota jako element po lewej stronie przegazanego funkcji partition fragmentu tablicy.

# %%
def quick_sort(arr):
    _quick_sort(arr, 0, len(arr) - 1)
    

def _quick_sort(arr, left_idx, right_idx):
    while left_idx < right_idx:
        pivot_position = _partition(arr, left_idx, right_idx)
        
        if pivot_position - left_idx < right_idx - pivot_position:
            _quick_sort(arr, left_idx, pivot_position)
            left_idx = pivot_position + 1  # I removed a tailing recursion
        else:
            _quick_sort(arr, pivot_position + 1, right_idx)
            right_idx = pivot_position  # I removed a tailing recursion
        
        
def _partition(arr, left_idx, right_idx):
    pivot = arr[left_idx]
    
    # Partition an array into 2 subarrays of elements lower than or
    # equal to a pivot and of elements greater than a pivot (in this
    # partition algorithm pivot isn't placed on a fixed position but
    # can be also swapped like all the remaining values)
    i = left_idx - 1
    j = right_idx + 1
    while True:
        i += 1
        while arr[i] < pivot: i += 1
            
        j -= 1
        while arr[j] > pivot: j -= 1
        
        if i < j:
            _swap(arr, i, j)
        else:
            return j  # Return a pivot position after the last swap

    
def _swap(arr, i, j):
    arr[i], arr[j] = arr[j], arr[i]

# %% [markdown]
# ###### Kilka testów

# %%
test_sort(quick_sort, samples=100)
# Out:
# TEST #1:
# Before sorting: [39, 61, 85, 8, 50, -71, -18, 65, -24]
# After sorting: [-71, -24, -18, 8, 39, 50, 61, 65, 85]
# Expected result: [-71, -24, -18, 8, 39, 50, 61, 65, 85]
# Test PASSED
# Current passed-to-tested ratio: 1/1
#
# TEST #2:
# Before sorting: [87, -88, -77, 43, -20, 0]
# After sorting: [-88, -77, -20, 0, 43, 87]
# Expected result: [-88, -77, -20, 0, 43, 87]
# Test PASSED
# Current passed-to-tested ratio: 2/2
#
# TEST #3:
# Before sorting: [98, 93, 36, 87, -5, -2, 4, -33, 46, -65, -36, -24, -43, -84, -15, -92, 86, -85, -49, 98, -95, -47, 88, -20, -2, 6, -73, -74, 80, -12, -56, 96]
# After sorting: [-95, -92, -85, -84, -74, -73, -65, -56, -49, -47, -43, -36, -33, -24, -20, -15, -12, -5, -2, -2, 4, 6, 36, 46, 80, 86, 87, 88, 93, 96, 98, 98]
# Expected result: [-95, -92, -85, -84, -74, -73, -65, -56, -49, -47, -43, -36, -33, -24, -20, -15, -12, -5, -2, -2, 4, 6, 36, 46, 80, 86, 87, 88, 93, 96, 98, 98]
# Test PASSED
# Current passed-to-tested ratio: 3/3
#
# TEST #4:
# Before sorting: [4, -1, -80, -29, -49, -17, -37, -28, -73, -14, 64, -1, -21, -29]
# After sorting: [-80, -73, -49, -37, -29, -29, -28, -21, -17, -14, -1, -1, 4, 64]
# Expected result: [-80, -73, -49, -37, -29, -29, -28, -21, -17, -14, -1, -1, 4, 64]
# Test PASSED
# Current passed-to-tested ratio: 4/4
#
# TEST #5:
# Before sorting: [-32, -82, -85, 68, 57, -12, -84, -22, -48, 0, 63, 22, 20]
# After sorting: [-85, -84, -82, -48, -32, -22, -12, 0, 20, 22, 57, 63, 68]
# Expected result: [-85, -84, -82, -48, -32, -22, -12, 0, 20, 22, 57, 63, 68]
# Test PASSED
# Current passed-to-tested ratio: 5/5
#
# TEST #6:
# Before sorting: [-73, 83, -53, 54, 100, -77, -33, -85, 79, 3, -11, 27, 41, -41, 34, -61, 39, -4, 53, -67, -85, 92, 86, 46, 99, -58, -58, 21, 96, 78, -12, -62]
# After sorting: [-85, -85, -77, -73, -67, -62, -61, -58, -58, -53, -41, -33, -12, -11, -4, 3, 21, 27, 34, 39, 41, 46, 53, 54, 78, 79, 83, 86, 92, 96, 99, 100]
# Expected result: [-85, -85, -77, -73, -67, -62, -61, -58, -58, -53, -41, -33, -12, -11, -4, 3, 21, 27, 34, 39, 41, 46, 53, 54, 78, 79, 83, 86, 92, 96, 99, 100]
# Test PASSED
# Current passed-to-tested ratio: 6/6
#
# TEST #7:
# Before sorting: [-32, -10, -6, 41, 93, 43, 30, -99, 15, 8, -24, -84, -78, -71, -35, -71, -31, 39, 24, 36, 47, 58, 14, -18, -10, -45, 62, -66, -13, 2, -26, 80, -15, 100, 37, -86, -98, 86, 55, 54]
# After sorting: [-99, -98, -86, -84, -78, -71, -71, -66, -45, -35, -32, -31, -26, -24, -18, -15, -13, -10, -10, -6, 2, 8, 14, 15, 24, 30, 36, 37, 39, 41, 43, 47, 54, 55, 58, 62, 80, 86, 93, 100]
# Expected result: [-99, -98, -86, -84, -78, -71, -71, -66, -45, -35, -32, -31, -26, -24, -18, -15, -13, -10, -10, -6, 2, 8, 14, 15, 24, 30, 36, 37, 39, 41, 43, 47, 54, 55, 58, 62, 80, 86, 93, 100]
# Test PASSED
# Current passed-to-tested ratio: 7/7
#
# TEST #8:
# Before sorting: [28, 28, 53, -30, 41, -45, 84, -42, -67]
# After sorting: [-67, -45, -42, -30, 28, 28, 41, 53, 84]
# Expected result: [-67, -45, -42, -30, 28, 28, 41, 53, 84]
# Test PASSED
# Current passed-to-tested ratio: 8/8
#
# TEST #9:
# Before sorting: [-84, -86, -98, 50, 82, -84, -95, -36, -48, 47]
# After sorting: [-98, -95, -86, -84, -84, -48, -36, 47, 50, 82]
# Expected result: [-98, -95, -86, -84, -84, -48, -36, 47, 50, 82]
# Test PASSED
# Current passed-to-tested ratio: 9/9
#
# TEST #10:
# Before sorting: [-93, 20, -31, 90, -43, 16]
# After sorting: [-93, -43, -31, 16, 20, 90]
# Expected result: [-93, -43, -31, 16, 20, 90]
# Test PASSED
# Current passed-to-tested ratio: 10/10
#
# TEST #11:
# Before sorting: [77, 83, -35, -52, 100]
# After sorting: [-52, -35, 77, 83, 100]
# Expected result: [-52, -35, 77, 83, 100]
# Test PASSED
# Current passed-to-tested ratio: 11/11
#
# TEST #12:
# Before sorting: [-47, 37, 88, 92, 60, 62, 63, -36, -83, 59, -22, 1, -84, 34, 7, -87, -7, -15, 89, 26, -34, 11, -97, 28, -25, 75, 11, 96, -5, -44, -30, 56, 47, -79, 7, 23, 65, 1, 79, 26, 91, 13, 3, -67, 0]
# After sorting: [-97, -87, -84, -83, -79, -67, -47, -44, -36, -34, -30, -25, -22, -15, -7, -5, 0, 1, 1, 3, 7, 7, 11, 11, 13, 23, 26, 26, 28, 34, 37, 47, 56, 59, 60, 62, 63, 65, 75, 79, 88, 89, 91, 92, 96]
# Expected result: [-97, -87, -84, -83, -79, -67, -47, -44, -36, -34, -30, -25, -22, -15, -7, -5, 0, 1, 1, 3, 7, 7, 11, 11, 13, 23, 26, 26, 28, 34, 37, 47, 56, 59, 60, 62, 63, 65, 75, 79, 88, 89, 91, 92, 96]
# Test PASSED
# Current passed-to-tested ratio: 12/12
#
# TEST #13:
# Before sorting: [22, -89]
# After sorting: [-89, 22]
# Expected result: [-89, 22]
# Test PASSED
# Current passed-to-tested ratio: 13/13
#
# TEST #14:
# Before sorting: [-65, 59, 22, -88, 17, -17, 13, 1, 97, 73, -90, 15, -23, 15, -54, -34, 64, 37, 29, -73, -15, -28, -27, -96, 45, 78, 77, 86, -47, 36, 41, 89, -11, 82, -68, 6, 46, -22, 9, 20, 30, -92, -91, -43, -28, -50, 84]
# After sorting: [-96, -92, -91, -90, -88, -73, -68, -65, -54, -50, -47, -43, -34, -28, -28, -27, -23, -22, -17, -15, -11, 1, 6, 9, 13, 15, 15, 17, 20, 22, 29, 30, 36, 37, 41, 45, 46, 59, 64, 73, 77, 78, 82, 84, 86, 89, 97]
# Expected result: [-96, -92, -91, -90, -88, -73, -68, -65, -54, -50, -47, -43, -34, -28, -28, -27, -23, -22, -17, -15, -11, 1, 6, 9, 13, 15, 15, 17, 20, 22, 29, 30, 36, 37, 41, 45, 46, 59, 64, 73, 77, 78, 82, 84, 86, 89, 97]
# Test PASSED
# Current passed-to-tested ratio: 14/14
#
# TEST #15:
# Before sorting: [-42, 89, -23, -65, -61, 5, 67, -37, 63, 47, 82, -32, 64, -14, 23, 9, 18, 29, 81, -86, 33, -78, -55, -34, -87, 92, -29, 50, -70, -48, -38, 19, 47, -56, 2, -16, -51, 47, 68, -42, -73, 12, -77, -48, -11, -39, -52]
# After sorting: [-87, -86, -78, -77, -73, -70, -65, -61, -56, -55, -52, -51, -48, -48, -42, -42, -39, -38, -37, -34, -32, -29, -23, -16, -14, -11, 2, 5, 9, 12, 18, 19, 23, 29, 33, 47, 47, 47, 50, 63, 64, 67, 68, 81, 82, 89, 92]
# Expected result: [-87, -86, -78, -77, -73, -70, -65, -61, -56, -55, -52, -51, -48, -48, -42, -42, -39, -38, -37, -34, -32, -29, -23, -16, -14, -11, 2, 5, 9, 12, 18, 19, 23, 29, 33, 47, 47, 47, 50, 63, 64, 67, 68, 81, 82, 89, 92]
# Test PASSED
# Current passed-to-tested ratio: 15/15
#
# TEST #16:
# Before sorting: [-24, -2, -54, -99, 65, 13, 86, 48, -2, 67, 84, 54, -12, 79, -86, 32, 25, -41, -25, -91, 79, 22, -96, -73, 54]
# After sorting: [-99, -96, -91, -86, -73, -54, -41, -25, -24, -12, -2, -2, 13, 22, 25, 32, 48, 54, 54, 65, 67, 79, 79, 84, 86]
# Expected result: [-99, -96, -91, -86, -73, -54, -41, -25, -24, -12, -2, -2, 13, 22, 25, 32, 48, 54, 54, 65, 67, 79, 79, 84, 86]
# Test PASSED
# Current passed-to-tested ratio: 16/16
#
# TEST #17:
# Before sorting: [46, -66, 75, 49, -34, 83, 13, 12, 95, 89, -98, -47, -3, 87, -82, 41, -17, 65, -21, -100, -91, 65, 64]
# After sorting: [-100, -98, -91, -82, -66, -47, -34, -21, -17, -3, 12, 13, 41, 46, 49, 64, 65, 65, 75, 83, 87, 89, 95]
# Expected result: [-100, -98, -91, -82, -66, -47, -34, -21, -17, -3, 12, 13, 41, 46, 49, 64, 65, 65, 75, 83, 87, 89, 95]
# Test PASSED
# Current passed-to-tested ratio: 17/17
#
# TEST #18:
# Before sorting: [73, 69, -26, 80, 50, -95, -61]
# After sorting: [-95, -61, -26, 50, 69, 73, 80]
# Expected result: [-95, -61, -26, 50, 69, 73, 80]
# Test PASSED
# Current passed-to-tested ratio: 18/18
#
# TEST #19:
# Before sorting: []
# After sorting: []
# Expected result: []
# Test PASSED
# Current passed-to-tested ratio: 19/19
#
# TEST #20:
# Before sorting: [-10, 96, -8, -56, 93, -82, -78, -45, -40, 54, 92, -61, -46, 26, 82, 29, -76, -74, 69, 73, 7, -6, -97, -35]
# After sorting: [-97, -82, -78, -76, -74, -61, -56, -46, -45, -40, -35, -10, -8, -6, 7, 26, 29, 54, 69, 73, 82, 92, 93, 96]
# Expected result: [-97, -82, -78, -76, -74, -61, -56, -46, -45, -40, -35, -10, -8, -6, 7, 26, 29, 54, 69, 73, 82, 92, 93, 96]
# Test PASSED
# Current passed-to-tested ratio: 20/20
#
# TEST #21:
# Before sorting: [-51, 43, -46, 67, -94, -43, 0, -46, 68, -13, 61, -93, 64, 74, -74, -21, -2, -82, 79, 9, -7, -57, 9]
# After sorting: [-94, -93, -82, -74, -57, -51, -46, -46, -43, -21, -13, -7, -2, 0, 9, 9, 43, 61, 64, 67, 68, 74, 79]
# Expected result: [-94, -93, -82, -74, -57, -51, -46, -46, -43, -21, -13, -7, -2, 0, 9, 9, 43, 61, 64, 67, 68, 74, 79]
# Test PASSED
# Current passed-to-tested ratio: 21/21
#
# TEST #22:
# Before sorting: [-53, 36, 66, 0, 62, -1, -16, -95, 99, -31, 18, 22, -9, 53, -19, 57, 30, 96, 70, -96, -53, -2, 73]
# After sorting: [-96, -95, -53, -53, -31, -19, -16, -9, -2, -1, 0, 18, 22, 30, 36, 53, 57, 62, 66, 70, 73, 96, 99]
# Expected result: [-96, -95, -53, -53, -31, -19, -16, -9, -2, -1, 0, 18, 22, 30, 36, 53, 57, 62, 66, 70, 73, 96, 99]
# Test PASSED
# Current passed-to-tested ratio: 22/22
#
# TEST #23:
# Before sorting: [-96, 32, 9, -99, 11, 36]
# After sorting: [-99, -96, 9, 11, 32, 36]
# Expected result: [-99, -96, 9, 11, 32, 36]
# Test PASSED
# Current passed-to-tested ratio: 23/23
#
# TEST #24:
# Before sorting: [75, -98, -83, 65, 82, -94, 23, 88, -65, 7, -61, 72, 29, -34, 66, -64, -5, 11, 76, -61, -9, 10, 40, -22, -14, -2, -29, -27, 18, -49]
# After sorting: [-98, -94, -83, -65, -64, -61, -61, -49, -34, -29, -27, -22, -14, -9, -5, -2, 7, 10, 11, 18, 23, 29, 40, 65, 66, 72, 75, 76, 82, 88]
# Expected result: [-98, -94, -83, -65, -64, -61, -61, -49, -34, -29, -27, -22, -14, -9, -5, -2, 7, 10, 11, 18, 23, 29, 40, 65, 66, 72, 75, 76, 82, 88]
# Test PASSED
# Current passed-to-tested ratio: 24/24
#
# TEST #25:
# Before sorting: [48, 94, -26, -79, 51]
# After sorting: [-79, -26, 48, 51, 94]
# Expected result: [-79, -26, 48, 51, 94]
# Test PASSED
# Current passed-to-tested ratio: 25/25
#
# TEST #26:
# Before sorting: [-46, 24, 5, 50, 34, -81, 19, 50, 12, 69, 50, -56, -47, -8, 12, -51, 64, 41, 72, 91, -75, -53, 49, 57, -6, 92]
# After sorting: [-81, -75, -56, -53, -51, -47, -46, -8, -6, 5, 12, 12, 19, 24, 34, 41, 49, 50, 50, 50, 57, 64, 69, 72, 91, 92]
# Expected result: [-81, -75, -56, -53, -51, -47, -46, -8, -6, 5, 12, 12, 19, 24, 34, 41, 49, 50, 50, 50, 57, 64, 69, 72, 91, 92]
# Test PASSED
# Current passed-to-tested ratio: 26/26
#
# TEST #27:
# Before sorting: [-63, 15, 50, 82, 86, -90, -79, 11, -19, 64, 69, -16]
# After sorting: [-90, -79, -63, -19, -16, 11, 15, 50, 64, 69, 82, 86]
# Expected result: [-90, -79, -63, -19, -16, 11, 15, 50, 64, 69, 82, 86]
# Test PASSED
# Current passed-to-tested ratio: 27/27
#
# TEST #28:
# Before sorting: [1, 47, -65, -93, 49, 1, 55, -16, 85, -70, -52, -20, -53, -71, 9, -26, -4, 72]
# After sorting: [-93, -71, -70, -65, -53, -52, -26, -20, -16, -4, 1, 1, 9, 47, 49, 55, 72, 85]
# Expected result: [-93, -71, -70, -65, -53, -52, -26, -20, -16, -4, 1, 1, 9, 47, 49, 55, 72, 85]
# Test PASSED
# Current passed-to-tested ratio: 28/28
#
# TEST #29:
# Before sorting: [-54, 18, 21, 84, 46, 34, -9, -15, -15, -76, 51, -100, 72, -36, -31, 70, -82, -22, -70, 7, -69, 36, 99, 62, 93, -80]
# After sorting: [-100, -82, -80, -76, -70, -69, -54, -36, -31, -22, -15, -15, -9, 7, 18, 21, 34, 36, 46, 51, 62, 70, 72, 84, 93, 99]
# Expected result: [-100, -82, -80, -76, -70, -69, -54, -36, -31, -22, -15, -15, -9, 7, 18, 21, 34, 36, 46, 51, 62, 70, 72, 84, 93, 99]
# Test PASSED
# Current passed-to-tested ratio: 29/29
#
# TEST #30:
# Before sorting: [-76, -98, -7, 69, -22, -53, 54, -12, -10, 9, -37, 72, -33, 29, -60, -4, 32]
# After sorting: [-98, -76, -60, -53, -37, -33, -22, -12, -10, -7, -4, 9, 29, 32, 54, 69, 72]
# Expected result: [-98, -76, -60, -53, -37, -33, -22, -12, -10, -7, -4, 9, 29, 32, 54, 69, 72]
# Test PASSED
# Current passed-to-tested ratio: 30/30
#
# TEST #31:
# Before sorting: [-28, 59, 93, -25, 26, -93, -10]
# After sorting: [-93, -28, -25, -10, 26, 59, 93]
# Expected result: [-93, -28, -25, -10, 26, 59, 93]
# Test PASSED
# Current passed-to-tested ratio: 31/31
#
# TEST #32:
# Before sorting: [-17, -3, -76, -68, 43, 80, 88, -35, 82, 93, -5, 59, -76, -81, -49, 100, -29, -64, -84, 1, -10, 90, 99, 9, 27, 72, -21, -46, 30]
# After sorting: [-84, -81, -76, -76, -68, -64, -49, -46, -35, -29, -21, -17, -10, -5, -3, 1, 9, 27, 30, 43, 59, 72, 80, 82, 88, 90, 93, 99, 100]
# Expected result: [-84, -81, -76, -76, -68, -64, -49, -46, -35, -29, -21, -17, -10, -5, -3, 1, 9, 27, 30, 43, 59, 72, 80, 82, 88, 90, 93, 99, 100]
# Test PASSED
# Current passed-to-tested ratio: 32/32
#
# TEST #33:
# Before sorting: [-63, -58, -34, 97, 46, -92, -45, -1, 75, 30, -54, 7, 36, 53, 22, -5, -64, -95, 36, -63, -32, -67, -74, -96, 88, 92, -29, -29, 60, 24, 60, 14, -73, -4, 10, 48, -67, -98, 50, 100, -47, -83, -94, 44, 66, -92, 20, 100, -86, 77]
# After sorting: [-98, -96, -95, -94, -92, -92, -86, -83, -74, -73, -67, -67, -64, -63, -63, -58, -54, -47, -45, -34, -32, -29, -29, -5, -4, -1, 7, 10, 14, 20, 22, 24, 30, 36, 36, 44, 46, 48, 50, 53, 60, 60, 66, 75, 77, 88, 92, 97, 100, 100]
# Expected result: [-98, -96, -95, -94, -92, -92, -86, -83, -74, -73, -67, -67, -64, -63, -63, -58, -54, -47, -45, -34, -32, -29, -29, -5, -4, -1, 7, 10, 14, 20, 22, 24, 30, 36, 36, 44, 46, 48, 50, 53, 60, 60, 66, 75, 77, 88, 92, 97, 100, 100]
# Test PASSED
# Current passed-to-tested ratio: 33/33
#
# TEST #34:
# Before sorting: [-49, -88, -35, 24, -97, -85, 65, -66, 91, 22, 33, 67, 41, -59, 63, -34, -95, 33, 67, 79, 95, 59, 94, -41, 49, 7, 96, -43, 11, -91, -9, 22]
# After sorting: [-97, -95, -91, -88, -85, -66, -59, -49, -43, -41, -35, -34, -9, 7, 11, 22, 22, 24, 33, 33, 41, 49, 59, 63, 65, 67, 67, 79, 91, 94, 95, 96]
# Expected result: [-97, -95, -91, -88, -85, -66, -59, -49, -43, -41, -35, -34, -9, 7, 11, 22, 22, 24, 33, 33, 41, 49, 59, 63, 65, 67, 67, 79, 91, 94, 95, 96]
# Test PASSED
# Current passed-to-tested ratio: 34/34
#
# TEST #35:
# Before sorting: []
# After sorting: []
# Expected result: []
# Test PASSED
# Current passed-to-tested ratio: 35/35
#
# TEST #36:
# Before sorting: [32, -93, -55, -27, 91, 13, -69, -49, 39, 48, 2, -50, -54]
# After sorting: [-93, -69, -55, -54, -50, -49, -27, 2, 13, 32, 39, 48, 91]
# Expected result: [-93, -69, -55, -54, -50, -49, -27, 2, 13, 32, 39, 48, 91]
# Test PASSED
# Current passed-to-tested ratio: 36/36
#
# TEST #37:
# Before sorting: [74, 18, 82, 33, -26, -78, -82, -77, -100, 78, 98, 64, 95, 98, 82, 70, -77, -88, -87, 99, -40, -24, 67, -7, 80, 77, -38, 80, 31, 26, 72, -2, 29, -21, -77, 88, -60, 54, -71]
# After sorting: [-100, -88, -87, -82, -78, -77, -77, -77, -71, -60, -40, -38, -26, -24, -21, -7, -2, 18, 26, 29, 31, 33, 54, 64, 67, 70, 72, 74, 77, 78, 80, 80, 82, 82, 88, 95, 98, 98, 99]
# Expected result: [-100, -88, -87, -82, -78, -77, -77, -77, -71, -60, -40, -38, -26, -24, -21, -7, -2, 18, 26, 29, 31, 33, 54, 64, 67, 70, 72, 74, 77, 78, 80, 80, 82, 82, 88, 95, 98, 98, 99]
# Test PASSED
# Current passed-to-tested ratio: 37/37
#
# TEST #38:
# Before sorting: [64, 97, 88, -97, 24, 87]
# After sorting: [-97, 24, 64, 87, 88, 97]
# Expected result: [-97, 24, 64, 87, 88, 97]
# Test PASSED
# Current passed-to-tested ratio: 38/38
#
# TEST #39:
# Before sorting: [-62, 21, 91, -27, -25, -63, 30, -57, -44, -3, 49, 78, -81, -63, -80, -68, -82, -78, -94, 79, 86, -74, -35, -3, 23, -54, -25, 73, -58, 16, 9, 55, 0, -89, 71, -14, 94, 44, 12, -48]
# After sorting: [-94, -89, -82, -81, -80, -78, -74, -68, -63, -63, -62, -58, -57, -54, -48, -44, -35, -27, -25, -25, -14, -3, -3, 0, 9, 12, 16, 21, 23, 30, 44, 49, 55, 71, 73, 78, 79, 86, 91, 94]
# Expected result: [-94, -89, -82, -81, -80, -78, -74, -68, -63, -63, -62, -58, -57, -54, -48, -44, -35, -27, -25, -25, -14, -3, -3, 0, 9, 12, 16, 21, 23, 30, 44, 49, 55, 71, 73, 78, 79, 86, 91, 94]
# Test PASSED
# Current passed-to-tested ratio: 39/39
#
# TEST #40:
# Before sorting: [-73]
# After sorting: [-73]
# Expected result: [-73]
# Test PASSED
# Current passed-to-tested ratio: 40/40
#
# TEST #41:
# Before sorting: [-58, 29, 4]
# After sorting: [-58, 4, 29]
# Expected result: [-58, 4, 29]
# Test PASSED
# Current passed-to-tested ratio: 41/41
#
# TEST #42:
# Before sorting: [54, -40, -64, 72, 97, -81, 5, -19, -52, 22, -9, 13, 53, -96, -81, -32, -54, 29, -8, -11, -97, -90, -16, 83, 63]
# After sorting: [-97, -96, -90, -81, -81, -64, -54, -52, -40, -32, -19, -16, -11, -9, -8, 5, 13, 22, 29, 53, 54, 63, 72, 83, 97]
# Expected result: [-97, -96, -90, -81, -81, -64, -54, -52, -40, -32, -19, -16, -11, -9, -8, 5, 13, 22, 29, 53, 54, 63, 72, 83, 97]
# Test PASSED
# Current passed-to-tested ratio: 42/42
#
# TEST #43:
# Before sorting: [-58, 79, 16, -62, 17, -27, -31, 17, -15, 30, 95, 12, 21, 68, 77, 15, -89, 0, 35, -81, 66, 65, -11, 8, 23, 35, -59, 20, -2, 67, 100, 50, -13, -63, -33, 10, 11, 86, -75]
# After sorting: [-89, -81, -75, -63, -62, -59, -58, -33, -31, -27, -15, -13, -11, -2, 0, 8, 10, 11, 12, 15, 16, 17, 17, 20, 21, 23, 30, 35, 35, 50, 65, 66, 67, 68, 77, 79, 86, 95, 100]
# Expected result: [-89, -81, -75, -63, -62, -59, -58, -33, -31, -27, -15, -13, -11, -2, 0, 8, 10, 11, 12, 15, 16, 17, 17, 20, 21, 23, 30, 35, 35, 50, 65, 66, 67, 68, 77, 79, 86, 95, 100]
# Test PASSED
# Current passed-to-tested ratio: 43/43
#
# TEST #44:
# Before sorting: [-45, -30, 95, 69, 9, -55, 99, -64, 2, 45, -57, 69, -50, 68, 3, -36, 94, 68, -61, 37, -87, -19, 68, 0, 3, 74, -47, 20, -43, -39]
# After sorting: [-87, -64, -61, -57, -55, -50, -47, -45, -43, -39, -36, -30, -19, 0, 2, 3, 3, 9, 20, 37, 45, 68, 68, 68, 69, 69, 74, 94, 95, 99]
# Expected result: [-87, -64, -61, -57, -55, -50, -47, -45, -43, -39, -36, -30, -19, 0, 2, 3, 3, 9, 20, 37, 45, 68, 68, 68, 69, 69, 74, 94, 95, 99]
# Test PASSED
# Current passed-to-tested ratio: 44/44
#
# TEST #45:
# Before sorting: [-45, 12, -72, -98, 34, 4, 56, 5]
# After sorting: [-98, -72, -45, 4, 5, 12, 34, 56]
# Expected result: [-98, -72, -45, 4, 5, 12, 34, 56]
# Test PASSED
# Current passed-to-tested ratio: 45/45
#
# TEST #46:
# Before sorting: [-67, -23, 99, 21, 17, -98, -93, 4, -93, 96, -67, -24, -30, 90, 35]
# After sorting: [-98, -93, -93, -67, -67, -30, -24, -23, 4, 17, 21, 35, 90, 96, 99]
# Expected result: [-98, -93, -93, -67, -67, -30, -24, -23, 4, 17, 21, 35, 90, 96, 99]
# Test PASSED
# Current passed-to-tested ratio: 46/46
#
# TEST #47:
# Before sorting: [-97, -69, -41, -82, 58, -91]
# After sorting: [-97, -91, -82, -69, -41, 58]
# Expected result: [-97, -91, -82, -69, -41, 58]
# Test PASSED
# Current passed-to-tested ratio: 47/47
#
# TEST #48:
# Before sorting: [-34, -32, -93, -46, -96, -79, 92, 9, 37, -41, 20, -64, -63, 65, 68, -72, 58, 95, -63, 20, -4, 31, -13, -86, -55, 69, 2, 73, 83, -49, -33, -91, -99, -20, -49, 23, 45, 19, 87]
# After sorting: [-99, -96, -93, -91, -86, -79, -72, -64, -63, -63, -55, -49, -49, -46, -41, -34, -33, -32, -20, -13, -4, 2, 9, 19, 20, 20, 23, 31, 37, 45, 58, 65, 68, 69, 73, 83, 87, 92, 95]
# Expected result: [-99, -96, -93, -91, -86, -79, -72, -64, -63, -63, -55, -49, -49, -46, -41, -34, -33, -32, -20, -13, -4, 2, 9, 19, 20, 20, 23, 31, 37, 45, 58, 65, 68, 69, 73, 83, 87, 92, 95]
# Test PASSED
# Current passed-to-tested ratio: 48/48
#
# TEST #49:
# Before sorting: [-20, -6, -59, 35, 89, 32, 97, -1, -7, 63, 10, -11, -50, 26, 82, -20, -92, 73, -51, 21, -29, 53, -91, -52, -72, -27, -61, 14, 37, -8, -21, -16, -37, -19, -99, -32, -81, -92, -28]
# After sorting: [-99, -92, -92, -91, -81, -72, -61, -59, -52, -51, -50, -37, -32, -29, -28, -27, -21, -20, -20, -19, -16, -11, -8, -7, -6, -1, 10, 14, 21, 26, 32, 35, 37, 53, 63, 73, 82, 89, 97]
# Expected result: [-99, -92, -92, -91, -81, -72, -61, -59, -52, -51, -50, -37, -32, -29, -28, -27, -21, -20, -20, -19, -16, -11, -8, -7, -6, -1, 10, 14, 21, 26, 32, 35, 37, 53, 63, 73, 82, 89, 97]
# Test PASSED
# Current passed-to-tested ratio: 49/49
#
# TEST #50:
# Before sorting: [37, -69, -38, 17, 37, -57, 61, -27, 60, -7, -90, -20, 31, 99, -17, -9, 32, -41, 77]
# After sorting: [-90, -69, -57, -41, -38, -27, -20, -17, -9, -7, 17, 31, 32, 37, 37, 60, 61, 77, 99]
# Expected result: [-90, -69, -57, -41, -38, -27, -20, -17, -9, -7, 17, 31, 32, 37, 37, 60, 61, 77, 99]
# Test PASSED
# Current passed-to-tested ratio: 50/50
#
# TEST #51:
# Before sorting: [-80, -85, 47, -5, 11, -67, -41, -56, -62, -6, 67, -43, -93, -28, 81, 3, -83, 24, -10, 38, 71, 73, -94, -73, -39, -40, -72, 47, 65, 38, 69, -30, 65, 77, -16, 89, 38, 97, -68, -5]
# After sorting: [-94, -93, -85, -83, -80, -73, -72, -68, -67, -62, -56, -43, -41, -40, -39, -30, -28, -16, -10, -6, -5, -5, 3, 11, 24, 38, 38, 38, 47, 47, 65, 65, 67, 69, 71, 73, 77, 81, 89, 97]
# Expected result: [-94, -93, -85, -83, -80, -73, -72, -68, -67, -62, -56, -43, -41, -40, -39, -30, -28, -16, -10, -6, -5, -5, 3, 11, 24, 38, 38, 38, 47, 47, 65, 65, 67, 69, 71, 73, 77, 81, 89, 97]
# Test PASSED
# Current passed-to-tested ratio: 51/51
#
# TEST #52:
# Before sorting: [49, 29, 70, 40, -94, 32, 38, -17, 23, -73, 56, -87, 12, 63, -85, -13, -38, 62, 39, -85, 9]
# After sorting: [-94, -87, -85, -85, -73, -38, -17, -13, 9, 12, 23, 29, 32, 38, 39, 40, 49, 56, 62, 63, 70]
# Expected result: [-94, -87, -85, -85, -73, -38, -17, -13, 9, 12, 23, 29, 32, 38, 39, 40, 49, 56, 62, 63, 70]
# Test PASSED
# Current passed-to-tested ratio: 52/52
#
# TEST #53:
# Before sorting: [-60, 81, -32, -77, 98, -35, -67]
# After sorting: [-77, -67, -60, -35, -32, 81, 98]
# Expected result: [-77, -67, -60, -35, -32, 81, 98]
# Test PASSED
# Current passed-to-tested ratio: 53/53
#
# TEST #54:
# Before sorting: [24, 92, 35, 85, 96, -44, -50, -95, -86, 57, 82, -29, 49, -10, -98, -19, -24, -86, 65, 31, 54, 68, 67, -45]
# After sorting: [-98, -95, -86, -86, -50, -45, -44, -29, -24, -19, -10, 24, 31, 35, 49, 54, 57, 65, 67, 68, 82, 85, 92, 96]
# Expected result: [-98, -95, -86, -86, -50, -45, -44, -29, -24, -19, -10, 24, 31, 35, 49, 54, 57, 65, 67, 68, 82, 85, 92, 96]
# Test PASSED
# Current passed-to-tested ratio: 54/54
#
# TEST #55:
# Before sorting: [-60, 76, -5, 45, 9, 30, 22, 55, 68, -71, 44, -45, 99, 59, 3, 34, 99, -98, -60, -2, 15, -98, 3]
# After sorting: [-98, -98, -71, -60, -60, -45, -5, -2, 3, 3, 9, 15, 22, 30, 34, 44, 45, 55, 59, 68, 76, 99, 99]
# Expected result: [-98, -98, -71, -60, -60, -45, -5, -2, 3, 3, 9, 15, 22, 30, 34, 44, 45, 55, 59, 68, 76, 99, 99]
# Test PASSED
# Current passed-to-tested ratio: 55/55
#
# TEST #56:
# Before sorting: [-24, -74, -47, -62, 70, -52, -3, -17, -88, 52, 96, 27, -43, -3, -52, 78, 51, 85, -73, 78, 62, -8, -83, -26, 47, -33, 86, 72, -15, 100, -16, -42, -36, 87, -76, -69, -29, 69, -45, -86, -82, 7, 88, -3, 46, 29, -34, -31]
# After sorting: [-88, -86, -83, -82, -76, -74, -73, -69, -62, -52, -52, -47, -45, -43, -42, -36, -34, -33, -31, -29, -26, -24, -17, -16, -15, -8, -3, -3, -3, 7, 27, 29, 46, 47, 51, 52, 62, 69, 70, 72, 78, 78, 85, 86, 87, 88, 96, 100]
# Expected result: [-88, -86, -83, -82, -76, -74, -73, -69, -62, -52, -52, -47, -45, -43, -42, -36, -34, -33, -31, -29, -26, -24, -17, -16, -15, -8, -3, -3, -3, 7, 27, 29, 46, 47, 51, 52, 62, 69, 70, 72, 78, 78, 85, 86, 87, 88, 96, 100]
# Test PASSED
# Current passed-to-tested ratio: 56/56
#
# TEST #57:
# Before sorting: [-52, 60, 5, -77, 60, -21, -30, 16, 97, 47, -75, 79, -68, -30, -1, 99, 97, 8, -62, -48]
# After sorting: [-77, -75, -68, -62, -52, -48, -30, -30, -21, -1, 5, 8, 16, 47, 60, 60, 79, 97, 97, 99]
# Expected result: [-77, -75, -68, -62, -52, -48, -30, -30, -21, -1, 5, 8, 16, 47, 60, 60, 79, 97, 97, 99]
# Test PASSED
# Current passed-to-tested ratio: 57/57
#
# TEST #58:
# Before sorting: [-6, 24, 43, -21, 34, 51, -66, 81, -51, -29, 86, -81, 1, -68, -13, -8, -57, -39, -44, 0, 63, -57, 94, -51, -99, -93, -89, -63, 44, 93, -46, 57, 15, -72, -67, 32, -3, -14, 53, -46, -64, 15, 18, 97, 67, 4, -73, -48]
# After sorting: [-99, -93, -89, -81, -73, -72, -68, -67, -66, -64, -63, -57, -57, -51, -51, -48, -46, -46, -44, -39, -29, -21, -14, -13, -8, -6, -3, 0, 1, 4, 15, 15, 18, 24, 32, 34, 43, 44, 51, 53, 57, 63, 67, 81, 86, 93, 94, 97]
# Expected result: [-99, -93, -89, -81, -73, -72, -68, -67, -66, -64, -63, -57, -57, -51, -51, -48, -46, -46, -44, -39, -29, -21, -14, -13, -8, -6, -3, 0, 1, 4, 15, 15, 18, 24, 32, 34, 43, 44, 51, 53, 57, 63, 67, 81, 86, 93, 94, 97]
# Test PASSED
# Current passed-to-tested ratio: 58/58
#
# TEST #59:
# Before sorting: [-54, -36, -3, -54, -71, 8, -74, -74, 49, -68, -66, -23, -75, 93, 78, -53, -96, 13, -93, -37, 86, 31, -92, -26, 15, 74, -47, 10, 13, -14, 99, -10, -76, 33, 26, 39, -89, -21, 37, 66, -50, 75, -84]
# After sorting: [-96, -93, -92, -89, -84, -76, -75, -74, -74, -71, -68, -66, -54, -54, -53, -50, -47, -37, -36, -26, -23, -21, -14, -10, -3, 8, 10, 13, 13, 15, 26, 31, 33, 37, 39, 49, 66, 74, 75, 78, 86, 93, 99]
# Expected result: [-96, -93, -92, -89, -84, -76, -75, -74, -74, -71, -68, -66, -54, -54, -53, -50, -47, -37, -36, -26, -23, -21, -14, -10, -3, 8, 10, 13, 13, 15, 26, 31, 33, 37, 39, 49, 66, 74, 75, 78, 86, 93, 99]
# Test PASSED
# Current passed-to-tested ratio: 59/59
#
# TEST #60:
# Before sorting: [54, 43, -1, -76, 57, -32, -72, -75, 49, 91, -60, 89, 23, -86, -81, 49, -74]
# After sorting: [-86, -81, -76, -75, -74, -72, -60, -32, -1, 23, 43, 49, 49, 54, 57, 89, 91]
# Expected result: [-86, -81, -76, -75, -74, -72, -60, -32, -1, 23, 43, 49, 49, 54, 57, 89, 91]
# Test PASSED
# Current passed-to-tested ratio: 60/60
#
# TEST #61:
# Before sorting: [-7, -58]
# After sorting: [-58, -7]
# Expected result: [-58, -7]
# Test PASSED
# Current passed-to-tested ratio: 61/61
#
# TEST #62:
# Before sorting: [6, 25, -18]
# After sorting: [-18, 6, 25]
# Expected result: [-18, 6, 25]
# Test PASSED
# Current passed-to-tested ratio: 62/62
#
# TEST #63:
# Before sorting: [64, -45, -76, 78, -26, 24, -42, 44, 5, 16, -96, 89, 38, -21, 64, -17, -23, 59, 29, -27, -81, 2, -69, 38, 1, 83, -66, -55, -37, -81, -30]
# After sorting: [-96, -81, -81, -76, -69, -66, -55, -45, -42, -37, -30, -27, -26, -23, -21, -17, 1, 2, 5, 16, 24, 29, 38, 38, 44, 59, 64, 64, 78, 83, 89]
# Expected result: [-96, -81, -81, -76, -69, -66, -55, -45, -42, -37, -30, -27, -26, -23, -21, -17, 1, 2, 5, 16, 24, 29, 38, 38, 44, 59, 64, 64, 78, 83, 89]
# Test PASSED
# Current passed-to-tested ratio: 63/63
#
# TEST #64:
# Before sorting: [63, 92, -92, 11, -69, 96, -43, 87, -37, 99, -94, 59, 55, 2, 15, 78, -60, -81, -47, 96, 37, -53, 100, 15, -92, 80, 64, 31, 46]
# After sorting: [-94, -92, -92, -81, -69, -60, -53, -47, -43, -37, 2, 11, 15, 15, 31, 37, 46, 55, 59, 63, 64, 78, 80, 87, 92, 96, 96, 99, 100]
# Expected result: [-94, -92, -92, -81, -69, -60, -53, -47, -43, -37, 2, 11, 15, 15, 31, 37, 46, 55, 59, 63, 64, 78, 80, 87, 92, 96, 96, 99, 100]
# Test PASSED
# Current passed-to-tested ratio: 64/64
#
# TEST #65:
# Before sorting: [83, -77, 4, -97, 45, 49, -52, -53, -89, 3, 100, 91, -18, 56, 44]
# After sorting: [-97, -89, -77, -53, -52, -18, 3, 4, 44, 45, 49, 56, 83, 91, 100]
# Expected result: [-97, -89, -77, -53, -52, -18, 3, 4, 44, 45, 49, 56, 83, 91, 100]
# Test PASSED
# Current passed-to-tested ratio: 65/65
#
# TEST #66:
# Before sorting: [30, -84, -92, -49, -32, 44, 83, -89, 81, 0, 91, 96, 91, -78, 29, 42, 30, -13, 26, 18, -32, -78, 29, -4, 42, 88, -50, -76, -76, 27, -22, -67, -24, -76, 64, -92, -100, 49, -55, -95, -10]
# After sorting: [-100, -95, -92, -92, -89, -84, -78, -78, -76, -76, -76, -67, -55, -50, -49, -32, -32, -24, -22, -13, -10, -4, 0, 18, 26, 27, 29, 29, 30, 30, 42, 42, 44, 49, 64, 81, 83, 88, 91, 91, 96]
# Expected result: [-100, -95, -92, -92, -89, -84, -78, -78, -76, -76, -76, -67, -55, -50, -49, -32, -32, -24, -22, -13, -10, -4, 0, 18, 26, 27, 29, 29, 30, 30, 42, 42, 44, 49, 64, 81, 83, 88, 91, 91, 96]
# Test PASSED
# Current passed-to-tested ratio: 66/66
#
# TEST #67:
# Before sorting: [-96, -10, -12, 51, 28, 8, -1, -39, 8, -78, -41, 56, 65]
# After sorting: [-96, -78, -41, -39, -12, -10, -1, 8, 8, 28, 51, 56, 65]
# Expected result: [-96, -78, -41, -39, -12, -10, -1, 8, 8, 28, 51, 56, 65]
# Test PASSED
# Current passed-to-tested ratio: 67/67
#
# TEST #68:
# Before sorting: [-59, 64, 39, 40, -17, 0, -22, -86, 32, 33, 1, -75, -43, 36, 14, -54, -39, 1, 67, 96, -61, -70]
# After sorting: [-86, -75, -70, -61, -59, -54, -43, -39, -22, -17, 0, 1, 1, 14, 32, 33, 36, 39, 40, 64, 67, 96]
# Expected result: [-86, -75, -70, -61, -59, -54, -43, -39, -22, -17, 0, 1, 1, 14, 32, 33, 36, 39, 40, 64, 67, 96]
# Test PASSED
# Current passed-to-tested ratio: 68/68
#
# TEST #69:
# Before sorting: [-76, -82, -91, 43, 4, -62, 57, -11, 98, -55, 86, -16, -99, -87, 7, 65, -29, -5, -39, -65, -84, 57, 74, 95, -24, 72, 84, 78, 88, 24, -77, 61, -11, 16, -27, -7, -89]
# After sorting: [-99, -91, -89, -87, -84, -82, -77, -76, -65, -62, -55, -39, -29, -27, -24, -16, -11, -11, -7, -5, 4, 7, 16, 24, 43, 57, 57, 61, 65, 72, 74, 78, 84, 86, 88, 95, 98]
# Expected result: [-99, -91, -89, -87, -84, -82, -77, -76, -65, -62, -55, -39, -29, -27, -24, -16, -11, -11, -7, -5, 4, 7, 16, 24, 43, 57, 57, 61, 65, 72, 74, 78, 84, 86, 88, 95, 98]
# Test PASSED
# Current passed-to-tested ratio: 69/69
#
# TEST #70:
# Before sorting: [-19, 82, -74, -76, 4, 24, 18, 39, -5, 80, 14, 43, -27, 80, -56, 70, 90, -97, -60, -11, 99, -22, -14, 10, -86, 94, -68, 94, -19, 94, -74, 82, 86, 87]
# After sorting: [-97, -86, -76, -74, -74, -68, -60, -56, -27, -22, -19, -19, -14, -11, -5, 4, 10, 14, 18, 24, 39, 43, 70, 80, 80, 82, 82, 86, 87, 90, 94, 94, 94, 99]
# Expected result: [-97, -86, -76, -74, -74, -68, -60, -56, -27, -22, -19, -19, -14, -11, -5, 4, 10, 14, 18, 24, 39, 43, 70, 80, 80, 82, 82, 86, 87, 90, 94, 94, 94, 99]
# Test PASSED
# Current passed-to-tested ratio: 70/70
#
# TEST #71:
# Before sorting: [-95, -45, -69, 34, 84, -17, -93, 31, -15, 47, 5, 2, -20, -9]
# After sorting: [-95, -93, -69, -45, -20, -17, -15, -9, 2, 5, 31, 34, 47, 84]
# Expected result: [-95, -93, -69, -45, -20, -17, -15, -9, 2, 5, 31, 34, 47, 84]
# Test PASSED
# Current passed-to-tested ratio: 71/71
#
# TEST #72:
# Before sorting: [-66, -1, 13]
# After sorting: [-66, -1, 13]
# Expected result: [-66, -1, 13]
# Test PASSED
# Current passed-to-tested ratio: 72/72
#
# TEST #73:
# Before sorting: [44, -95, -21, 89, 44, -66, -15, 38]
# After sorting: [-95, -66, -21, -15, 38, 44, 44, 89]
# Expected result: [-95, -66, -21, -15, 38, 44, 44, 89]
# Test PASSED
# Current passed-to-tested ratio: 73/73
#
# TEST #74:
# Before sorting: [22, -7, 67, 64, 49, -21, 16, 86, -26, -25, -89, -30, -42, -13, 12, 32, -82, -96, -44, 68, 27, -90, -91, 1, -36, -64, 67, -48, 9, 92, 36, 0, 70, 49, 27, 46, -58, -73]
# After sorting: [-96, -91, -90, -89, -82, -73, -64, -58, -48, -44, -42, -36, -30, -26, -25, -21, -13, -7, 0, 1, 9, 12, 16, 22, 27, 27, 32, 36, 46, 49, 49, 64, 67, 67, 68, 70, 86, 92]
# Expected result: [-96, -91, -90, -89, -82, -73, -64, -58, -48, -44, -42, -36, -30, -26, -25, -21, -13, -7, 0, 1, 9, 12, 16, 22, 27, 27, 32, 36, 46, 49, 49, 64, 67, 67, 68, 70, 86, 92]
# Test PASSED
# Current passed-to-tested ratio: 74/74
#
# TEST #75:
# Before sorting: [72, -28, -71, 8, -8, -53, 50, -13, 75, -22, -57, 18, -37, -73, -1, 62, -1, 29, -79, 70, 10, 17, -100, 7, -17, 59, -1, 80, -96, 42, 24, 93, -100, 16, -49, 38, 3, -18, 65, -28, 57, 38]
# After sorting: [-100, -100, -96, -79, -73, -71, -57, -53, -49, -37, -28, -28, -22, -18, -17, -13, -8, -1, -1, -1, 3, 7, 8, 10, 16, 17, 18, 24, 29, 38, 38, 42, 50, 57, 59, 62, 65, 70, 72, 75, 80, 93]
# Expected result: [-100, -100, -96, -79, -73, -71, -57, -53, -49, -37, -28, -28, -22, -18, -17, -13, -8, -1, -1, -1, 3, 7, 8, 10, 16, 17, 18, 24, 29, 38, 38, 42, 50, 57, 59, 62, 65, 70, 72, 75, 80, 93]
# Test PASSED
# Current passed-to-tested ratio: 75/75
#
# TEST #76:
# Before sorting: []
# After sorting: []
# Expected result: []
# Test PASSED
# Current passed-to-tested ratio: 76/76
#
# TEST #77:
# Before sorting: [1, -9, -23, 95, 42, 66, 86, -45, 33, -49, 21, -42, -92, 85, 47, 65, 78, -46, -72, 91, -57, -50, -73, -14, 28, -19, -26, 99, -29, -51, -77, -34, -19, -8, -86, 64, -83, -49, 70]
# After sorting: [-92, -86, -83, -77, -73, -72, -57, -51, -50, -49, -49, -46, -45, -42, -34, -29, -26, -23, -19, -19, -14, -9, -8, 1, 21, 28, 33, 42, 47, 64, 65, 66, 70, 78, 85, 86, 91, 95, 99]
# Expected result: [-92, -86, -83, -77, -73, -72, -57, -51, -50, -49, -49, -46, -45, -42, -34, -29, -26, -23, -19, -19, -14, -9, -8, 1, 21, 28, 33, 42, 47, 64, 65, 66, 70, 78, 85, 86, 91, 95, 99]
# Test PASSED
# Current passed-to-tested ratio: 77/77
#
# TEST #78:
# Before sorting: [99, -39, 24, -96, -54, -93, 97, -75, 14, 51, 76, -72, -100, -44, 25, 14, -75, 38, -27, 9, -82, 71, 26, -100, 35, -82, -84, 6, -87, -77, -56, -11, -73, -69, 3, 0, -58, -57, -80, -13, -60, 77, -84, 12, 13, -81, -9, 9, 27]
# After sorting: [-100, -100, -96, -93, -87, -84, -84, -82, -82, -81, -80, -77, -75, -75, -73, -72, -69, -60, -58, -57, -56, -54, -44, -39, -27, -13, -11, -9, 0, 3, 6, 9, 9, 12, 13, 14, 14, 24, 25, 26, 27, 35, 38, 51, 71, 76, 77, 97, 99]
# Expected result: [-100, -100, -96, -93, -87, -84, -84, -82, -82, -81, -80, -77, -75, -75, -73, -72, -69, -60, -58, -57, -56, -54, -44, -39, -27, -13, -11, -9, 0, 3, 6, 9, 9, 12, 13, 14, 14, 24, 25, 26, 27, 35, 38, 51, 71, 76, 77, 97, 99]
# Test PASSED
# Current passed-to-tested ratio: 78/78
#
# TEST #79:
# Before sorting: [22, -20, -72, -69, -18, 90, -4, 53, -18, -32]
# After sorting: [-72, -69, -32, -20, -18, -18, -4, 22, 53, 90]
# Expected result: [-72, -69, -32, -20, -18, -18, -4, 22, 53, 90]
# Test PASSED
# Current passed-to-tested ratio: 79/79
#
# TEST #80:
# Before sorting: [94, -68, 53, 42, -22, 33, 11, -89, -24, 51, -6, 86, 1, -44, -35, -5, -73, -61, -56, -27, -77, -67, 46, -9, -51, -13, 21, -44]
# After sorting: [-89, -77, -73, -68, -67, -61, -56, -51, -44, -44, -35, -27, -24, -22, -13, -9, -6, -5, 1, 11, 21, 33, 42, 46, 51, 53, 86, 94]
# Expected result: [-89, -77, -73, -68, -67, -61, -56, -51, -44, -44, -35, -27, -24, -22, -13, -9, -6, -5, 1, 11, 21, 33, 42, 46, 51, 53, 86, 94]
# Test PASSED
# Current passed-to-tested ratio: 80/80
#
# TEST #81:
# Before sorting: [37, 94, 23, 57, -63, -25, 51, 70, 8, 22, -1, -39, -68, -41, 89, 2, -14, 1, -2, 22, 39, -86, 58, -39, 67, 67, 69, 62, -53, 16]
# After sorting: [-86, -68, -63, -53, -41, -39, -39, -25, -14, -2, -1, 1, 2, 8, 16, 22, 22, 23, 37, 39, 51, 57, 58, 62, 67, 67, 69, 70, 89, 94]
# Expected result: [-86, -68, -63, -53, -41, -39, -39, -25, -14, -2, -1, 1, 2, 8, 16, 22, 22, 23, 37, 39, 51, 57, 58, 62, 67, 67, 69, 70, 89, 94]
# Test PASSED
# Current passed-to-tested ratio: 81/81
#
# TEST #82:
# Before sorting: [-66, 35, -33, -36, 13, 20, -77, 91, -57, -81, 67, 20, -48, -56, 23, 100, 77, -80, -98, -20, -17, 21, -33, -42, -42, -82, 67]
# After sorting: [-98, -82, -81, -80, -77, -66, -57, -56, -48, -42, -42, -36, -33, -33, -20, -17, 13, 20, 20, 21, 23, 35, 67, 67, 77, 91, 100]
# Expected result: [-98, -82, -81, -80, -77, -66, -57, -56, -48, -42, -42, -36, -33, -33, -20, -17, 13, 20, 20, 21, 23, 35, 67, 67, 77, 91, 100]
# Test PASSED
# Current passed-to-tested ratio: 82/82
#
# TEST #83:
# Before sorting: [-37, 20, -65]
# After sorting: [-65, -37, 20]
# Expected result: [-65, -37, 20]
# Test PASSED
# Current passed-to-tested ratio: 83/83
#
# TEST #84:
# Before sorting: [36, 32, 73, -97, -62, -30]
# After sorting: [-97, -62, -30, 32, 36, 73]
# Expected result: [-97, -62, -30, 32, 36, 73]
# Test PASSED
# Current passed-to-tested ratio: 84/84
#
# TEST #85:
# Before sorting: [-54, 12, 93, -60, 17, -89, 77, -2, 28, 10, 74, 74, -37, 88]
# After sorting: [-89, -60, -54, -37, -2, 10, 12, 17, 28, 74, 74, 77, 88, 93]
# Expected result: [-89, -60, -54, -37, -2, 10, 12, 17, 28, 74, 74, 77, 88, 93]
# Test PASSED
# Current passed-to-tested ratio: 85/85
#
# TEST #86:
# Before sorting: [92, -33, -49, -5, -8, 67, 29, 62, 46]
# After sorting: [-49, -33, -8, -5, 29, 46, 62, 67, 92]
# Expected result: [-49, -33, -8, -5, 29, 46, 62, 67, 92]
# Test PASSED
# Current passed-to-tested ratio: 86/86
#
# TEST #87:
# Before sorting: [-38, 65, 56, 29, -24, 53, 44, 86, -82, 55, -12, 17, 54, -1, -41, -99, -70, 68, -49, 9, 89]
# After sorting: [-99, -82, -70, -49, -41, -38, -24, -12, -1, 9, 17, 29, 44, 53, 54, 55, 56, 65, 68, 86, 89]
# Expected result: [-99, -82, -70, -49, -41, -38, -24, -12, -1, 9, 17, 29, 44, 53, 54, 55, 56, 65, 68, 86, 89]
# Test PASSED
# Current passed-to-tested ratio: 87/87
#
# TEST #88:
# Before sorting: [-91, 55, -89, 100, -12, 44, 44, 90, 38, 14, 51, 99, -86, 41, 42]
# After sorting: [-91, -89, -86, -12, 14, 38, 41, 42, 44, 44, 51, 55, 90, 99, 100]
# Expected result: [-91, -89, -86, -12, 14, 38, 41, 42, 44, 44, 51, 55, 90, 99, 100]
# Test PASSED
# Current passed-to-tested ratio: 88/88
#
# TEST #89:
# Before sorting: [51, 38, -60, 48, 78, -37, 37, -97, 24, -58, 25, 13, -67, -95, 54, 24, -27, 3, -52, -29, 68, 61, 0, 98, -83, 58, 47, -3, 59, -36]
# After sorting: [-97, -95, -83, -67, -60, -58, -52, -37, -36, -29, -27, -3, 0, 3, 13, 24, 24, 25, 37, 38, 47, 48, 51, 54, 58, 59, 61, 68, 78, 98]
# Expected result: [-97, -95, -83, -67, -60, -58, -52, -37, -36, -29, -27, -3, 0, 3, 13, 24, 24, 25, 37, 38, 47, 48, 51, 54, 58, 59, 61, 68, 78, 98]
# Test PASSED
# Current passed-to-tested ratio: 89/89
#
# TEST #90:
# Before sorting: [3]
# After sorting: [3]
# Expected result: [3]
# Test PASSED
# Current passed-to-tested ratio: 90/90
#
# TEST #91:
# Before sorting: [18, -32, -72, -5, 76, 33, -76, 67, -12, 32, 89, 43, 27, 52, -32, 80, 8, -6, -54, 21, 99, 10, 64, -25, 89, -8, -14, 18, -81, -61, -50, -94, -51, -95, 27, 81, 96, 25, -3, 7, -44, -65, 89, 84, -49, -44]
# After sorting: [-95, -94, -81, -76, -72, -65, -61, -54, -51, -50, -49, -44, -44, -32, -32, -25, -14, -12, -8, -6, -5, -3, 7, 8, 10, 18, 18, 21, 25, 27, 27, 32, 33, 43, 52, 64, 67, 76, 80, 81, 84, 89, 89, 89, 96, 99]
# Expected result: [-95, -94, -81, -76, -72, -65, -61, -54, -51, -50, -49, -44, -44, -32, -32, -25, -14, -12, -8, -6, -5, -3, 7, 8, 10, 18, 18, 21, 25, 27, 27, 32, 33, 43, 52, 64, 67, 76, 80, 81, 84, 89, 89, 89, 96, 99]
# Test PASSED
# Current passed-to-tested ratio: 91/91
#
# TEST #92:
# Before sorting: [71, 96, 24, -51, -92, 50, 21, 77, -78, -87, -5, -22, -73, 90, 51, -76, 79, -55, -100, 54, -14, -51, -82, -100, 64, 27, 74, 25, -63, 76, 66]
# After sorting: [-100, -100, -92, -87, -82, -78, -76, -73, -63, -55, -51, -51, -22, -14, -5, 21, 24, 25, 27, 50, 51, 54, 64, 66, 71, 74, 76, 77, 79, 90, 96]
# Expected result: [-100, -100, -92, -87, -82, -78, -76, -73, -63, -55, -51, -51, -22, -14, -5, 21, 24, 25, 27, 50, 51, 54, 64, 66, 71, 74, 76, 77, 79, 90, 96]
# Test PASSED
# Current passed-to-tested ratio: 92/92
#
# TEST #93:
# Before sorting: [-56, -87, -30, 60, -65, 75, -26, -70, 78, 13, 31, 70, -93, 96, -70, -6, 79, 52, -86]
# After sorting: [-93, -87, -86, -70, -70, -65, -56, -30, -26, -6, 13, 31, 52, 60, 70, 75, 78, 79, 96]
# Expected result: [-93, -87, -86, -70, -70, -65, -56, -30, -26, -6, 13, 31, 52, 60, 70, 75, 78, 79, 96]
# Test PASSED
# Current passed-to-tested ratio: 93/93
#
# TEST #94:
# Before sorting: [-5, 26, -43, -11, -58, 35, 88, -35, -71, -93, -13, 15, 39, 45, 87, -12, -49, 32, -32, -74, -4, 69, -21, 41, 10, -58, -26, -44, -79, -49, -99, -46, -80, 72, 94, 52, 16, 74, -73, -7]
# After sorting: [-99, -93, -80, -79, -74, -73, -71, -58, -58, -49, -49, -46, -44, -43, -35, -32, -26, -21, -13, -12, -11, -7, -5, -4, 10, 15, 16, 26, 32, 35, 39, 41, 45, 52, 69, 72, 74, 87, 88, 94]
# Expected result: [-99, -93, -80, -79, -74, -73, -71, -58, -58, -49, -49, -46, -44, -43, -35, -32, -26, -21, -13, -12, -11, -7, -5, -4, 10, 15, 16, 26, 32, 35, 39, 41, 45, 52, 69, 72, 74, 87, 88, 94]
# Test PASSED
# Current passed-to-tested ratio: 94/94
#
# TEST #95:
# Before sorting: [-92, 29, -33, 60, -76, -99, 75]
# After sorting: [-99, -92, -76, -33, 29, 60, 75]
# Expected result: [-99, -92, -76, -33, 29, 60, 75]
# Test PASSED
# Current passed-to-tested ratio: 95/95
#
# TEST #96:
# Before sorting: [-65, 31, 78, 94, 56, -19, 31, -96, 17, -20, 21, 84, -87, -11, -60, 69, -1, 92, -14, -14]
# After sorting: [-96, -87, -65, -60, -20, -19, -14, -14, -11, -1, 17, 21, 31, 31, 56, 69, 78, 84, 92, 94]
# Expected result: [-96, -87, -65, -60, -20, -19, -14, -14, -11, -1, 17, 21, 31, 31, 56, 69, 78, 84, 92, 94]
# Test PASSED
# Current passed-to-tested ratio: 96/96
#
# TEST #97:
# Before sorting: [33, 17, -59, 52, -54, 59, 5, 50, 65, -81, 19, -7, 58, -4, -83, 80, -43, -33, 40, 74, 0, -54, -15, -44, -35, -93, -54, 39, -63, 11, -27, -75, -20, -19, 15, 20, -99, -33, -31, 97, 5, -45, 56, 41, 92, 28, 82, -24]
# After sorting: [-99, -93, -83, -81, -75, -63, -59, -54, -54, -54, -45, -44, -43, -35, -33, -33, -31, -27, -24, -20, -19, -15, -7, -4, 0, 5, 5, 11, 15, 17, 19, 20, 28, 33, 39, 40, 41, 50, 52, 56, 58, 59, 65, 74, 80, 82, 92, 97]
# Expected result: [-99, -93, -83, -81, -75, -63, -59, -54, -54, -54, -45, -44, -43, -35, -33, -33, -31, -27, -24, -20, -19, -15, -7, -4, 0, 5, 5, 11, 15, 17, 19, 20, 28, 33, 39, 40, 41, 50, 52, 56, 58, 59, 65, 74, 80, 82, 92, 97]
# Test PASSED
# Current passed-to-tested ratio: 97/97
#
# TEST #98:
# Before sorting: [60, -41, -94, 53, -48, 45, -9, -40, 90, -68, -3, 17, 46, -87, -33, 67, -91, -91, -62, -10, -6, -11, -37, 34, -72, -34, 20, 78, 70, 79, -95, -59, 53, -50, -33, 16, 91, 31, 49, -32, -41, -67, -12, 37]
# After sorting: [-95, -94, -91, -91, -87, -72, -68, -67, -62, -59, -50, -48, -41, -41, -40, -37, -34, -33, -33, -32, -12, -11, -10, -9, -6, -3, 16, 17, 20, 31, 34, 37, 45, 46, 49, 53, 53, 60, 67, 70, 78, 79, 90, 91]
# Expected result: [-95, -94, -91, -91, -87, -72, -68, -67, -62, -59, -50, -48, -41, -41, -40, -37, -34, -33, -33, -32, -12, -11, -10, -9, -6, -3, 16, 17, 20, 31, 34, 37, 45, 46, 49, 53, 53, 60, 67, 70, 78, 79, 90, 91]
# Test PASSED
# Current passed-to-tested ratio: 98/98
#
# TEST #99:
# Before sorting: [-25, -7, 66, -69, 57, 90, 66, -99, 29, 45, -53, 67, 23, -2, -17, 82, -16, 79, -43]
# After sorting: [-99, -69, -53, -43, -25, -17, -16, -7, -2, 23, 29, 45, 57, 66, 66, 67, 79, 82, 90]
# Expected result: [-99, -69, -53, -43, -25, -17, -16, -7, -2, 23, 29, 45, 57, 66, 66, 67, 79, 82, 90]
# Test PASSED
# Current passed-to-tested ratio: 99/99
#
# TEST #100:
# Before sorting: [-69, -67, 69, -64, 59, -34, -99, -65, 26, 5, -99, 64, 55, -20, -90, 16, -51, 65, 60, -20, -60, 18, 1, -11, -30, -79, -54, 60, 85, 9, 18, 94, 19, 40, -13, 11, 60]
# After sorting: [-99, -99, -90, -79, -69, -67, -65, -64, -60, -54, -51, -34, -30, -20, -20, -13, -11, 1, 5, 9, 11, 16, 18, 18, 19, 26, 40, 55, 59, 60, 60, 60, 64, 65, 69, 85, 94]
# Expected result: [-99, -99, -90, -79, -69, -67, -65, -64, -60, -54, -51, -34, -30, -20, -20, -13, -11, 1, 5, 9, 11, 16, 18, 18, 19, 26, 40, 55, 59, 60, 60, 60, 64, 65, 69, 85, 94]
# Test PASSED
# Current passed-to-tested ratio: 100/100
#
# Sorting algorithms is correct
# Passed tests in total: 100/100
